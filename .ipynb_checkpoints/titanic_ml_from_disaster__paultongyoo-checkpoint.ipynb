# %% [markdown]
# <img src="https://dootoo.app/images/thoughtswork_banner.png"/>

# %% [markdown]
# # Kaggle Competition Submission: Titanic: Machine Learning from Disaster

# %% [markdown]
# * **Author:** Paul Tongyoo
# * **Contact:** Message me on <a href="https://www.linkedin.com/in/paultongyoo/">LinkedIn</a>
# * **Date:** May 15, 2025
# * **Official Competition Page:** <a href="https://www.kaggle.com/competitions/titanic">Titanic: Machine Learning from Disaster</a>
# * **Latest Submission Score (Accuracy):** 0.7727 (Top 39% of 15995 entries)

# %% [markdown]
# (Work in progress)

# %% [markdown]
# Please Note: To use Table of Contents links, please run notebook within Jupyter environment.

# %% [markdown]
# ## Table of Contents
# 1. [Project Summary](#Project-Summary)
#     1. [What I Did](#What-I-Did)
#     1. [What I Learned](#What-I-Learned)
#     1. [What's Next](#Whats-Next)
# 1. [Introduction](#Introduction)
# 1. [Methodology](#Methodology)
#     1. [Data Understanding](#Data-Understanding)
#         1. [Data Dictionary](#Data-Dictionary)
#         1. [Variable Notes](#Variable-Notes)
#         1. [Descriptive Statistics](#Descriptive-Statistics)
#         1. [Row Samples](#Row-Samples)
#         1. [Data Types](#Data-Types)
#         1. [Missing Values Summary](#Missing-Values-Summary)
#     1. [Data Preparation](#Data-Preparation)
#         1. [Missing Value Imputation](#Missing-Value-Imputation)
#             1. [Embarked](#Embarked)
#             1. [Cabin](#Cabin)
#             1. [Age](#Age)
#             1. [Fare](#Fare)
#     1. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
#         1. [Individual Features x Target](#Individual-Features-x-Target)
#             1. [Pclass](#Pclass)
#             1. [Sex](#Sex)
#             1. [SibSp](#SibSp)
#             1. [Parch](#Parch)
#             1. [Embarked_](#Embarked_)
#             1. [HasCabin](#HasCabin)
#             1. [Cabin_count](#Cabin_count)
#             1. [Cabin_Location_s](#Cabin_Location_s)
#             1. [Deck](#Deck)
#             1. [Title](#Title)
#             1. [Age_](#Age_)
#             1. [Age_Group](#Age_Group)
#             1. [Fare_](#Fare_)
#             1. [Summary of Single Feature Relationship with Target](#Summary-of-Single-Feature-Relationship-with-Target)
#         1. [Composite Features x Target](#Composite-Features-x-Target)
#             1. [Pclass x Sex](#Pclass-x-Sex)
#             1. [Pclass x Sex x SibSp](#Pclass-x-Sex-x-SibSp)
#             1. [Pclass x Sex x Parch](#Pclass-x-Sex-x-Parch)
#             1. [Pclass x Sex x Embarked](#Pclass-x-Sex-x-Embarked)
#             1. [Pclass x Sex x HasCabin](#Pclass-x-Sex-x-HasCabin)
#             1. [Pclass x Sex x Cabin_count](#Pclass-x-Sex-x-Cabin_count)
#             1. [Pclass x Sex x Cabin_Location_s](#Pclass-x-Sex-x-Cabin_Location_s)
#             1. [Pclass x Sex x Deck](#Pclass-x-Sex-x-Deck)
#             1. [Pclass x Sex x Title](#Pclass-x-Sex-x-Title)
#             1. [Pclass x Sex x Age_Group](#Pclass-x-Sex-x-Age_Group)
#             1. [Pclass x Sex x Fare](#Pclass-x-Sex-x-Fare)
#             1. [Analysis Summary of Composite Feature Relationships with Target](#Analysis-Summary-of-Composite-Feature-Relationships-with-Target)
#         1. [Latent Features](#Latent-Features)
#             1. [Name](#Name)
#             1. [Ticket](#Ticket)
#         1. [Compilation of Feature Engineering Plans](#Compilation-of-Feature-Engineering-Plans)
#     1. [Training/Test Set Distribution Comparison](#TrainingTest-Set-Distribution-Comparison)
#         1. [Pclass_Sex](#Pclass_Sex)
#         1. [Pclass_](#Pclass_)
#         1. [Sex_](#Sex_)
#         1. [SibSp_](#SibSp_)
#         1. [Parch_](#Parch_)
#         1. [Embarked__](#Embarked__)
#         1. [HasCabin_](#HasCabin_)
#         1. [Cabin_count_](#Cabin_count_)
#         1. [Cabin_Location_s_](#Cabin_Location_s_)
#         1. [Deck_](#Deck_)
#         1. [Title_](#Title_)
#         1. [Age__](#Age__)
#         1. [Fare__](#Fare__)
#         1. [Compilation of Distribution Shift Mitigation Plans](#Compilation-of-Distribution-Shift-Mitigation-Plans)
#     1. [Feature Engineering](#Feature-Engineering)
#         1. [Pclass_Sex One-Hot Encodings](#Pclass_Sex-One-Hot-Encodings)
#             1. [Create Features](#Create-Features)
#             1. [Assess Distribution Shift](#Assess-Distribution-Shift)
#         1. [Smoothed Features](#Smoothed-Features)
#         1. [Is_Shared_Ticket](#Is_Shared_Ticket)
#         1. [Fare_Per_Person_log_bin](#Fare_Per_Person_log_bin)
#         1. [Has_Other_Family_Members](#Has_Other_Family_Members)
#         1. [Compilation of Engineered Features and KL Values](#Compilation-of-Engineered-Features-and-KL-Values)
#     1. [Model Development](#Model-Development)
#         1. [Baseline Establishment](#Baseline-Establishment)
#             1. [Predict Majority Class](#Predict-Majority-Class)
#             1. [Predict Simple Model](#Predict-Simple-Model)
#         1. [Engineered Features Test](#Engineered-Features-Test)
#         1. [Out-of-Fold Prediction Mistake Analysis](#Out-of-Fold-Prediction-Mistake-Analysis)
#         1. [SHAP Analysis of Mistakes](#SHAP-Analysis-of-Mistakes)
#         1. [Pclass x Sex Subgroup Sample Size Analysis](#Pclass-x-Sex-Subgroup-Sample-Size-Analysis)
#         1. [Model-per-Subgroup Baseline Performance](#Model-per-Subgroup-Baseline-Performance)
#     1. [Pclass x Sex Subgroup Development](#Pclass-x-Sex-Subgroup-Development)
#         1. [P1 Male](#P1-Male)
#             1. [P1 Male Desciptive Statistics](#P1-Male-Desciptive-Statistics)
#             1. [P1 Male Distribution Shift Assessment](#P1-Male-Distribution-Shift-Assessment)
#             1. [P1 Male Feature Engineering](#P1-Male-Feature-Engineering)
#                 1. [P1_Male_Parch_SibSp_bin](#P1_Male_Parch_SibSp_bin)
#                 1. [P1_Male_Embarked_Is_S](#P1_Male_Embarked_Is_S)
#                 1. [P1_Male_Cabin_count_bin](#P1_Male_Cabin_count_bin)
#                 1. [P1_Male Cabin_Location_s](#P1_Male-Cabin_Location_s)
#                 1. [P1_Male_Deck_bin](#P1_Male_Deck_bin)
#                 1. [P1_Male_Title_bin](#P1_Male_Title_bin)
#                 1. [P1_Male_Age_bin](#P1_Male_Age_bin)
#                 1. [P1_Male_Fare_log_bin](#P1_Male_Fare_log_bin)
#             1. [P1 Male Feature Chi-Square Testing](#P1-Male-Feature-Chi-Square-Testing)
#             1. [P1 Male Smoothed Feature Engineering](#P1-Male-Smoothed-Feature-Engineering)
#             1. [P1 Male Model Development](#P1-Male-Model-Development)
#         1. [P3 Female](#P3-Female)
#             1. [P3 Female Desciptive Statistics](#P3-Female-Desciptive-Statistics)
#             1. [P3 Female Distribution Shift Assessment](#P3-Female-Distribution-Shift-Assessment)
#             1. [P3 Female Feature Engineering](#P3-Female-Feature-Engineering)
#                 1. [P3_Female_Parch_SibSp_bin](#P3_Female_Parch_SibSp_bin)
#                 1. [P3_Female_Embarked_Is_S](#P3_Female_Embarked_Is_S)
#                 1. [P3_Female_Cabin_count_bin](#P3_Female_Cabin_count_bin)
#                 1. [P3_Female_Cabin_Location_s_bin](#P3_Female_Cabin_Location_s_bin)
#                 1. [P3_Female_Deck_bin](#P3_Female_Deck_bin)
#     1. [Subgroup Feature Search](#Subgroup-Feature-Search)
#         1. [P1 Male](#P1-Male)
#         1. [P2 Male](#P2-Male)
#         1. [P3 Male](#P3-Male)
#         1. [P3 Female](#P3-Female)
#     1. [Hyperparameter Tuning](#Hyperparameter-Tuning)
# 1. [Submission](#Submission)
# 1. [References](#References)

# %% [markdown]
# ## Project Summary
#
# This project tackles the classic Kaggle challenge: predicting passenger survival on the Titanic using machine learning. It serves as a hands-on exercise in feature engineering, model development, and interpretability within a well-known dataset, allowing for deep exploration of structured data analysis and model evaluation techniques.
#
# ---
#
# ### What I Did
#
# - Performed exploratory data analysis (EDA) to understand patterns in survival across features like class, gender, fare, and cabin location.
# - Conducted advanced feature engineering, including interaction features (e.g., `Pclass × Sex × Age Group`) and smoothed binary indicators for rare subgroups.
# - Handled missing values with targeted imputation strategies.
# - Trained and tuned multiple models (e.g., XGBoost, Random Forest) and compared cross-validation scores across feature sets.
# - Interpreted model predictions using SHAP values and worst-fold mistake analysis to identify sources of misclassification.
# - Developed a modular, iterative framework for feature testing and scoring consistency.
#
# ---
#
# ### What I Learned
#
# - How to systematically test the predictive power of engineered features using cross-validation and mistake analysis.
# - The impact of overrepresented or underrepresented groups on feature reliability and generalization.
# - The value of designing interpretable binary features for decision tree models, especially when dealing with small or extreme-case subgroups.
# - Best practices for combining domain intuition with statistical evidence when crafting features.
# - How to balance model complexity with interpretability through visualizations and score decomposition.
#
# ---
#
# ### What's Next
#
# - Automate feature testing and scoring pipelines for faster iteration.
# - Expand into ensemble methods and stacking with model-specific feature subsets.
# - Try alternative modeling techniques like LightGBM or TabNet.
# - Experiment with semi-supervised learning or active learning to handle small or ambiguous passenger groups.
# - Submit final models to Kaggle and track performance over time with versioned feature sets.

# %% [markdown]
# ## Introduction

# %% [markdown]
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this challenge, Kaggle asked us to build a predictive model that answers the question: **“what sorts of people were more likely to survive?”** using passenger data (ie name, age, gender, socio-economic class, etc).

# %% [markdown]
# ## Methodology

# %%
from datetime import datetime
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype, IntervalDtype
from scipy.stats import entropy
from scipy.special import rel_entr
import math
from scipy.stats import chi2_contingency
from IPython.display import display
from itertools import combinations

import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
custom_cmap = LinearSegmentedColormap.from_list("survival_cmap", ["tomato", "lightblue"])

import re
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, StandardScaler  
from sklearn.inspection import permutation_importance
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.model_selection import learning_curve, validation_curve, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree, export_text
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import shap

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# Kaggle provided passenger data split into two groups:
# * Training set (<a href="./input/train.csv">train.csv</a>)
#     * 891 rows, 12 features
# * Test set (<a href="./input/test.csv">test.csv</a>)
#     * 418 rows, 11 features (no `Survived` col)

# %%
# Kaggle.com env
#train_df = pd.read_csv('/kaggle/input/titanic/train.csv')
#test_df = pd.read_csv('/kaggle/input/titanic/test.csv')

# Local Env
train_df = pd.read_csv('./input/train.csv')
test_df = pd.read_csv('./input/test.csv')

# %% [markdown]
# #### Data Dictionary
#
# | Variable | Definition | Key, Example |
# | -------- | ---------- | --- |
# | **Survived** | Survival | 0 = No, 1 = Yes |
# | **PassengerId** | Integer index of passenger | 0,1,2,3,... |
# | **Name** | Name of passenger including title | Braund, Mr. Owen Harris |
# | **Pclass** | Ticket class | 1 = 1st, 2 = 2nd, 3 = 3rd |
# | **Sex** | Sex | female, male |
# | **Age** | Age in years | 0.15, 2, 15 |
# | **SibSp** | # of siblings / spouses aboard the Titanic | 0,1,2,3,.. |
# | **Parch** | # of parents / children aboard the Titanic | 0,1,2,3,.. |
# | **Ticket** | Ticket number, some with prefixes, **shared among groups** | SW/PP 751 |
# | **Fare** | Passenger fare, **shared among groups**	 | 7.91, 14.4542, 512.3292 |
# | **Cabin** | Cabin number(s) listed on ticket, prefixed with deck letter, **shared among groups**	 | A20, "B57 B59 B63 B66"	 |
# | **Embarked** | Port of Embarkation | C = Cherbourg (France), Q = Queenstown (Ireland), S = Southampton (England) |
#
# #### Variable Notes
#
# **pclass:** A proxy for socio-economic status (SES)
# * 1st = Upper
# * 2nd = Middle
# * 3rd = Lower
#
# **age:** Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp:** The dataset defines family relations in this way...
# * Sibling = brother, sister, stepbrother, stepsister
# * Spouse = husband, wife (mistresses and fiancés were ignored)
#
# **parch:** The dataset defines family relations in this way...
# * Parent = mother, father
# * Child = daughter, son, stepdaughter, stepson
# * Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# #### Descriptive Statistics

# %%
train_df.describe(include='number')
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Initial inferences:
# * **PassengerId:** column is most likely a sequential integer index from 1 to 891
# * **Survived:** Mean survival rate for this data set is 38.4%
# * **Pclass:** Top 25% of passengers were in 1st and 2nd Class, remainder in 3rd class
# * **Age:** Youngest child was less than 6 months old, oldest is 80 years old.  Median age 28 yrs, 75th pecentile 38 yrs.  177 values missing
# * **SibSp / Parch**:  At least 50% of passengers traveled alone, 75% passengers had at most 1 sibling or spouse.  Max family size is 8
# * **Fare:** Fares ranged from 0.00 (potentially crew?) to 512.32.  Median fare 14.45, 75th percentile 31.00 - highest fares likely correlates with upper class

# %%
train_df.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# Initial Inferences:
# * **Name:** Contains surname and title info, probable tokens for splitting
# * **Sex:** Majority of passengers were male
# * **Ticket:** Contains number; some contain prefixes with potentially useful info. 210 passengers shared the same ticket number, indicating traveling together (may be family and/or household staff)
# * **Cabin:** Contains room number and deck letter prefix.  Some cabin strings contain multiple cabin numbers, may also signal family or household staff relationships.  687 values missing
# * **Embarked:** Majority of passengers embarked from Southampton, England (644).  2 values missing

# %% [markdown]
# #### Row Samples

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Data Types

# %%
train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### Missing Values Summary

# %%
train_df.isnull().sum().loc[lambda x: x > 0]
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
test_df.isnull().sum().loc[lambda x: x > 0]
# Out:
# Age       86
# Fare       1
# Cabin    327
# dtype: int64

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Missing Value Imputation

# %% [markdown]
# ##### Embarked

# %% [markdown]
# * Only 2 missing values in the data set, will impute based on available data
# * Both passengers list the same cabin and ticket number, strongly suggesting they traveled together and embarked from the same port
# * Historical records show Martha Evelyn Stone and (Rose) Amelie Icard embarked from **Southampton** (See 1,2 in References section)
#     * Amelie was maid to Mrs Stone
# * This being said, to maximize predictive integrity of upcoming modeling we'll inspect data only available at train time instead.
# * Passengers residing on Deck B embarked from either Southamption or Cherbourg, increasing the likelihood these two passengers embarked from one of those two locations.
# * Verified Cabin B28 nor Ticket 113572 are not shared by any other passengers.
# * Verified no other passengers sharing the same last name as Icard or Stone.
# * Given 58.8% of 1st class passengers embarked from Southampton, it is more likely these passengers embarked from Southampton as well.
# * **Missing Embarked values will be imputed with the most common embarkation point of passengers of the same Pclass.**

# %%
train_df[train_df['Embarked'].isnull()][['Name', 'Pclass', 'Ticket', 'Cabin', 'Age', 'Fare', 'Parch', 'SibSp']]
# Out:
#                                           Name  Pclass  Ticket Cabin   Age  \
# 61                         Icard, Miss. Amelie       1  113572   B28  38.0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)       1  113572   B28  62.0
#
#      Fare  Parch  SibSp
# 61   80.0      0      0
# 829  80.0      0      0

# %%
train_df[train_df['Ticket'] == '113572'][['Name', 'Pclass', 'Ticket', 'Cabin', 'Age', 'Fare', 'Parch', 'SibSp']]
# Out:
#                                           Name  Pclass  Ticket Cabin   Age  \
# 61                         Icard, Miss. Amelie       1  113572   B28  38.0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)       1  113572   B28  62.0
#
#      Fare  Parch  SibSp
# 61   80.0      0      0
# 829  80.0      0      0

# %%
train_df[train_df['Cabin'] == 'B28'][['Name', 'Pclass', 'Ticket', 'Cabin', 'Age', 'Fare', 'Parch', 'SibSp']]
# Out:
#                                           Name  Pclass  Ticket Cabin   Age  \
# 61                         Icard, Miss. Amelie       1  113572   B28  38.0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)       1  113572   B28  62.0
#
#      Fare  Parch  SibSp
# 61   80.0      0      0
# 829  80.0      0      0

# %%
train_df[train_df['Name'].str.contains("Stone")][['Name', 'Pclass', 'Ticket', 'Cabin', 'Age', 'Fare', 'Parch', 'SibSp']]
# Out:
#                                                   Name  Pclass  Ticket Cabin  \
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...       1   16966   E34
# 829          Stone, Mrs. George Nelson (Martha Evelyn)       1  113572   B28
#
#       Age   Fare  Parch  SibSp
# 319  40.0  134.5      1      1
# 829  62.0   80.0      0      0

# %%
train_df[train_df['Name'].str.contains("Icard")][['Name', 'Pclass', 'Ticket', 'Cabin', 'Age', 'Fare', 'Parch', 'SibSp']]
# Out:
#                    Name  Pclass  Ticket Cabin   Age  Fare  Parch  SibSp
# 61  Icard, Miss. Amelie       1  113572   B28  38.0  80.0      0      0

# %%
deck_df = train_df[['Cabin', 'Embarked']].copy()
deck_df['Deck'] = deck_df['Cabin'].str[0]
deck_df[deck_df['Deck'] == 'B']['Embarked'].value_counts()
# Out:
# Embarked
# S    23
# C    22
# Name: count, dtype: int64

# %%
first_class_df = train_df[train_df['Pclass'] == 1]
embarked_counts = first_class_df['Embarked'].value_counts(dropna=False).sort_index()
embarked_percent = (embarked_counts / embarked_counts.sum()) * 100
summary_df = pd.DataFrame({
    'Count': embarked_counts,
    'Percentage': embarked_percent.round(2)
})
summary_df.index.name = 'Embarked'
summary_df.reset_index(inplace=True)
print(summary_df)
# Out:
#   Embarked  Count  Percentage
# 0        C     85       39.35
# 1        Q      2        0.93
# 2        S    127       58.80
# 3      NaN      2        0.93

# %%
train_df.groupby(['Embarked', 'Pclass'])['Fare'].median()
# Out:
# Embarked  Pclass
# C         1         78.2667
#           2         24.0000
#           3          7.8958
# Q         1         90.0000
#           2         12.3500
#           3          7.7500
# S         1         52.0000
#           2         13.5000
#           3          8.0500
# Name: Fare, dtype: float64

# %%
train_df['Embarked'].describe()  # Southamption was the most common embarkation point, used for fallback scenario
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
def impute_embarked(df):
    """
    Imputs missing "Embarked" values with the most common Embarkation point from those of the same Pclass. 
    Sets missing value to "S" if mode can't be found (in scenario that all Embarked values for the current Pclass is missing (unlikely))

    Args:
        df (DataFrame): Data set to impute (either training or test data set)

    Returns:
        Updated DataFrame with imputed Embarked feature
    """
    def impute_embarked_with_mode(row, df):
        if pd.isna(row['Embarked']):
            mode_value = df[df['Pclass'] == row['Pclass']]['Embarked'].mode()
            return mode_value[0] if not mode_value.empty else 'S'  # Default to 'S' if mode is not found
        else:
            return row['Embarked']
    
    df['Embarked'] = df.apply(lambda row: impute_embarked_with_mode(row, df), axis=1)
    return df

prepared_train_df = impute_embarked(train_df)
prepared_test_df = impute_embarked(test_df)

# %% [markdown]
# ##### Cabin

# %% [markdown]
# * 1st class passengers are missing only 18.5% of cabin numbers vs 2nd and 3rd class passengers missing 91% and 97.5% of Cabin numbers respectively -- Suggests having a Cabin number is a socio-economic class indicator that should be captured.
# * The known cabin values also have additional signals that should be captured separately:
#     * They contain more than one cabin designation (e.g. "B57 B59 B63 B66"):
#         * Number of cabins becomes an indirect family and wealth signal
#             * 1st class passengers had the most multi-cabins designation
#     * Each cabin token is prefixed with a single character, most likely being the ship deck where is is located
#     * The cabin number will also be extracted as a potential signal, as number corresponds to location of cabin on the ship

# %%
deck_df = train_df[['Pclass', 'Cabin']].copy()
missing_pct = deck_df.groupby('Pclass')['Cabin'].apply(lambda x: x.isna().mean() * 100).reset_index()
missing_pct.columns = ['Pclass', 'Missing_Cabin_Percentage']
print(missing_pct)
# Out:
#    Pclass  Missing_Cabin_Percentage
# 0       1                 18.518519
# 1       2                 91.304348
# 2       3                 97.556008

# %%
def derive_features_from_cabin_then_drop(df):
    """
    Creates FOUR new features based on contents of "Cabin" and then DROPS the "Cabin" column:
      1) "HasCabin" (bool): true if passenger had Cabin value
      2) "Cabin_count" (category): Number of cabins cited in passenger's Cabin value.  
                              Set to 1 for passengers with no Cabin value.
      3) "Deck" (category): Single letter identifying the deck where known Cabin was located (e.g. A, B C)
                            Set to 'M' for passengers with no Cabin value
      4) "Cabin_Location_s" (category): String indicating whether cab is located on "port" or "starboard" side of boat
                                        based on cabin number(s).  Set to "both" if string contains multiple cabin
                                        numbers that reside on both sides of boat

    Args:
        df (DataFrame): Data set to impute (either training or test data set)

    Returns:
        Nothing
    """
    df['HasCabin'] = (df['Cabin'].notnull()).astype(int)
    df['Cabin_count'] = df['Cabin'].apply(lambda x: 0 if pd.isna(x) else len(x.split()))
    df['Cabin_count'] = df['Cabin_count'].astype('category')

    # Extract first character from non-missing Cabin values; assign 'M' for missing Cabin values
    df['Deck'] = df['Cabin'].apply(lambda x: 'M' if pd.isna(x) else x[0])  
    deck_order = sorted(df["Deck"].dropna().unique())
    df["Deck"] = pd.Categorical(df["Deck"], categories=deck_order, ordered=True)

    # Implement Cabin_Location_s
    def determine_cabin_side(cabin_str):
        if pd.isna(cabin_str):
            return "no_cabin_info" 
    
        # Extract all numeric parts from the cabin string
        cabin_numbers = re.findall(r'\d+', cabin_str)
        if not cabin_numbers:
            return "no_cabin_number"
    
        cabin_nums = [int(num) for num in cabin_numbers]
    
        all_even = all(num % 2 == 0 for num in cabin_nums)
        all_odd = all(num % 2 != 0 for num in cabin_nums)
    
        if all_even:
            return "port"
        elif all_odd:
            return "starboard"
        else:
            return "port_and_starboard"
    
    # Apply function to create the new feature
    df['Cabin_Location_s'] = df['Cabin'].apply(determine_cabin_side).astype('category')
    
    df.drop(columns="Cabin", inplace=True)

# Create prepared training and test data frames to be used for EDA and modeling
derive_features_from_cabin_then_drop(prepared_train_df)
derive_features_from_cabin_then_drop(prepared_test_df)

# %%
print(prepared_train_df[['HasCabin']].value_counts().sort_index())
print()
print(prepared_train_df[['Pclass', 'Cabin_count']].value_counts().sort_index())
print()
print(prepared_train_df[['Deck']].value_counts().sort_index())
print()
print(prepared_train_df[['Cabin_Location_s']].value_counts().sort_index())
# Out:
# HasCabin
# 0           687
# 1           204
# Name: count, dtype: int64
#
# Pclass  Cabin_count
# 1       0               40
#         1              156
#         2               12
#         3                6
#         4                2
# 2       0              168
#         1               16
# 3       0              479
#         1                8
#         2                4
# Name: count, dtype: int64
#
# Deck
# A        15
# B        47
# C        59
# D        33
# E        32
# F        13
# G         4
# M       687
# T         1
# Name: count, dtype: int64
#
# Cabin_Location_s
# no_cabin_info         687
# no_cabin_number         4
# port                  108
# port_and_starboard      2
# starboard              90
# Name: count, dtype: int64

# %% [markdown]
# ##### Age

# %% [markdown]
# * Dropping rows with missing age is clearly avoided given the large number of missing values relative to the total samples in the data set plus the availability of surrounding data to inform a calculated imputation strategy.
# * Imputing the missing values with the mean/median age (29.7, 28 respectively) or some missing indicator (e.g. -1) is inferior to researching correlation strength between Age and the following features and taking the median age of each correlated group.
# * The following correlation strengths were identified (direction ignored given label encoding order undefined):
#     * **Pclass (0.42):** Moderate correlation
#     * **Title (0.32):** Moderate correlation
# * Given the above, Age will be imputed with the **median age found for each group of passengers split by Pclass and Title.**

# %%
# Determine correlation strength between Age and adjacent features
le = LabelEncoder()
df_corr = train_df[['Age', 'Sex', 'Pclass', 'Name']].copy()
df_corr['Sex_encoded'] = le.fit_transform(df_corr['Sex'])
df_corr['Title'] = df_corr['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False) + '.'
df_corr['Title_encoded'] = le.fit_transform(df_corr['Title'])
corr = df_corr[['Age', 'Sex_encoded', 'Pclass', 'Title_encoded']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr.loc[['Age']], annot=True, fmt=".2f", cmap='coolwarm', center=0, square=True)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_corr, x="Title", y="Age", hue="Pclass")
plt.title("Median Age by Title differs per Pclass")
plt.show()

# %%
def impute_age(df):
    """
    Imputes missing values in the "Age" column of the specified DataFrame with the median age
    of the data grouped by "Pclass" and Title (extracted from "Name")

    Adds "Title" column to the DataFrame as well.

    Args:
        df (DataFrame): Data set to impute (either training or test data set)

    Returns:
        Nothing
    """

    # First attempt to impute by Pclass X Title
    df['Title'] = df['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False) + '.'
    pclass_title_age_median_map = df.groupby(['Pclass', 'Title'])['Age'].median()
    def impute_age_by_pclass_title(row):
        if pd.notna(row['Age']):
            return row['Age']
        return pclass_title_age_median_map.loc[row['Pclass'], row['Title']]
    df['Age'] = df.apply(impute_age_by_pclass_title, axis=1)

    # In the scenario where all ages for a given title are missing, impute with median age for Sex
    sex_age_median_map = df.groupby(['Sex'])['Age'].median()
    def impute_age_by_sex(row):
        if pd.notna(row['Age']):
            return row['Age']
        return sex_age_median_map.loc[row['Sex']]
    df['Age'] = df.apply(impute_age_by_sex, axis=1)

impute_age(prepared_train_df)
impute_age(prepared_test_df)

# %% [markdown]
# ##### Fare

# %% [markdown]
# * We'll set missing Fare values to the median Fare of passengers from the same class and embarkation point

# %%
sns.boxplot(data=train_df, x="Pclass", y="Fare", hue="Embarked")
plt.show()

# %%
def impute_fare(df):
    """
    Imputes missing values in the "Fare" column of the specified DataFrame with the median Fare
    of passengers with the same Pclass and Embarked 

    Args:
        df (DataFrame): Data set to impute (either training or test data set)

    Returns:
        Nothing
    """
    df['Fare'] = df['Fare'].fillna(df.groupby(['Pclass', 'Embarked'])['Fare'].transform('median'))

impute_fare(prepared_train_df)
impute_fare(prepared_test_df)

# %%
# Confirm no more missing values
print(f"Missing Training Data Values:\n{prepared_train_df.isnull().sum().loc[lambda x: x > 0]}")
print(f"\nMissing Test Data Values:\n{prepared_test_df.isnull().sum().loc[lambda x: x > 0]}")
# Out:
# Missing Training Data Values:
# Series([], dtype: int64)
#
# Missing Test Data Values:
# Series([], dtype: int64)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def plot_vars(plot_df):

    # Identify discrete and continuous columns
    discrete_vars = [col for col in plot_df.columns 
                     if plot_df[col].dtype in ['int64', 'int32', 'object', 'category'] 
                     and plot_df[col].nunique() <= 20]
    
    continuous_vars = [col for col in plot_df.columns 
                       if (plot_df[col].dtype in ['float64', 'float32'] 
                           or (plot_df[col].dtype in ['int64', 'int32'] and plot_df[col].nunique() > 20))]
    
    # Combine for plotting
    all_vars = discrete_vars + continuous_vars

    n_cols = 3
    n_rows = int(np.ceil(len(all_vars) / n_cols))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3 * n_rows))
    
    # Flatten axes for easy indexing
    axes = axes.flatten()
    
    for i, col in enumerate(all_vars):
        if col in discrete_vars:
            sns.histplot(plot_df[col], ax=axes[i], discrete=True, shrink=0.8)
        else:
            sns.histplot(plot_df[col], ax=axes[i], kde=True, bins=30)
        
        axes[i].set_title(col)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('Count')
    
    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.show()

# %%
# Plot base dataset
plot_vars(prepared_train_df)

# %% [markdown]
# **Note:** `Name` and `Ticket` are not plotted above but will be analyzed below.  `PassengerId` will be ignored given its uniform distribution/definition.

# %% [markdown]
# #### Individual Features x Target

# %% [markdown]
# * The relationship between each feature and the target class `Survived` is analyzed below.
# * The relationship between combinations of features and the target class is analyzed in the subsequent subsection titled "[Composite Features x Target](#Composite-Features-x-Target)".

# %% [markdown]
# ##### Pclass

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Pclass", hue="Survived")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Pclass")
    .agg(Survival_Rate=('Survived', 'mean'), Count=('Survived', 'size'))
    .reset_index()
    .sort_values(by="Survival_Rate", ascending=False)
)
survival_df
# Out:
#    Pclass  Survival_Rate  Count
# 0       1       0.629630    216
# 1       2       0.472826    184
# 2       3       0.242363    491

# %% [markdown]
# * 1st class had highest survival rate (62%)
# * 2nd class had marginal survival rate (47%)
# * 3rd class had lowest survival rate (24%)
# * Non-linear relationship, high-sample size per class, clear threshold split points for trees
# * **Feature Engineering Plan:** No changes, input into model as-is

# %% [markdown]
# ##### Sex

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Sex", hue="Survived")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Sex")
    .agg(Survival_Rate=('Survived', 'mean'), Count=('Survived', 'size'))
    .reset_index()
    .sort_values(by="Survival_Rate", ascending=False)
)
survival_df
# Out:
#       Sex  Survival_Rate  Count
# 0  female       0.742038    314
# 1    male       0.188908    577

# %% [markdown]
# * Most females survived (74.2%), consistent with "women and children first" evacuation protocol
# * Vast majority of males perished (18.8%)
# * Non-linear relationship, high-sample size per class, clear threshold split points for trees
# * **Feature Engineering Plan:** No changes, input into model as-is

# %% [markdown]
# ##### SibSp

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="SibSp", hue="Survived")
plt.title("All SibSp Values")
plt.show()
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df[prepared_train_df['SibSp'] > 1], x="SibSp", hue="Survived")
plt.title("SibSp > 1")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("SibSp")
    .agg(Survival_Rate=('Survived', 'mean'), Count=('Survived', 'size'))
    .reset_index()
    .sort_values(by="SibSp", ascending=True)
)
survival_df
# Out:
#    SibSp  Survival_Rate  Count
# 0      0       0.345395    608
# 1      1       0.535885    209
# 2      2       0.464286     28
# 3      3       0.250000     16
# 4      4       0.166667     18
# 5      5       0.000000      5
# 6      8       0.000000      7

# %% [markdown]
# * Passengers with no siblings or spouses had a lower survival rate (34.5%) than those with 1 or 2 sibling/spouses (53.5& and 46.4%, respectively)
# * Survival rate decreased as number of siblings/spouses increased from 3 to 4 (25%, 16.7%)
# * Passengers with 5 or more sibling/spouses did not survive
# * Non-Linear relationship: Survival rate increases from 0->1 and then decreases from 1->8
# * Low sample sizes for `SibSp >= 2`
#     * Samples with Sibsp=>5 and =8 presumably came from the same family => Potentially rare case, risks overfitting
# * **Feature Engineering Plan:** Review sample sizes after combining with `Parch` (also a family quantifier) and bin low sample sizes

# %% [markdown]
# ##### Parch

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Parch", hue="Survived")
plt.show()
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df[prepared_train_df['Parch'] > 2], x="Parch", hue="Survived")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Parch")
    .agg(Survival_Rate=('Survived', 'mean'), Count=('Survived', 'size'))
    .reset_index()
    .sort_values(by="Parch", ascending=True)
)
survival_df
# Out:
#    Parch  Survival_Rate  Count
# 0      0       0.343658    678
# 1      1       0.550847    118
# 2      2       0.500000     80
# 3      3       0.600000      5
# 4      4       0.000000      4
# 5      5       0.200000      5
# 6      6       0.000000      1

# %% [markdown]
# * Passengers with no parents or children had lower survival rate (34.3%) to those with 1-3 parents/children
# * Survival rate increased to 60% from 1 to 3, and then drops sharply to 0 from 4-6
# * Non-Linear relationship: Survival rate increases from 0->1 and then decreases from 1->2,5.
# * Low sample sizes for `Parch >= 3`
# * **Feature Engineering Plan:** Review sample sizes after combining with `SibSp` (also a family quantifier) and bin low sample sizes

# %% [markdown]
# ##### Embarked_

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Embarked", hue="Survived")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Embarked")
    .agg(Survival_Rate=('Survived', 'mean'), Count=('Survived', 'size'))
    .reset_index()
    .sort_values(by="Survival_Rate", ascending=False)
)
survival_df
# Out:
#   Embarked  Survival_Rate  Count
# 0        C       0.553571    168
# 1        Q       0.389610     77
# 2        S       0.339009    646

# %% [markdown]
# * Most people from Cherbourg survived (55.5%)
# * Most people embarked from Southamption, which had the lowest survival rate (33.9%)
# * Most people from Queensland perished, had 2nd lowest survival rate (39.0%)
# * Clear survival threshold point by splitting on `Embarked == 'C'`
# * High sample size for `C` and `S` classes, moderate sample size for `Q`
# * **Feature Engineering Plan:** Feed into model as-is

# %% [markdown]
# ##### HasCabin

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="HasCabin", hue="Survived")
plt.xticks([0, 1], ["0", "1"])
plt.show()

survival_df = (
    prepared_train_df
    .groupby("HasCabin")
    .agg(Survival_Rate=('Survived', 'mean'), 
         Count=('Survived', 'size'),
        Pclass_1_Count=('Pclass', lambda x: (x == 1).sum()),
        Pclass_2_Count=('Pclass', lambda x: (x == 2).sum()),
        Pclass_3_Count=('Pclass', lambda x: (x == 3).sum())
        )
    .reset_index()
    .sort_values(by="Survival_Rate", ascending=False)
)
survival_df
# Out:
#    HasCabin  Survival_Rate  Count  Pclass_1_Count  Pclass_2_Count  \
# 1         1       0.666667    204             176              16
# 0         0       0.299854    687              40             168
#
#    Pclass_3_Count
# 1              12
# 0             479

# %% [markdown]
# * Clear survival threshold split between those with a cabin number (67%) and those without one (30%)
# * Majority of passengers with a cabin number were 1st class, aligning having a cabin number with social-economic status and higher survival rate
# * Not having a cabin number is also associated with lower class and survival rate
# * **Feature Engineering Plan:** Input as-is

# %% [markdown]
# ##### Cabin_count

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Cabin_count", hue="Survived")
plt.title("All Cabin_count Values")
plt.show()
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df[prepared_train_df['Cabin_count'] != 0], x="Cabin_count", hue="Survived")
plt.title("Cabin_count > 0")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Cabin_count", observed=True)
    .agg(Survival_Rate=('Survived', 'mean'), 
         Count=('Survived', 'size'),
        Pclass_1_Count=('Pclass', lambda x: (x == 1).sum()),
        Pclass_2_Count=('Pclass', lambda x: (x == 2).sum()),
        Pclass_3_Count=('Pclass', lambda x: (x == 3).sum())
        )
    .reset_index()
    .sort_values(by="Cabin_count", ascending=True)
)
survival_df
# Out:
#   Cabin_count  Survival_Rate  Count  Pclass_1_Count  Pclass_2_Count  \
# 0           0       0.299854    687              40             168
# 1           1       0.677778    180             156              16
# 2           2       0.562500     16              12               0
# 3           3       0.500000      6               6               0
# 4           4       1.000000      2               2               0
#
#    Pclass_3_Count
# 0             479
# 1               8
# 2               4
# 3               0
# 4               0

# %% [markdown]
# * Those listing more than one cabin on their ticket had higher survival rates than those listing only one
# * Those listing more than one cabin were mainly 1st class passengers
# * Signal behavior is similar to Parch/Sibsp (i.e. a "family size" indicator)
# * Low sample size for Cabin_count >= 2
# * **Feature Engineering Plan:**  Bin `Cabin_count` into `1`, and `2+` bins

# %% [markdown]
# ##### Cabin_Location_s

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Cabin_Location_s", hue="Survived")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Cabin_Location_s", observed=True)
    .agg(Survival_Rate=('Survived', 'mean'), 
         Count=('Survived', 'size'),
         Pclass_1_Count=('Pclass', lambda x: (x == 1).sum()),
         Pclass_2_Count=('Pclass', lambda x: (x == 2).sum()),
         Pclass_3_Count=('Pclass', lambda x: (x == 3).sum())
        )
    .reset_index()
    .sort_values(by="Count", ascending=False)
)
survival_df
# Out:
#      Cabin_Location_s  Survival_Rate  Count  Pclass_1_Count  Pclass_2_Count  \
# 0       no_cabin_info       0.299854    687              40             168
# 2                port       0.611111    108              96               6
# 4           starboard       0.733333     90              77               7
# 1     no_cabin_number       0.500000      4               1               3
# 3  port_and_starboard       1.000000      2               2               0
#
#    Pclass_3_Count
# 0             479
# 2               6
# 4               6
# 1               0
# 3               0

# %% [markdown]
# * Starboard-side cabins had higher success rate (73.3%), consistent with historical accounts of Officer Murdoch following protocol of "women and children first, and then men if space remained".
# * Post-side cabins lower success rate (61%) consistent with historical accounts of Officer Lightoller only allowing women (even at the expense of leaving boat seats empty!) and children and declining most men.
# * Missing cabin info had significantly lower success rate (30%) and was mostly comprised ofr 2nd and 3rd class passengers, suggesting missing cabin info correlated with passenger status
# * High sample sizes for no_cabin_info, port, and starboard; very low sample size for port_and_starboard class
# * **Feature Engineering Plan:**  Input as-is but rename `port_and_starboard` to `port_and_starboard_rare` to clarify this was a rare sample occurrence that will likely introduce overfitting if utilized by model (e.g. appears in feature_importances_)

# %% [markdown]
# ##### Deck

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df, x="Deck", hue="Survived")
plt.title("All Deck Values")
plt.show()
sns.countplot(data=prepared_train_df[prepared_train_df['Deck'] != 'M'], x="Deck", hue="Survived")
plt.title("Deck != M")
plt.show()

survival_df = (
    prepared_train_df
    .groupby("Deck", observed=True)
    .agg(
        Survival_Rate=('Survived', 'mean'),
        Count=('Survived', 'size'),
        Pclass_1_Count=('Pclass', lambda x: (x == 1).sum()),
        Pclass_2_Count=('Pclass', lambda x: (x == 2).sum()),
        Pclass_3_Count=('Pclass', lambda x: (x == 3).sum())
    )
    .reset_index()
    .sort_values(by="Deck", ascending=True)
)
survival_df
# Out:
#   Deck  Survival_Rate  Count  Pclass_1_Count  Pclass_2_Count  Pclass_3_Count
# 0    A       0.466667     15              15               0               0
# 1    B       0.744681     47              47               0               0
# 2    C       0.593220     59              59               0               0
# 3    D       0.757576     33              29               4               0
# 4    E       0.750000     32              25               4               3
# 5    F       0.615385     13               0               8               5
# 6    G       0.500000      4               0               0               4
# 7    M       0.299854    687              40             168             479
# 8    T       0.000000      1               1               0               0

# %% [markdown]
# * Each deck had a different survival rate, some similar to others
# * Decks A-B-C exclusive to 1st Class
# * Decks D-E majority presided by 1st class with small samples of 2nd and 3rd class passengers; also had very similar survival rates, and highest amongst the decks (~75%)
# * Decks F-G only 2nd and 3rd class passengers and low sample sizes each
# * **Feature Engineering Plan:** Bin as follows to maximize generalizability to test set:
#     * Bin Decks A-B-C given exclusivity to Pclass=1
#     * Bin Decks D-E given similar class makeup and survival rates
#     * Bin Decks F-G given similar class makeup
#     * Keep Deck "M" separate to distinguish "missing-ness" and distinct low success rate (30.0%)
#     * Bin Deck T into an `Other` given very low sample size and different class makeup; note if this class is used by model it will be prone to overfitting

# %% [markdown]
# ##### Title

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=prepared_train_df.query("Title in ['Mr.', 'Mrs.', 'Miss.', 'Master.']"), x="Title", hue="Survived")
plt.title("Titles in (Mr., Mrs., Miss., Master.)")
plt.show()
plt.figure(figsize=(12,3))
sns.countplot(data=prepared_train_df.query("Title not in ['Mr.', 'Mrs.', 'Miss.', 'Master.']"), x="Title", hue="Survived")
plt.title("All other Titles")
plt.show()

survival_by_title_df = (
    prepared_train_df
    .groupby("Title")
    .agg(Survival_Rate=('Survived', 'mean'), 
         Count=('Survived', 'size'),
         Pclass_1_Count=('Pclass', lambda x: (x == 1).sum()),
         Pclass_2_Count=('Pclass', lambda x: (x == 2).sum()),
         Pclass_3_Count=('Pclass', lambda x: (x == 3).sum()))
    .reset_index()
    .sort_values(by="Count", ascending=False)
)
print(survival_by_title_df)

# Confirmation of age range for Master. title
print("\nConfirmation that 'Master.' Title ages reflect 'young boy': 0.42 - 12")
print(prepared_train_df.query("Title in ['Master.']")['Age'].describe())

# Confirmation Ms. title should be grouped with Miss. (unmarried) (assumming she would have traveled with spouse)
print("\nConfirmation Ms. title should be grouped with Miss. (unmarried)")
print(prepared_train_df.query("Title in ['Ms.']")[['Name', 'SibSp']])
# Out:
#         Title  Survival_Rate  Count  Pclass_1_Count  Pclass_2_Count  \
# 12        Mr.       0.156673    517             107              91
# 9       Miss.       0.697802    182              46              34
# 13       Mrs.       0.792000    125              42              41
# 8     Master.       0.575000     40               3               9
# 4         Dr.       0.428571      7               5               2
# 15       Rev.       0.000000      6               0               6
# 7      Major.       0.500000      2               2               0
# 1        Col.       0.500000      2               2               0
# 10      Mlle.       1.000000      2               2               0
# 11       Mme.       1.000000      1               1               0
# 14        Ms.       1.000000      1               0               1
# 0       Capt.       0.000000      1               1               0
# 6       Lady.       1.000000      1               1               0
# 5   Jonkheer.       0.000000      1               1               0
# 3        Don.       0.000000      1               1               0
# 2   Countess.       1.000000      1               1               0
# 16       Sir.       1.000000      1               1               0
#
#     Pclass_3_Count
# 12             319
# 9              102
# 13              42
# 8               28
# 4                0
# 15               0
# 7                0
# 1                0
# 10               0
# 11               0
# 14               0
# 0                0
# 6                0
# 5                0
# 3                0
# 2                0
# 16               0
#
# Confirmation that 'Master.' Title ages reflect 'young boy': 0.42 - 12
# count    40.000000
# mean      4.516750
# std       3.433651
# min       0.420000
# 25%       1.750000
# 50%       4.000000
# 75%       7.250000
# max      12.000000
# Name: Age, dtype: float64
#
# Confirmation Ms. title should be grouped with Miss. (unmarried)
#                           Name  SibSp
# 443  Reynaldo, Ms. Encarnacion      0

# %% [markdown]
# * Top 3 Titles (Mr., Miss., Mrs.) reasonably spread across passenger classes, with high sample sizes
# * "Master" title relatively low sample size, but doesn't warrant binning with surrounding Titles given its implication of age
# * **Feature Engineering Plan:** All other titles have very low sample counts, thus warranting binning to increase generalizability:
#     *  `Mme.` --> Bin with `Mrs.` as short for Madame, widely used by married women
#     *  `Mlle.` --> Bin with `Miss.` as short for Mademoiselle, used by young or unmarried women
#     *  `Ms.` --> Bin with `Miss.` based on EDA confirmation this passenger was unmarried
#     *  `Major`, `Col.`, `Capt.` --> `Military`
#     *  `Countess.`, `Lady.`, `Sir.`, `Don.`, `Jonkheer.` --> `Noble`
#     *  Leave `Dr.` and `Rev.` separate given distinct roles, survival rates (42% and 0%, repsectively) and marginally higher sample sizes

# %% [markdown]
# ##### Age_

# %%
sns.displot(data=prepared_train_df, x="Age", hue="Survived", kde=True, bins=range(0, 85, 5))
plt.show()

prepared_train_df['Age_bin'] = pd.cut(prepared_train_df['Age'], bins=range(0, 85, 5))
survival_by_Age_bin_df = (
    prepared_train_df
    .groupby("Age_bin", observed=True)
    .agg(
        Survival_Rate=('Survived', 'mean'),
        Count=('Survived', 'size')
    )
    .reset_index()
    .sort_values(by="Age_bin")
)
print(survival_by_Age_bin_df)

ax = sns.kdeplot(data=prepared_train_df, x="Age", label="Training Set")
sns.kdeplot(data=prepared_test_df, x="Age", ax=ax, label="Test Set")
plt.xticks(range(0, 85, 5))
ax.legend()
plt.show()
# Out:
#      Age_bin  Survival_Rate  Count
# 0     (0, 5]       0.687500     48
# 1    (5, 10]       0.350000     20
# 2   (10, 15]       0.578947     19
# 3   (15, 20]       0.403101    129
# 4   (20, 25]       0.354839    124
# 5   (25, 30]       0.251256    199
# 6   (30, 35]       0.462264    106
# 7   (35, 40]       0.379310     87
# 8   (40, 45]       0.454545     55
# 9   (45, 50]       0.400000     40
# 10  (50, 55]       0.416667     24
# 11  (55, 60]       0.388889     18
# 12  (60, 65]       0.285714     14
# 13  (65, 70]       0.000000      3
# 14  (70, 75]       0.000000      4
# 15  (75, 80]       1.000000      1

# %% [markdown]
# * First Age bin (0,5] has the highest survival rate (68.7%), consistent with the "women and children first" evacauation policy
# * Survival rate decreases for Age Bins `(15,20]` through `(25-30]`, dropping to lowest bin rate of 25.1%
# * Low sample sizes for ages 40+, all have similar success rates w/ exception of `n=1 (75, 80]` passenger
# * **Distribution Shift between Training and Test Data Sets:** Training and test data sets different in (at least) 4 ways:
#     * Training set has more passengers in ~0-5 age range
#     * Training set has less passengers in ~20-30 age range
#     * Training set has more passengers in ~30-42 age range
#     * Training set peak age density is at ~25 years old ish; test set peak age is younger
# * **Feature Engineering Plan:** In addition to increasing generalizability for age learnings of the low sample sizes for ages `40+`, binning will also enable model to define learnings in terms of  age-ranges more likely to occur in test set.

# %% [markdown]
# ##### Age_Group

# %% [markdown]
# * Created domain-specific binned Age to assess survival relationship and capture the "Young Child" difference in survival rate found above
# * Young Child survival rate greatest of all groups; consistent with "women and children first" evac protocol
# * Survival rate amongst remaining groups does not appear significant, will investigate when exploring Composite Features x Target

# %%
def create_feature_Age_Group(train_df, test_df):
    """
    Add an ordered categorical 'AgeGroup' feature to train and test DataFrames using revised domain-specific bins
    designed to reduce KL divergence to ≤ 0.02.

    Age bins:
        - Young_Child: 0-5
        - Child:       6–17
        - Young_Adult: 18–29
        - Adult:       30–59
        - Senior:      60+

    Args:
        train_df (pd.DataFrame): Training dataset containing an 'Age' column.
        test_df (pd.DataFrame): Test dataset containing an 'Age' column.

    Modifies:
        Adds an 'AgeGroup' column with ordered categorical values to both datasets.
    """
    bins = [0, 5, 17, 29, 59, np.inf]
    labels = ['Young_Child', 'Child', 'Young_Adult', 'Adult', 'Senior']
    age_cat_type = pd.CategoricalDtype(categories=labels, ordered=True)

    for df in [train_df, test_df]:
        df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels)
        df['Age_Group'] = df['Age_Group'].astype(age_cat_type)


create_feature_Age_Group(prepared_train_df, prepared_test_df)

# %%
sns.displot(data=prepared_train_df, x="Age_Group", hue="Survived", kde=True, bins=range(0, 85, 5))
plt.show()

survival_by_Age_Group_bin_df = (
    prepared_train_df
    .groupby("Age_Group", observed=True)
    .agg(
        Survival_Rate=('Survived', 'mean'),
        Count=('Survived', 'size')
    )
    .reset_index()
    .sort_values(by="Age_Group")
)
print(survival_by_Age_Group_bin_df)
# Out:
#      Age_Group  Survival_Rate  Count
# 0  Young_Child       0.687500     48
# 1        Child       0.434783     69
# 2  Young_Adult       0.310606    396
# 3        Adult       0.423295    352
# 4       Senior       0.269231     26

# %% [markdown]
# ##### Fare_

# %%
print("Key Detail: Fare is shared amongst passengers sharing same ticket number!")
print("Sample subset of duplicate Ticket/Fare combinations in the data:")
fare_duplicates = prepared_train_df.groupby("Ticket")[['Ticket', "Fare"]].value_counts().head(10).reset_index()
fare_duplicates.columns = ["Ticket Number", "Fare", "Number of Duplicates"]
print(fare_duplicates)

sns.displot(data=prepared_train_df, x="Fare", hue="Survived", kde=True)
plt.title("Fare (raw) Distribution")
plt.show()
prepared_train_df["Fare_log"] = np.log1p(prepared_train_df["Fare"])
prepared_test_df["Fare_log"] = np.log1p(prepared_test_df["Fare"])
sns.displot(data=prepared_train_df, x="Fare_log", hue="Survived", kde=True)
plt.title("Fare (log) Distribution")
plt.show()

prepared_train_df['Fare_log_bin'] = pd.cut(prepared_train_df['Fare_log'], bins=np.arange(0, 8, 0.5))
prepared_test_df['Fare_log_bin'] = pd.cut(prepared_test_df['Fare_log'], bins=np.arange(0, 8, 0.5))
survival_by_Fare_log_bin_df = (
    prepared_train_df
    .groupby("Fare_log_bin", observed=True)
    .agg(
        Survival_Rate=('Survived', 'mean'),
        Count=('Survived', 'size')
    )
    .reset_index()
    .sort_values(by="Fare_log_bin")
)
print(survival_by_Fare_log_bin_df)

# prepared_test_df["Fare_log"] = np.log1p(prepared_test_df["Fare"])
# ax = sns.kdeplot(data=prepared_train_df, x="Fare_log", label="Training Set")
# sns.kdeplot(data=prepared_test_df, x="Fare_log", ax=ax, label="Test Set")
# plt.xticks(np.arange(0, 8, 0.5))
# ax.legend()
# plt.show()
# Out:
# Key Detail: Fare is shared amongst passengers sharing same ticket number!
# Sample subset of duplicate Ticket/Fare combinations in the data:
#   Ticket Number     Fare  Number of Duplicates
# 0        110152  86.5000                     3
# 1        110413  79.6500                     3
# 2        110465  52.0000                     2
# 3        110564  26.5500                     1
# 4        110813  75.2500                     1
# 5        111240  33.5000                     1
# 6        111320  38.5000                     1
# 7        111361  57.9792                     2
# 8        111369  30.0000                     1
# 9        111426  26.5500                     1
#   Fare_log_bin  Survival_Rate  Count
# 0   (1.5, 2.0]       0.000000      3
# 1   (2.0, 2.5]       0.223496    349
# 2   (2.5, 3.0]       0.414286    140
# 3   (3.0, 3.5]       0.456647    173
# 4   (3.5, 4.0]       0.400000     70
# 5   (4.0, 4.5]       0.641026     78
# 6   (4.5, 5.0]       0.823529     34
# 7   (5.0, 5.5]       0.666667     18
# 8   (5.5, 6.0]       0.625000      8
# 9   (6.0, 6.5]       1.000000      3

# %%
sns.boxplot(data=prepared_train_df, x="Pclass", y="Fare")
plt.title("Fares overlap across Pclass")
plt.show()

# %% [markdown]
# * **Important:** Fare value reflects amount **paid for all passengers sharing the same ticket** (see "Ticket" EDA for more info on sharing).  Here, fare refers to "aggregated fare".
# * Aggregated Fare skewed heavily to right; log transformation performed to create and plot new `Fare_log` feature for analysis
# * Low sample sizes observed for `(1.5, 2.0]` bin and bins `>= (4.5, 5.0]`
# * Fares also **overlap across multiple classes**
# * **Feature Engineering Plan:**
#     * First, we should calculate a "Fare per person" to account for scenarios where listed fare is total paid amongst passengers sharing same ticket number.
#     * Compare performance of training with raw and logged versions of "Fare per person" to assess whether compression of skew improves accuracy (logging not absolutely necessary for tree (threshold-based) models)
#     * Bin the low sample size "Fare per person" ranges to increase generalizability
#     * Combine with `Pclass` if needed to capture more context around `Fare` bins and prevent generalization errors around `Fare`-only patterns

# %% [markdown]
# ##### Summary of Single Feature Relationship with Target

# %% [markdown]
# | Feature | Summary of Relationship with Target | Domain Implication / Further EDA |
# | ------- | ----------------------------------- | -------------------|
# | **Pclass** | P1: Most likely to survive, 63%; P2: Near equal, 47%, P3: Less likely to survive, 24% | Priority given to higher class, more affluent |
# | **Sex** | male: Less likely, 19%, female: More likely, 74% | Priority given to women, consistent with "women and children first" evac  |
# | **SibSp** | 0: Less likely, 34.5%, 1: More likely, 53.6%, 2: Near equal, 46%, 3: low > 16->0% | Larger families potentially more difficult to evacuate from cabins, or perhaps larger families tended to be in lower ticket classes less likely to survive |
# | **Parch** | Similar to Sibsp for 0->2 & 5->6; 3: higher survival rate (though small sample size, could be all same family= rare case) | See `SibSp` notes |
# | **Embarked** | C: Had marginally higher success rate, 55%, Q: 39%, S: 34% | C may have most high class ticket holders; Q/S predominately lower class (check in next section) |
# | **HasCabin** | Having a Cabin number: 66%, Not Having: 30% | Having a cabin number may be associated with high class or higher-higher class, check in next section |
# | **Cabin_count** | Those with more than one cabin listed had success rates 50% and higher | May represent elite families and may be all one family |
# | **Cabin_Location_s** | Those with cabin numbers listed on starboard side had 12% higher survival | Consistent with historical reports of starboard evac procedure being more lenient than port-side evac |
# | **Deck** | _Of those with cabin numbers,_ Decks B, D, and E had highest survival rates (~75%) | Decks may have had closer proximity to lifeboats and/or disproportionate number of female and/or P1 ticket holders |
# | **Title** | "Mr." title had lowest survival, 15.6%; Miss./Mrs. had highest survival, 69.8%/79.2% respectively; Master. had 57.5%, marginally higher survival | Title implies both Sex and Age; High female title rates aligns with "women and children first", however marginally lower rates for children does not align (perhaps most children were lower class?) |
# | **Age**  | Only for ages `(0,5]` was survival high, 68.8%; `(10,15]` had second highest survival, 57.9%; all other bins had survival between 28.6% and 46% (with exception of sole surviving `(75,80]` passenger)) | The high survival of `(0,5]` aligns with "women and children first" evac protocol; the remaining similar rates amongst the bins suggests that age was not a strong factor in influencing age; Created **Age_Group** to explore significance of Survival relationship in Composite Features x Target section |
# | **Fare**/**Fare_log** | Log1p(Fare) values higher than 4.0 had the highest survival rates ranging from 64% to 100% | Higher fares an indication of social economic class |

# %% [markdown]
# #### Composite Features x Target

# %%
# Define functions for printing and plotting data
def analyze_two_composite_features_x_survived(feature_1, feature_2, plot_heatmap=False):
    # Chi-squared contingency table
    contingency = pd.crosstab(
        index=prepared_train_df[feature_1],
        columns=[prepared_train_df[feature_2], prepared_train_df['Survived']]
    )

    chi2, p, dof, expected = chi2_contingency(contingency)

    print(f"Chi-Square Test: Is '{feature_1}' survival affected by '{feature_2}'?")
    print(f"Chi² Statistic: {chi2:.4f}")
    print(f"Degrees of Freedom: {dof}")
    print(f"P-value: {p:.6f}")
    print("Conclusion:", "Dependent (Significant)" if p < 0.05 else "Independent (Not Significant)")

    # Display sample sizes by group (feature_1 x feature_2)
    print("\nCounts of each combination of feature_1 x feature_2:")
    combo_counts = (
        prepared_train_df
        .groupby([feature_1, feature_2])
        .size()
        .reset_index(name='n')
        .sort_values(feature_1, ascending=True)
    )
    print(combo_counts.to_string(index=False))

    if plot_heatmap:
        heatmap_data = prepared_train_df.groupby([feature_1, feature_2])['Survived'].mean().unstack()
        
        # Plot heatmap
        sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=custom_cmap, cbar_kws={'label': 'Mean Survival Rate'})
        plt.title(f'Survival Rate by {feature_1} and {feature_2}')
        plt.ylabel(feature_1)
        plt.xlabel(feature_2)
        plt.tight_layout()
        plt.show()
    
def analyze_three_composite_features_x_survived(feature_1, feature_2, feature_3, plot_heatmap=False):
    def print_chi_2_test(feature_1, feature_2, feature_3):
        # Track p-values for each feature_1 × feature_2 group
        results = []
        
        # Loop through each feature_1 × feature_2 subgroup
        for (feature_1_val, feature_2_val), group in prepared_train_df.groupby([feature_1, feature_2], observed=True):
            # Create contingency table of feature_3 vs Survived
            contingency = pd.crosstab(group[feature_3], group['Survived'])
        
            # Only test if there's more than 1 unique feature_3 value and both 0 and 1 are present in Survived
            chi2, p, dof, expected = chi2_contingency(contingency)
            results.append({
                feature_1: feature_1_val,
                feature_2: feature_2_val,
                'p_value': p,
                'significant': p < 0.05
            })
        
        # Create summary DataFrame
        results_df = pd.DataFrame(results)
        print(f"Stratified Chi² Tests: Does {feature_3} affect survival within each {feature_1} x {feature_2} group?")
        print(results_df)
        
    def print_counts_table(feature_1, feature_2, feature_3):
        # Add Dataset column
        prepared_train_df['Dataset'] = 'Train'
        prepared_test_df['Dataset'] = 'Test'
        
        # Combine for counts
        combined = pd.concat([
            prepared_train_df[[feature_1, feature_2, feature_3, 'Dataset']],
            prepared_test_df[[feature_1, feature_2, feature_3, 'Dataset']]
        ])
        
        # Count occurrences
        count_df = (
            combined.groupby([feature_1, feature_2, feature_3, 'Dataset'], observed=True)
            .size()
            .reset_index(name='Count')
        )
        
        # Pivot Train vs Test counts
        pivot_counts = count_df.pivot_table(index=[feature_3, feature_1, feature_2],
                                            observed=True,
                                            columns='Dataset',
                                            values='Count',
                                            fill_value=0).reset_index()
        
        # Compute Train survival rates
        survival_df = (
            prepared_train_df
            .dropna(subset=[feature_3, feature_1, feature_2, 'Survived'])
            .groupby([feature_3, feature_1, feature_2], observed=True)['Survived']
            .mean()
            .reset_index()
            .rename(columns={'Survived': 'Train_Survival_Rate'})
        )
        
        # Merge counts with survival rate
        final_df = pd.merge(pivot_counts, survival_df, on=[feature_3,feature_1, feature_2], how='left')
        final_df.sort_values(by=[feature_3, feature_1, feature_2, 'Train'], ascending=True, inplace=True)
        print(f"\nCounts of {feature_1} x {feature_2} x {feature_3}:")
        print(final_df)
        print()

    def plot_heatmaps(feature_1, feature_2, feature_3):
        grouped = prepared_train_df.groupby([feature_3, feature_1, feature_2], observed=True)['Survived'].mean().reset_index()
    
        # Plot heatmaps by feature_3 (e.g., Deck or Embarked)
        feature_3_values = grouped[feature_3].unique()
        n = len(feature_3_values)
        cols = 3
        rows = math.ceil(n / cols)
    
        fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 5 * rows), sharey=True)
        axes = axes.flatten()  # Flatten for easy indexing
    
        for i, feature_3_val in enumerate(feature_3_values):
            subset = grouped[grouped[feature_3] == feature_3_val]
            pivot = subset.pivot(index=feature_1, columns=feature_2, values='Survived')
            sns.heatmap(pivot, annot=True, fmt=".2f", cmap=custom_cmap, ax=axes[i], cbar=(i == n - 1))
            axes[i].set_title(f"{feature_3} = {feature_3_val}")
            axes[i].set_xlabel(feature_2)
            axes[i].set_ylabel(feature_1)
    
        # Hide unused subplots (if any)
        for j in range(i + 1, len(axes)):
            axes[j].axis('off')
    
        plt.tight_layout()
        plt.show()

    print_chi_2_test(feature_1, feature_2, feature_3)
    print_counts_table(feature_1, feature_2, feature_3)
    if plot_heatmap:
        plot_heatmaps(feature_1, feature_2, feature_3)

# %% [markdown]
# ##### Pclass x Sex

# %% [markdown]
# * **`Pclass` survival affected by `Sex` (statistically-significant)**
# * **Sample sizes are large enough to one-hot encode `Pclass_Sex` into 6 "base" features**
# * **Layer in smoothed features where P(Pclass x Sex) < 0.5:**
#     * `P1_male_smoothed` (p=0.37)
#     * `P2_male_smoothed` (p=0.16)
#     * `P3_male_smoothed` (p=0.14)
# * P1 survival rate is _not_ consistently high across sexes
# * P1_female = 0.97, P1_male = 0.37
# * Split also revealed P2_female = 0.92, P2_male = 0.16 => P2 females also survived at high rate
# * Female survival rate is also _not_ consistently high
#     * P3 females survived at 50% rate
# * P1 Male survival rate above mean Male survival rate
# * P2/P3 Male survival rate similarly low

# %%
analyze_two_composite_features_x_survived('Pclass', 'Sex', True)
# Out:
# Chi-Square Test: Is 'Pclass' survival affected by 'Sex'?
# Chi² Statistic: 129.7300
# Degrees of Freedom: 6
# P-value: 0.000000
# Conclusion: Dependent (Significant)
#
# Counts of each combination of feature_1 x feature_2:
#  Pclass    Sex   n
#       1 female  94
#       1   male 122
#       2 female  76
#       2   male 108
#       3 female 144
#       3   male 347

# %% [markdown]
# ##### Pclass x Sex x SibSp

# %% [markdown]
# * **No `Pclass x Sex` Survival Rates have a significant association with `SibSp` (p < 0.05)**

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Parch')
# Out:
# Stratified Chi² Tests: Does Parch affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  0.025151         True
# 1       1    male  0.352355        False
# 2       2  female  0.595560        False
# 3       2    male  0.000146         True
# 4       3  female  0.127758        False
# 5       3    male  0.356392        False
#
# Counts of Pclass x Sex x Parch:
#     Parch  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0       0       1  female   33.0   64.0             0.984375
# 1       0       1    male   46.0   99.0             0.363636
# 2       0       2  female   16.0   45.0             0.888889
# 3       0       2    male   56.0   89.0             0.089888
# 4       0       3  female   50.0   85.0             0.588235
# 5       0       3    male  123.0  296.0             0.121622
# 6       1       1  female   12.0   17.0             1.000000
# 7       1       1    male    7.0   14.0             0.285714
# 8       1       2  female    6.0   18.0             0.944444
# 9       1       2    male    5.0   14.0             0.500000
# 10      1       3  female   10.0   25.0             0.480000
# 11      1       3    male   12.0   30.0             0.266667
# 12      2       1  female    3.0   13.0             0.846154
# 13      2       1    male    3.0    8.0             0.625000
# 14      2       2  female    7.0   11.0             1.000000
# 15      2       2    male    2.0    5.0             0.400000
# 16      2       3  female   10.0   25.0             0.320000
# 17      2       3    male    8.0   18.0             0.166667
# 18      3       1  female    1.0    0.0                  NaN
# 19      3       1    male    1.0    0.0                  NaN
# 20      3       2  female    1.0    2.0             1.000000
# 21      3       3  female    0.0    2.0             0.500000
# 22      3       3    male    0.0    1.0             0.000000
# 23      4       1  female    1.0    0.0                  NaN
# 24      4       1    male    0.0    1.0             0.000000
# 25      4       3  female    1.0    2.0             0.000000
# 26      4       3    male    0.0    1.0             0.000000
# 27      5       3  female    0.0    4.0             0.250000
# 28      5       3    male    1.0    1.0             0.000000
# 29      6       3  female    0.0    1.0             0.000000
# 30      6       3    male    1.0    0.0                  NaN
# 31      9       3  female    1.0    0.0                  NaN
# 32      9       3    male    1.0    0.0                  NaN

# %% [markdown]
# ##### Pclass x Sex x Parch

# %% [markdown]
# * **P1 Female and P2 Male Survival Rates have a significant association with `Parch` (p < 0.05)**
# * **Given several subgroups have n < 50, do NOT one hot encode broad feature `Pclass_Sex_Parch`**
# * **Create smoothed features `P1_Female_Parch_smoothed` and `P2_Male_Parch_smoothed` to capture association**
# * P1 Female Survival Rates by `Parch`:
#     *  `0`: 98.4%, n = 64
#     *  `1`: 100%, n = 17
#     *  `2`: 84.6%, n = 13
# * P2 Male Survival Rates by `Parch`:
#     * `0`: 8.9%, n = 89
#     * `1`: 50%, n = 14
#     * `2`: 40%, <span style="color:red">**n = 5**</span> (exclude)

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Parch')
# Out:
# Stratified Chi² Tests: Does Parch affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  0.025151         True
# 1       1    male  0.352355        False
# 2       2  female  0.595560        False
# 3       2    male  0.000146         True
# 4       3  female  0.127758        False
# 5       3    male  0.356392        False
#
# Counts of Pclass x Sex x Parch:
#     Parch  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0       0       1  female   33.0   64.0             0.984375
# 1       0       1    male   46.0   99.0             0.363636
# 2       0       2  female   16.0   45.0             0.888889
# 3       0       2    male   56.0   89.0             0.089888
# 4       0       3  female   50.0   85.0             0.588235
# 5       0       3    male  123.0  296.0             0.121622
# 6       1       1  female   12.0   17.0             1.000000
# 7       1       1    male    7.0   14.0             0.285714
# 8       1       2  female    6.0   18.0             0.944444
# 9       1       2    male    5.0   14.0             0.500000
# 10      1       3  female   10.0   25.0             0.480000
# 11      1       3    male   12.0   30.0             0.266667
# 12      2       1  female    3.0   13.0             0.846154
# 13      2       1    male    3.0    8.0             0.625000
# 14      2       2  female    7.0   11.0             1.000000
# 15      2       2    male    2.0    5.0             0.400000
# 16      2       3  female   10.0   25.0             0.320000
# 17      2       3    male    8.0   18.0             0.166667
# 18      3       1  female    1.0    0.0                  NaN
# 19      3       1    male    1.0    0.0                  NaN
# 20      3       2  female    1.0    2.0             1.000000
# 21      3       3  female    0.0    2.0             0.500000
# 22      3       3    male    0.0    1.0             0.000000
# 23      4       1  female    1.0    0.0                  NaN
# 24      4       1    male    0.0    1.0             0.000000
# 25      4       3  female    1.0    2.0             0.000000
# 26      4       3    male    0.0    1.0             0.000000
# 27      5       3  female    0.0    4.0             0.250000
# 28      5       3    male    1.0    1.0             0.000000
# 29      6       3  female    0.0    1.0             0.000000
# 30      6       3    male    1.0    0.0                  NaN
# 31      9       3  female    1.0    0.0                  NaN
# 32      9       3    male    1.0    0.0                  NaN

# %% [markdown]
# ##### Pclass x Sex x Embarked

# %% [markdown]
# * **Survival rate for P3 Females is significantly associated with embarkation point (p < 0.05)**
# * **Given two subgroups have n < 50, do NOT one hot encode broad feature `Pclass_Sex_Embarked`**
# * **Create Smoothed Feature `P3_Female_Embarked` to capture association**
# * P3 Female Survival Rates by Embarkation point:
#     * `S` Southampton: 37.5%, n=88
#     * `Q` Queenstown: 72.7%, n=33
#     * `C` Cherbourg: 65.2%, n=23

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Embarked')
# Out:
# Stratified Chi² Tests: Does Embarked affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  0.885543        False
# 1       1    male  0.641582        False
# 2       2  female  0.645631        False
# 3       2    male  0.848234        False
# 4       3  female  0.000729         True
# 5       3    male  0.094459        False
#
# Counts of Pclass x Sex x Embarked:
#    Embarked  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0         C       1  female   28.0   43.0             0.976744
# 1         C       1    male   28.0   42.0             0.404762
# 2         C       2  female    4.0    7.0             1.000000
# 3         C       2    male    7.0   10.0             0.200000
# 4         C       3  female    8.0   23.0             0.652174
# 5         C       3    male   27.0   43.0             0.232558
# 6         Q       1  female    1.0    1.0             1.000000
# 7         Q       1    male    0.0    1.0             0.000000
# 8         Q       2  female    0.0    2.0             1.000000
# 9         Q       2    male    4.0    1.0             0.000000
# 10        Q       3  female   23.0   33.0             0.727273
# 11        Q       3    male   18.0   39.0             0.076923
# 12        S       1  female   21.0   50.0             0.960000
# 13        S       1    male   29.0   79.0             0.354430
# 14        S       2  female   26.0   67.0             0.910448
# 15        S       2    male   52.0   97.0             0.154639
# 16        S       3  female   41.0   88.0             0.375000
# 17        S       3    male  101.0  265.0             0.128302

# %% [markdown]
# ##### Pclass x Sex x HasCabin

# %% [markdown]
# * **P2 Male Survival Rate is significantly associated with `HasCabin` (p < 0.05)**
# * **Given all subgroups have n < 50, do NOT one hot encode broad feature `Pclass_Sex_HasCabin`**
# * **Create smoothed feature `P2_Male_HasCabin_smoothed` to capture association**
# * P2 Males Survival Rates:
#     * With Cabin Number: 66.7%, <span style="color:red">**n=6**</span>
#     * Without Cabin Number: 12.7%, n=102

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'HasCabin')
# Out:
# Stratified Chi² Tests: Does HasCabin affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  1.000000        False
# 1       1    male  0.117936        False
# 2       2  female  1.000000        False
# 3       2    male  0.003200         True
# 4       3  female  0.676657        False
# 5       3    male  0.408145        False
#
# Counts of Pclass x Sex x HasCabin:
#     HasCabin  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0          0       1  female   10.0   13.0             1.000000
# 1          0       1    male   17.0   27.0             0.222222
# 2          0       2  female   27.0   66.0             0.924242
# 3          0       2    male   59.0  102.0             0.127451
# 4          0       3  female   71.0  138.0             0.492754
# 5          0       3    male  143.0  341.0             0.131965
# 6          1       1  female   40.0   81.0             0.962963
# 7          1       1    male   40.0   95.0             0.410526
# 8          1       2  female    3.0   10.0             0.900000
# 9          1       2    male    4.0    6.0             0.666667
# 10         1       3  female    1.0    6.0             0.666667
# 11         1       3    male    3.0    6.0             0.333333

# %% [markdown]
# ##### Pclass x Sex x Cabin_count

# %% [markdown]
# * **P1 Female, P2 Male, and P3 Male Survival Rates are significantly associated with `Cabin_count` (p < 0.05)**
# * **Given all subgroups have n < 50, do NOT one hot encode broad feature `Pclass_Sex_Cabin_count`**
# * **Create smoothed feature `P1_Female_Cabin_count_smoothed`, `P2_Male_Cabin_count_smoothed`, and `P3_Male_Cabin_count_smoothed` to capture associations**
# * P1 Female Survival Rates by `Cabin_count`:
#     * `0`: 100%, n = 13
#     * `1`: 98.6%, n = 71
#     * `2`: 66.7%, <span style="color:red">**n = 6**</span>
#     * `3`: <span style="color:green">**100%**</span>, <span style="color:red">**n = 2**</span>
#     * `4`: <span style="color:green">**100%**</span>, <span style="color:red">**n = 2**</span>
# * P2 Male Survival Rates by `Cabin_count`:
#     * `0`: 12.7%, n = 102
#     * `1`: 66.7%, <span style="color:red">**n = 6**</span>
# * P3 Male Survival Rates by `Cabin_count`:
#     * `0`: 13.1.7%, n = 341
#     * `1`: 66.7%, <span style="color:red">**n = 3**</span>
#     * `2`: 0%, <span style="color:red">**n = 3**</span>

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Cabin_count')
# Out:
# Stratified Chi² Tests: Does Cabin_count affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  0.000810         True
# 1       1    male  0.146218        False
# 2       2  female  1.000000        False
# 3       2    male  0.003200         True
# 4       3  female  0.540915        False
# 5       3    male  0.020912         True
#
# Counts of Pclass x Sex x Cabin_count:
#    Cabin_count  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0            0       1  female   10.0   13.0             1.000000
# 1            0       1    male   17.0   27.0             0.222222
# 2            0       2  female   27.0   66.0             0.924242
# 3            0       2    male   59.0  102.0             0.127451
# 4            0       3  female   71.0  138.0             0.492754
# 5            0       3    male  143.0  341.0             0.131965
# 6            1       1  female   32.0   71.0             0.985915
# 7            1       1    male   34.0   85.0             0.400000
# 8            1       2  female    3.0   10.0             0.900000
# 9            1       2    male    4.0    6.0             0.666667
# 10           1       3  female    1.0    5.0             0.600000
# 11           1       3    male    0.0    3.0             0.666667
# 12           2       1  female    4.0    6.0             0.666667
# 13           2       1    male    3.0    6.0             0.666667
# 14           2       3  female    0.0    1.0             1.000000
# 15           2       3    male    3.0    3.0             0.000000
# 16           3       1  female    3.0    2.0             1.000000
# 17           3       1    male    1.0    4.0             0.250000
# 18           4       1  female    1.0    2.0             1.000000
# 19           4       1    male    2.0    0.0                  NaN

# %% [markdown]
# ##### Pclass x Sex x Cabin_Location_s

# %% [markdown]
# * **P2 Male Survival Rate is significantly associated with `Cabin_Location_s` (p < 0.05)**
# * **Given all subgroups have n < 50, do NOT one hot encode broad feature `Pclass_Sex_Cabin_Location_s`**
# * **Create smoothed feature `P2_Male_Cabin_Location_s_smoothed` to capture the association**
# * P2 Male Survival Rates by `Cabin_Location_s`:
#     * `no_cabin_info`: 12.6%, n = 102
#     * `no_cabin_number` : 0%, <span style="color:red">**n = 1**</span>
#     * `port`: 80.0%, <span style="color:red">**n = 5**</span>
#     * `port_and_starboard`: <span style="color:red">**n = 0**</span>
#     * `starboard`: <span style="color:red">**n = 0**</span>

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Cabin_Location_s')
# Out:
# Stratified Chi² Tests: Does Cabin_Location_s affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  0.760020        False
# 1       1    male  0.224981        False
# 2       2  female  0.882668        False
# 3       2    male  0.000269         True
# 4       3  female  0.362586        False
# 5       3    male  0.252414        False
#
# Counts of Pclass x Sex x Cabin_Location_s:
#       Cabin_Location_s  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0        no_cabin_info       1  female   10.0   13.0             1.000000
# 1        no_cabin_info       1    male   17.0   27.0             0.222222
# 2        no_cabin_info       2  female   27.0   66.0             0.924242
# 3        no_cabin_info       2    male   59.0  102.0             0.127451
# 4        no_cabin_info       3  female   71.0  138.0             0.492754
# 5        no_cabin_info       3    male  143.0  341.0             0.131965
# 6      no_cabin_number       1    male    0.0    1.0             0.000000
# 7      no_cabin_number       2  female    0.0    2.0             1.000000
# 8      no_cabin_number       2    male    2.0    1.0             0.000000
# 9                 port       1  female   17.0   37.0             0.945946
# 10                port       1    male   23.0   59.0             0.389831
# 11                port       2  female    2.0    1.0             1.000000
# 12                port       2    male    2.0    5.0             0.800000
# 13                port       3  female    1.0    4.0             0.500000
# 14                port       3    male    1.0    2.0             0.500000
# 15  port_and_starboard       1  female    1.0    2.0             1.000000
# 16  port_and_starboard       1    male    2.0    0.0                  NaN
# 17           starboard       1  female   22.0   42.0             0.976190
# 18           starboard       1    male   15.0   35.0             0.457143
# 19           starboard       2  female    1.0    7.0             0.857143
# 20           starboard       3  female    0.0    2.0             1.000000
# 21           starboard       3    male    2.0    4.0             0.250000

# %% [markdown]
# ##### Pclass x Sex x Deck

# %% [markdown]
# * **P2 Male and P3 Male Survival Rates are significantly associated with `Deck` (p < 0.05)**
# * **Create Smoothed Features `P2_Male_Deck_smoothed` and `P3_Male_Deck_smoothed` to capture n > 50 association**
# * **Don't model `D` or `F` associations due to <span style="color:red">low sample sizes (n < 50)</span>**
# * P2 Male Survival Rates by Deck:
#     * `D`: 50%, <span style="color:red">**n = 2**</span>
#     * `F`: 75%, <span style="color:red">**n = 4**</span>
#     * `M`: 12.7%, n = 102
# * P3 Male Survival Rates by Deck:
#     * `F`: 0%, <span style="color:red">**n = 4**</span>
#     * `M`: 13.2%, n = 341

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Deck')
# Out:
# Stratified Chi² Tests: Does Deck affect survival within each Pclass x Sex group?
#    Pclass     Sex   p_value  significant
# 0       1  female  0.174176        False
# 1       1    male  0.459345        False
# 2       2  female  0.545257        False
# 3       2    male  0.001466         True
# 4       3  female  0.566413        False
# 5       3    male  0.001214         True
#
# Counts of Pclass x Sex x Deck:
#    Deck  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0     A       1  female    3.0    1.0             1.000000
# 1     A       1    male    4.0   14.0             0.428571
# 2     B       1  female    9.0   27.0             1.000000
# 3     B       1    male    9.0   20.0             0.400000
# 4     C       1  female   19.0   27.0             0.888889
# 5     C       1    male   16.0   32.0             0.343750
# 6     D       1  female    5.0   16.0             1.000000
# 7     D       1    male    6.0   13.0             0.461538
# 8     D       2  female    0.0    2.0             1.000000
# 9     D       2    male    2.0    2.0             0.500000
# 10    E       1  female    4.0   10.0             1.000000
# 11    E       1    male    5.0   15.0             0.533333
# 12    E       2  female    0.0    4.0             0.750000
# 13    E       3  female    0.0    1.0             1.000000
# 14    E       3    male    0.0    2.0             1.000000
# 15    F       2  female    3.0    4.0             1.000000
# 16    F       2    male    2.0    4.0             0.750000
# 17    F       3  female    0.0    1.0             1.000000
# 18    F       3    male    3.0    4.0             0.000000
# 19    G       3  female    1.0    4.0             0.500000
# 20    M       1  female   10.0   13.0             1.000000
# 21    M       1    male   17.0   27.0             0.222222
# 22    M       2  female   27.0   66.0             0.924242
# 23    M       2    male   59.0  102.0             0.127451
# 24    M       3  female   71.0  138.0             0.492754
# 25    M       3    male  143.0  341.0             0.131965
# 26    T       1    male    0.0    1.0             0.000000

# %% [markdown]
# ##### Pclass x Sex x Title

# %% [markdown]
# * **P2 Male and P3 Male Survival Rates are significantly associated with Title (p < 0.05)**
# * **Given a subgroup has n < 50, do NOT one hot encode broad feature `Pclass_Sex_Title`**
# * **Create Smoothed `P2_Male_Title_smoothed`, `P3_Male_Title_smoothed`**
# * P2 Male Survival Rate by Title:
#     * `Master.`: <span style="color:green">**100%**</span>, <span style="color:red">**n = 9**</span>
#     * `Mr.`: 8.7%, n = 91
# * P3 Male Survival Rate by Title:
#     * `Master.`: 39.2%, n = 28
#     * `Mr.`: 11.3%, n = 319

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Title')
# Out:
# Stratified Chi² Tests: Does Title affect survival within each Pclass x Sex group?
#    Pclass     Sex       p_value  significant
# 0       1  female  9.980026e-01        False
# 1       1    male  3.070856e-01        False
# 2       2  female  7.904032e-01        False
# 3       2    male  1.847230e-11         True
# 4       3  female  1.000000e+00        False
# 5       3    male  1.118163e-04         True
#
# Counts of Pclass x Sex x Title:
#         Title  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0       Capt.       1    male    0.0    1.0             0.000000
# 1        Col.       1    male    2.0    2.0             0.500000
# 2   Countess.       1  female    0.0    1.0             1.000000
# 3        Don.       1    male    0.0    1.0             0.000000
# 4       Dona.       1  female    1.0    0.0                  NaN
# 5         Dr.       1  female    0.0    1.0             1.000000
# 6         Dr.       1    male    1.0    4.0             0.500000
# 7         Dr.       2    male    0.0    2.0             0.000000
# 8   Jonkheer.       1    male    0.0    1.0             0.000000
# 9       Lady.       1  female    0.0    1.0             1.000000
# 10     Major.       1    male    0.0    2.0             0.500000
# 11    Master.       1    male    2.0    3.0             1.000000
# 12    Master.       2    male    2.0    9.0             1.000000
# 13    Master.       3    male   17.0   28.0             0.392857
# 14      Miss.       1  female   14.0   46.0             0.956522
# 15      Miss.       2  female   16.0   34.0             0.941176
# 16      Miss.       3  female   48.0  102.0             0.500000
# 17      Mlle.       1  female    0.0    2.0             1.000000
# 18       Mme.       1  female    0.0    1.0             1.000000
# 19        Mr.       1    male   52.0  107.0             0.345794
# 20        Mr.       2    male   59.0   91.0             0.087912
# 21        Mr.       3    male  129.0  319.0             0.112853
# 22       Mrs.       1  female   35.0   42.0             0.976190
# 23       Mrs.       2  female   14.0   41.0             0.902439
# 24       Mrs.       3  female   23.0   42.0             0.500000
# 25        Ms.       2  female    0.0    1.0             1.000000
# 26        Ms.       3  female    1.0    0.0                  NaN
# 27       Rev.       2    male    2.0    6.0             0.000000
# 28       Sir.       1    male    0.0    1.0             1.000000

# %% [markdown]
# ##### Pclass x Sex x Age_Group

# %% [markdown]
# * **P1 Females, P1 Males, P2 Males, and P3 Males Survival Rates have significant associations with `Age_Group` (p < 0.05)**
# * **Given many subgroups have n < 50, do NOT one-hot encode broad feature `Pclass_Sex_Age_Group`**
# * **Create Smoothed Features `P1_Female_Age_Group_smoothed`, `P1_Male_Age_Group_smoothed`, `P2_Male_Age_Group_smoothed`, `P3_Male_Age_Group_smoothed`**
# * **P1 Female Survival Rate** by Age_Group:
#     * `Young_Child`: 0%, <span style="color:red">**n = 1**</span> (exclude)
#     * `Child`: <span style="color:green">**100%**</span>, <span style="color:red">**n = 7**</span> (include)
#     * `Young_Adult`: 95.4%, n = 22
#     * `Adult`: 98.3%, n = 61
#     * `Senior`: 100%, <span style="color:red">**n = 3**</span> (exclude)
# * **P1 Male Survival Rate** by Age_Group:
#     * `Young_Child`: 100%, <span style="color:red">**n = 2**</span> (exclude)
#     * `Child`: 100%, <span style="color:red">**n = 2**</span> (exclude)
#     * `Young_Adult`: 42.9%, n = 21
#     * `Adult`: 36.1%, n = 83
#     * `Senior`: 14.3%, n = 14
# * **P2 Male Survival Rate** by Age_Group:
#     * `Young_Child`: <span style="color:green">**100%**</span>, <span style="color:red">**n = 8**</span> (include)
#     * `Child`: 33.3%, <span style="color:red">**n = 3**</span> (exclude)
#     * `Young_Adult`: 2.8%, n = 36
#     * `Adult`: 10.5%, n = 57
#     * `Senior`: 25.3%, <span style="color:red">**n = 4**</span> (exclude)
# * **P3 Male Survival Rate** by Age_Group:
#     * `Young_Child`: 41.1%, n = 17
#     * `Child`: 16.7%, n = 30
#     * `Young_Adult`: 11.8%, n = 212
#     * `Adult`: 11.9%, n = 84
#     * `Senior`: 0%, <span style="color:red">**n = 4**</span> (exclude)

# %%
analyze_three_composite_features_x_survived('Pclass', 'Sex', 'Age_Group')
# Out:
# Stratified Chi² Tests: Does Age_Group affect survival within each Pclass x Sex group?
#    Pclass     Sex       p_value  significant
# 0       1  female  2.697702e-06         True
# 1       1    male  3.631165e-02         True
# 2       2  female  7.460600e-01        False
# 3       2    male  4.565921e-10         True
# 4       3  female  1.274097e-01        False
# 5       3    male  1.278659e-02         True
#
# Counts of Pclass x Sex x Age_Group:
#       Age_Group  Pclass     Sex   Test  Train  Train_Survival_Rate
# 0   Young_Child       1  female    0.0    1.0             0.000000
# 1   Young_Child       1    male    0.0    2.0             1.000000
# 2   Young_Child       2  female    2.0    5.0             1.000000
# 3   Young_Child       2    male    1.0    8.0             1.000000
# 4   Young_Child       3  female    5.0   15.0             0.733333
# 5   Young_Child       3    male    4.0   17.0             0.411765
# 6         Child       1  female    0.0    7.0             1.000000
# 7         Child       1    male    3.0    2.0             1.000000
# 8         Child       2  female    4.0    7.0             1.000000
# 9         Child       2    male    3.0    3.0             0.333333
# 10        Child       3  female    6.0   20.0             0.400000
# 11        Child       3    male   17.0   30.0             0.166667
# 12  Young_Adult       1  female   13.0   22.0             0.954545
# 13  Young_Adult       1    male    7.0   21.0             0.428571
# 14  Young_Adult       2  female   16.0   31.0             0.903226
# 15  Young_Adult       2    male   32.0   36.0             0.027778
# 16  Young_Adult       3  female   48.0   74.0             0.527027
# 17  Young_Adult       3    male  101.0  212.0             0.117925
# 18        Adult       1  female   31.0   61.0             0.983607
# 19        Adult       1    male   44.0   83.0             0.361446
# 20        Adult       2  female    7.0   33.0             0.909091
# 21        Adult       2    male   24.0   57.0             0.105263
# 22        Adult       3  female   13.0   34.0             0.382353
# 23        Adult       3    male   23.0   84.0             0.119048
# 24       Senior       1  female    6.0    3.0             1.000000
# 25       Senior       1    male    3.0   14.0             0.142857
# 26       Senior       2  female    1.0    0.0                  NaN
# 27       Senior       2    male    3.0    4.0             0.250000
# 28       Senior       3  female    0.0    1.0             1.000000
# 29       Senior       3    male    1.0    4.0             0.000000

# %% [markdown]
# ##### Pclass x Sex x Fare

# %% [markdown]
# * **Going to skip analyzing potential feature derivation from this combination given the known distribution shift between training and test data sets for `Fare_Per_Person_log_bin` (KL > 0.07)**
# * Significant distribution shift increases probability Fare-based rules will fail to generalize on the test set.
# * Will revisit if warranted post experimentation of initial feature set identified above.

# %% [markdown]
# ##### Analysis Summary of Composite Feature Relationships with Target
#
# * Chi-squared test was used to confirm the statistical significance of association between `Pclass` Survival Rate and `Sex` (p < 0.05).
# * After statistical-significance was confirmed, the Survival Rates for each pairwise combination of `Pclass` and `Sex` was calculated.
#     * This analysis yielded the following features to test in the Model Development phase:
#         * Create **6 binary features** by one-hot encoding `Pclass_Sex` due to each pairwise combination being supported by adequate sample size (n > 50).
#         * Create **3 smoothed rate features** to support the following pairwise combinations which had p < 0.5:
#             * `P1_Male_smoothed` (p=0.37)
#             * `P2_Male_smoothed` (p=0.16)
#             * `P3_Male_smoothed` (p=0.14)
# * After statistical significance was confirmed, chi-squared tests were performed between `Pclass_Sex` Survival Rate and each adjacent feature to identify which feature values had statistically-significant associations with `Pclass_Sex` Success Rate.
# * Of the many combinations of values between adjacent features and `Pclass_Sex`, only a relatively small subset of values were shown to be statistically-significant based on chi-squared testing.
#     * This analysis yielded the following additional **16 smoothed rate features** to test in Model Development:
#         * `P1_Female_Parch_smoothed`, `P2_Male_Parch_smoothed`
#         * `P3_Female_Embarked_smoothed`
#         * `P2_Male_HasCabin_smoothed`
#         * `P1_Female_Cabin_count_smoothed`, `P2_Male_Cabin_count_smoothed`, `P3_Male_Cabin_count_smoothed`
#         * `P2_Male_Cabin_Location_s_smoothed`
#         * `P2_Male_Deck_smoothed`, `P3_Male_Deck_smoothed`
#         * `P2_Male_Title_smoothed`, `P3_Male_Title_smoothed`
#         * `P1_Female_Age_Group_smoothed`, `P1_Male_Age_Group_smoothed`, `P2_Male_Age_Group_smoothed`, `P3_Male_Age_Group_smoothed`
# * **To prevent data leakage, it is critical that all smoothed rate features are created using Training Dataset only.**

# %% [markdown]
# #### Latent Features

# %% [markdown]
# ##### Name

# %% [markdown]
# * **Important:**
#     * `Name` begins with the surname of the passenger (e.g. `Braund` of `Braund, Mr. Owen Harris`), which in many instances in the data set is shared amongst passengers **from the same family**.
#     * Frequency encoding the surname *alone* is NOT a valid signal as visual inspection has uncovered **several instances where surnames are shared by passengers who are likely not from the same family** (e.g. passengers have different `Embarked`, `Fare` values and `Ticket` number proximity is wide).  See `Allen` surname as example.
#     * Visual inspection has also revealed passengers sharing the `Surname` don't always share the same `Ticket` nor do their `Parch`/`SibSp` reflect their relationship (see `Abselseth` as an example)
#         * It looks like `Pclass`, `Fare`, and `Embarked` matching are the strongest indicator of likely family grouping.
#         * Secondary signal is having a `Ticket` number that is numerically close in distance (e.g. see `Abselseth` `Ticket` numbers `348122` and `348125`)
# * **Feature Engineering Plan:**
#     * Create a "family member frequency" feature that counts the number of *training set* passengers that share the same `Surname`, `Pclass`, `Fare`, and `Embarked` values and map that frequency number to passengers in the test data set that share the same combination of feature values.
#     * **To prevent data leakage it is critical to not include any test data in the calculation of family member frequency.**

# %%
prepared_train_df["Surname"] = prepared_train_df["Name"].str.extract(r'^([^,]+)')
prepared_test_df["Surname"] = prepared_test_df["Name"].str.extract(r'^([^,]+)')
train_surnames = set(prepared_train_df["Surname"].unique())
test_surnames = set(prepared_test_df["Surname"].unique())
shared_surnames = train_surnames.intersection(test_surnames)
print(f"Number of surnames in training set: {len(train_surnames)}")
print(f"Number of surnames in test set: {len(test_surnames)}")
print(f"Number of surnames shared between train and test: {len(shared_surnames)}")
# Out:
# Number of surnames in training set: 667
# Number of surnames in test set: 352
# Number of surnames shared between train and test: 144

# %%
# Extract Surname from Name in both datasets
prepared_train_df["Surname"] = prepared_train_df["Name"].str.extract(r'^([^,]+)')
prepared_test_df["Surname"] = prepared_test_df["Name"].str.extract(r'^([^,]+)')

# Add a placeholder Survived column to the test set for consistency
prepared_test_df["Survived"] = np.nan  # since test set doesn't have labels

# Select relevant columns for inspection
cols_to_keep = ["Name", "Surname", "Pclass", "Ticket", "Fare", "Embarked", "Parch", "SibSp", "Age", "Survived"]

# Concatenate both dataframes
combined_df = pd.concat([
    prepared_train_df[cols_to_keep],
    prepared_test_df[cols_to_keep]
], ignore_index=True)

# Optional: sort to make similar groups easier to spot
combined_df = combined_df.sort_values(by=["Surname", "Pclass", "Fare", "Embarked", "Ticket", "Parch", "SibSp", "Age"])

# View the combined dataset
combined_df.reset_index(drop=True, inplace=True)
combined_df.head(100)
# Out:
#                                                Name   Surname  Pclass  \
# 0                               Abbing, Mr. Anthony    Abbing       3
# 1                       Abbott, Mr. Rossmore Edward    Abbott       3
# 2                  Abbott, Mrs. Stanton (Rosa Hunt)    Abbott       3
# 3                     Abbott, Master. Eugene Joseph    Abbott       3
# 4                     Abelseth, Mr. Olaus Jorgensen  Abelseth       3
# ..                                              ...       ...     ...
# 95                           Barton, Mr. David John    Barton       3
# 96                       Bateman, Rev. Robert James   Bateman       2
# 97                              Baumann, Mr. John D   Baumann       1
# 98                         Baxter, Mr. Quigg Edmond    Baxter       1
# 99  Baxter, Mrs. James (Helene DeLaudeniere Chaput)    Baxter       1
#
#          Ticket      Fare Embarked  Parch  SibSp   Age  Survived
# 0     C.A. 5547    7.5500        S      0      0  42.0       0.0
# 1     C.A. 2673   20.2500        S      1      1  16.0       0.0
# 2     C.A. 2673   20.2500        S      1      1  35.0       1.0
# 3     C.A. 2673   20.2500        S      2      0  13.0       NaN
# 4        348122    7.6500        S      0      0  25.0       NaN
# ..          ...       ...      ...    ...    ...   ...       ...
# 95       324669    8.0500        S      0      0  22.0       0.0
# 96  S.O.P. 1166   12.5250        S      0      0  51.0       0.0
# 97     PC 17318   25.9250        S      0      0  40.0       0.0
# 98     PC 17558  247.5208        C      1      0  24.0       0.0
# 99     PC 17558  247.5208        C      1      0  50.0       1.0
#
# [100 rows x 10 columns]

# %% [markdown]
# ##### Ticket

# %% [markdown]
# * Logic and nuance here is thankfully much simplier than what was discussed with `Name`; we can assume that passengers sharing the same `Ticket` are part of the same traveling group (including those that do not share the same `Surname`, which occurs when household staff, friends, etc travel together).
# * **Ideas for Feature Engineering:**
#     * Create a "ticket frequency" feature that counts the number of *training set* passengers that share the same `Ticket` values and map that frequency number to passengers in the test data set that share the same combination of feature values.
#     * **To prevent data leakage it is critical to not include any test data in the calculation of ticket frequency.**

# %%
train_tickets = set(prepared_train_df["Ticket"].unique())
test_tickets = set(prepared_test_df["Ticket"].unique())
shared_tickets = train_tickets.intersection(test_tickets)
print(f"Number of tickets in training set: {len(train_tickets)}")
print(f"Number of tickets in test set: {len(test_tickets)}")
print(f"Number of tickets shared between train and test: {len(shared_tickets)}")
# Out:
# Number of tickets in training set: 681
# Number of tickets in test set: 363
# Number of tickets shared between train and test: 115

# %% [markdown]
# #### Compilation of Feature Engineering Plans

# %% [markdown]
# | Feature | Feature Engineering Ideas |
# | ------------ | ------------------------- |
# | **Pclass** | Represent with `Pclass_Sex` one-hot encodings + 3 `P*_Male_smoothed` supports |
# | **Sex** | Represent with `Pclass_Sex` one-hot encodings + 3 `P*_Male_smoothed` supports |
# | **SibSp** | Do not represent with feature at this time. |
# | **Parch** | Represent with `P1_Female_Parch_smoothed`, `P2_Male_Parch_smoothed`  |
# | **Embarked** | Represent with `P3_Female_Embarked_smoothed`  |
# | **HasCabin** | Represent with `P2_Male_HasCabine_smoothed`  |
# | **Cabin_count** | Represent with `P1_Female_Cabin_count_smoothed`, `P2_Male_Cabin_count_smoothed`, `P3_Male_Cabin_count_smoothed` |
# | **Cabin_Location_s** | Represent with `P2_Male_Cabin_Location_s_smoothed` |
# | **Deck** | Represent with `P2_Male_Deck_smoothed`, `P3_Male_Deck_smoothed` |
# | **Title** | Represent with `P2_Male_Title_smoothed`, `P3_Male_Title_smoothed` |
# | **Age** | Represent with `P1_Female_Age_Group_smoothed`, `P1_Male_Age_Group_smoothed`, `P2_Male_Age_Group_smoothed`, `P3_Male_Age_group_smoothed` |
# | **Fare** | Refrain from representing with feature for now given known distribution shift of `Fare_Per_Person_log_bin` |
# | **Name** | Create a "family member frequency" feature that counts the number of *training set* passengers that share the same `Surname`, `Pclass`, `Fare`, and `Embarked` values and map that frequency number to passengers in the test data set that share the same combination of feature values. |
# | **Ticket** | Create a "ticket frequency" feature that counts the number of *training set* passengers that share the same `Ticket` values and map that frequency number to passengers in the test data set that share the same combination of feature values. |

# %% [markdown]
# ### Training/Test Set Distribution Comparison

# %%
def plot_feature_distribution(feature, train_df, test_df):
    """
    Plots the distribution of a given feature across training and test sets.

    Converts CategoricalDtype and IntervalDtype columns to string to ensure compatibility
    with Seaborn’s histplot and kdeplot functions. Preserves bin order in plots.

    Does not mutate the original DataFrames.

    Args:
        feature (str): The name of the feature column to plot.
        train_df (DataFrame): Training dataset.
        test_df (DataFrame): Test dataset.

    Returns:
        None
    """
    # Copy feature columns
    train_col = train_df[feature].copy()
    test_col = test_df[feature].copy()

    # Convert Categorical and Interval types to string while preserving order
    if isinstance(train_col.dtype, pd.CategoricalDtype):
        # Preserve category order
        category_order = [str(c) for c in train_col.cat.categories]
        train_col = train_col.astype(str).astype(pd.CategoricalDtype(categories=category_order, ordered=True))
        test_col = test_col.astype(str).astype(pd.CategoricalDtype(categories=category_order, ordered=True))

    elif isinstance(train_col.dtype, pd.IntervalDtype):
        # Convert interval to string
        train_col = train_col.astype(str)
        test_col = test_col.astype(str)

        # Create ordered categories from train bins
        category_order = sorted(train_col.unique(), key=lambda x: eval(x.strip("()[]").split(",")[0]))
        train_col = pd.Categorical(train_col, categories=category_order, ordered=True)
        test_col = pd.Categorical(test_col, categories=category_order, ordered=True)

    # Create combined DataFrame for plotting
    combined = pd.concat([
        train_col.to_frame(name=feature).assign(Dataset='Train'),
        test_col.to_frame(name=feature).assign(Dataset='Test')
    ]).reset_index(drop=True)

    # Plot
    plt.figure(figsize=(8, 4))
    sns.histplot(data=combined, x=feature, hue='Dataset', stat='percent',
                     multiple='dodge', common_norm=False)
    # if combined[feature].dtype in ['object', 'category']:
    #     sns.histplot(data=combined, x=feature, hue='Dataset', stat='percent',
    #                  multiple='dodge', common_norm=False)
    # else:
    #     sns.kdeplot(data=combined, x=feature, hue='Dataset', fill=True)

    plt.title(f'Distribution of {feature} (Train vs Test)')
    plt.tight_layout()
    plt.show()


def compute_kl_divergence(column, train_df, test_df):
    # Normalize value counts to get probability distributions
    train_dist = train_df[column].value_counts(normalize=True).sort_index()
    test_dist = test_df[column].value_counts(normalize=True).sort_index()

    # Align the indexes so both distributions have the same support
    all_indices = train_dist.index.union(test_dist.index)
    train_probs = train_dist.reindex(all_indices, fill_value=1e-9)
    test_probs = test_dist.reindex(all_indices, fill_value=1e-9)

    # Compute KL divergence: KL(train || test)
    kl_div = entropy(train_probs, test_probs)
    return kl_div
    
def print_train_test_distributions_for_feature(feature_name, train_df, test_df, plot_shift=False):
    """
    Prints and plots distribution of specified feature across training and test sets to assess whether distribution shift is within acceptable levels.
    Also prints Kullback-Leibler (KL) divergence that quantifies difference in training and test set distributions of feature.

    Args:
        feature_name (string): Column name present in both prepared
        train_df (DataFrame): Training data set containing feature
        test_df (DataFrame): Test data set containing feature

    Returns:
        Nothing
    """
    test_counts = (
        test_df
        .groupby(feature_name, observed=True)
        .size()
        .rename("Test_Count")
        .reset_index()
    )
    distribution_by_feature_df = (
        train_df
        .groupby(feature_name, observed=True)
        .size()
        .rename("Train_Count")
        .reset_index()
        .merge(test_counts, on=feature_name, how="left")
        .fillna({'Test_Count': 0})
        .sort_values(by="Train_Count", ascending=False)
    )
    total_train = distribution_by_feature_df["Train_Count"].sum()
    total_test = distribution_by_feature_df["Test_Count"].sum()
    distribution_by_feature_df["Train_Percent"] = (distribution_by_feature_df["Train_Count"] / total_train * 100).round(2)
    distribution_by_feature_df["Test_Percent"] = (distribution_by_feature_df["Test_Count"] / total_test * 100).round(2)
    distribution_by_feature_df = distribution_by_feature_df.sort_values(by="Train_Count", ascending=False)
    print(distribution_by_feature_df)
    print(f"\nKL Divergence: {compute_kl_divergence(feature_name, train_df, test_df):.4f}\n")

    if plot_shift:
        plot_feature_distribution(feature_name, train_df, test_df)

# %% [markdown]
# #### Pclass_Sex

# %%
def create_feature_Pclass_Sex(train_df, test_df):
    for df in [train_df, test_df]:
        df['Pclass_Sex'] = df['Pclass'].astype(str) + '_' + df['Sex'].astype(str)

create_feature_Pclass_Sex(prepared_train_df, prepared_test_df)

# %%
print_train_test_distributions_for_feature('Pclass_Sex', prepared_train_df, prepared_test_df)
# Out:
#   Pclass_Sex  Train_Count  Test_Count  Train_Percent  Test_Percent
# 5     3_male          347         146          38.95         34.93
# 4   3_female          144          72          16.16         17.22
# 1     1_male          122          57          13.69         13.64
# 3     2_male          108          63          12.12         15.07
# 0   1_female           94          50          10.55         11.96
# 2   2_female           76          30           8.53          7.18
#
# KL Divergence: 0.0077

# %% [markdown]
# <span style="color:green">**Neglible shift for `Pclass_Sex`:**</span> KL = 0.0077 < 0.02

# %% [markdown]
# #### Pclass_

# %%
print_train_test_distributions_for_feature('Pclass', prepared_train_df, prepared_test_df)
# Out:
#    Pclass  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2       3          491         218          55.11         52.15
# 0       1          216         107          24.24         25.60
# 1       2          184          93          20.65         22.25
#
# KL Divergence: 0.0018

# %% [markdown]
# <span style="color:green">**Neglible shift for `Pclass`:**</span> KL = 0.0018 < 0.02

# %% [markdown]
# #### Sex_

# %%
print_train_test_distributions_for_feature('Sex', prepared_train_df, prepared_test_df)
# Out:
#       Sex  Train_Count  Test_Count  Train_Percent  Test_Percent
# 1    male          577         266          64.76         63.64
# 0  female          314         152          35.24         36.36
#
# KL Divergence: 0.0003

# %% [markdown]
# <span style="color:green">**Neglible shift for `Sex`:**</span> KL = 0.0003 < 0.02

# %% [markdown]
# #### SibSp_

# %%
print_train_test_distributions_for_feature('SibSp', prepared_train_df, prepared_test_df)
# Out:
#    SibSp  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0      0          608         283          68.24         67.70
# 1      1          209         110          23.46         26.32
# 2      2           28          14           3.14          3.35
# 4      4           18           4           2.02          0.96
# 3      3           16           4           1.80          0.96
# 6      8            7           2           0.79          0.48
# 5      5            5           1           0.56          0.24
#
# KL Divergence: 0.0115

# %% [markdown]
# <span style="color:green">**Neglible shift for `SibSp`:**</span> KL = 0.0115 < 0.02

# %% [markdown]
# #### Parch_

# %%
print_train_test_distributions_for_feature('Parch', prepared_train_df, prepared_test_df)
# Out:
#    Parch  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0      0          678         324          76.09         77.88
# 1      1          118          52          13.24         12.50
# 2      2           80          33           8.98          7.93
# 3      3            5           3           0.56          0.72
# 5      5            5           1           0.56          0.24
# 4      4            4           2           0.45          0.48
# 6      6            1           1           0.11          0.24
#
# KL Divergence: 0.0081

# %% [markdown]
# <span style="color:green">**Neglible shift for `Parch`:**</span> KL = 0.0081 < 0.02

# %% [markdown]
# #### Embarked__

# %%
print_train_test_distributions_for_feature('Embarked', prepared_train_df, prepared_test_df)
# Out:
#   Embarked  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2        S          646         270          72.50         64.59
# 0        C          168         102          18.86         24.40
# 1        Q           77          46           8.64         11.00
#
# KL Divergence: 0.0142

# %% [markdown]
# <span style="color:green">**Neglible shift for `Embarked`:**</span> KL = 0.0142 < 0.02

# %% [markdown]
# #### HasCabin_

# %%
print_train_test_distributions_for_feature('HasCabin', prepared_train_df, prepared_test_df)
# Out:
#    HasCabin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0         0          687         327           77.1         78.23
# 1         1          204          91           22.9         21.77
#
# KL Divergence: 0.0004

# %% [markdown]
# <span style="color:green">**Neglible shift for `HasCabin`:**</span> KL = 0.0004 < 0.02

# %% [markdown]
# #### Cabin_count_

# %%
print_train_test_distributions_for_feature('Cabin_count', prepared_train_df, prepared_test_df)
# Out:
#   Cabin_count  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0           0          687         327          77.10         78.23
# 1           1          180          74          20.20         17.70
# 2           2           16          10           1.80          2.39
# 3           3            6           4           0.67          0.96
# 4           4            2           3           0.22          0.72
#
# KL Divergence: 0.0054

# %% [markdown]
# <span style="color:green">**Neglible shift for `Cabin_count`:**</span> KL = 0.0037 < 0.02

# %% [markdown]
# #### Cabin_Location_s_

# %%
print_train_test_distributions_for_feature('Cabin_Location_s', prepared_train_df, prepared_test_df)
# Out:
#      Cabin_Location_s  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0       no_cabin_info          687         327          77.10         78.23
# 2                port          108          46          12.12         11.00
# 4           starboard           90          40          10.10          9.57
# 1     no_cabin_number            4           2           0.45          0.48
# 3  port_and_starboard            2           3           0.22          0.72
#
# KL Divergence: 0.0031

# %% [markdown]
# <span style="color:green">**Negligible Shift for `Cabin_Location_s`:**</span> KL = 0.0031 < 0.02

# %% [markdown]
# #### Deck_

# %%
print_train_test_distributions_for_feature('Deck', prepared_train_df, prepared_test_df)
# Out:
#   Deck  Train_Count  Test_Count  Train_Percent  Test_Percent
# 7    M          687       327.0          77.10         78.23
# 2    C           59        35.0           6.62          8.37
# 1    B           47        18.0           5.27          4.31
# 3    D           33        13.0           3.70          3.11
# 4    E           32         9.0           3.59          2.15
# 0    A           15         7.0           1.68          1.67
# 5    F           13         8.0           1.46          1.91
# 6    G            4         1.0           0.45          0.24
# 8    T            1         0.0           0.11          0.00
#
# KL Divergence: 0.0234

# %% [markdown]
# <span style="color:orange">**Distribution Shift for `Deck`:**</span> KL = 0.0234 > 0.02
# * `Deck=M`, `Deck=C`, and `Deck=F` appear less frequently in the training set than in the test set.
# * `Deck=E`, `Deck=D`, and `Deck=B` appear more frequently in the training set than in the test set.
# * **Mitigation Plan:**
#     * Reweight samples during model training to account for shift
#     * Ablation test to assess influence

# %% [markdown]
# #### Title_

# %%
print_train_test_distributions_for_feature('Title', prepared_train_df, prepared_test_df)
# Out:
#         Title  Train_Count  Test_Count  Train_Percent  Test_Percent
# 12        Mr.          517       240.0          58.02         57.55
# 9       Miss.          182        78.0          20.43         18.71
# 13       Mrs.          125        72.0          14.03         17.27
# 8     Master.           40        21.0           4.49          5.04
# 4         Dr.            7         1.0           0.79          0.24
# 15       Rev.            6         2.0           0.67          0.48
# 1        Col.            2         2.0           0.22          0.48
# 10      Mlle.            2         0.0           0.22          0.00
# 7      Major.            2         0.0           0.22          0.00
# 11       Mme.            1         0.0           0.11          0.00
# 14        Ms.            1         1.0           0.11          0.24
# 0       Capt.            1         0.0           0.11          0.00
# 6       Lady.            1         0.0           0.11          0.00
# 5   Jonkheer.            1         0.0           0.11          0.00
# 3        Don.            1         0.0           0.11          0.00
# 2   Countess.            1         0.0           0.11          0.00
# 16       Sir.            1         0.0           0.11          0.00
#
# KL Divergence: 0.1749

# %% [markdown]
# <span style="color:orange">**High Distribution Shift for `Title`:**</span> KL = 0.1749 > 0.02 (<span style="color:red">**High!**</span>)
# * Top 4 titles relatively stable across training and test sets
# * Rare titles appear mostly in training set
# * **Mitigation Plan:**
#     * At minimum group rare titles into new "Other" category
#     * Consider excluding rare titles completely
#     * Ablation test to assess influence

# %% [markdown]
# #### Age__

# %%
print_train_test_distributions_for_feature('Age', prepared_train_df, prepared_test_df)
# Out:
#       Age  Train_Count  Test_Count  Train_Percent  Test_Percent
# 34  26.00          108        12.0          12.12          2.96
# 23  18.00           59        13.0           6.62          3.20
# 41  31.00           35         6.0           3.93          1.48
# 53  40.00           33         5.0           3.70          1.23
# 31  24.00           32        17.0           3.59          4.19
# ..    ...          ...         ...            ...           ...
# 0    0.42            1         0.0           0.11          0.00
# 86  70.50            1         0.0           0.11          0.00
# 84  66.00            1         0.0           0.11          0.00
# 88  74.00            1         0.0           0.11          0.00
# 89  80.00            1         0.0           0.11          0.00
#
# [90 rows x 5 columns]
#
# KL Divergence: 1.3025

# %% [markdown]
# <span style="color:orange">**Distribution Shift for `Age`:**</span> KL = 1.3025 > 0.02 (<span style="color:red">**High!**</span>)
# * Many more instances of 0-15 year olds and 18-50 year olds in training data set (practically the entire range)
# * Model may overfit on age patterns that are underrepresented in test data (e.g. children or young adults)
# * **Mitigation Plan:**
#     * Re-bin `Age_bin` to align distributions across data sets.
#     * Reweight sample based on Age bins
#     * Ablation test to assess influence

# %% [markdown]
# #### Fare__

# %%
print_train_test_distributions_for_feature('Fare', prepared_train_df, prepared_test_df)
# Out:
#         Fare  Train_Count  Test_Count  Train_Percent  Test_Percent
# 43    8.0500           43        18.0           4.83          4.83
# 85   13.0000           42        17.0           4.71          4.56
# 40    7.8958           38        11.0           4.26          2.95
# 30    7.7500           34        21.0           3.82          5.63
# 138  26.0000           31        19.0           3.48          5.09
# ..       ...          ...         ...            ...           ...
# 51    8.4583            1         0.0           0.11          0.00
# 176  40.1250            1         0.0           0.11          0.00
# 59    9.2167            1         0.0           0.11          0.00
# 178  42.4000            1         1.0           0.11          0.27
# 26    7.7292            1         0.0           0.11          0.00
#
# [248 rows x 5 columns]
#
# KL Divergence: 3.4819

# %% [markdown]
# <span style="color:orange">**Large Distribution Shift for `Fare`:**</span> KL = 3.4819 > 0.02 (<span style="color:red">**Very High!**</span>)
# * **Important Note:** In instances where multiple passengers are traveling together, Fare represents sum paid by all passengers.
# * **Mitigation Plan:**
#     * Calculate "fare per person" (FPP) using training data set to calculate group size
#     * Bin values to consolidate long-tail values
#     * Reweight sample based on FPP bins
#     * Ablation test to assess influence

# %% [markdown]
# #### Compilation of Distribution Shift Mitigation Plans

# %% [markdown]
# | Feature | KL | Mitigation Plan |
# | ------- | ----------------|----------------------------- |
# | **Pclass_Sex** | 0.0077 | None needed |
# | **Pclass**  | 0.0018 | None needed  |
# | **Sex** | 0.0003 | None needed  |
# | **SibSp** | 0.0115 | None needed  |
# | **Parch** | 0.0081 | None needed  |
# | **Embarked** | 0.0142 |None needed   |
# | **HasCabin** | 0.0004 |None needed   |
# | **Cabin_count** |  0.0037 | None needed  |
# | **Cabin_Location_s** |  0.0031 | None needed  |
# | **Deck** | <span style="color:orange">**0.0234**</span> | Reweight samples during model training to account for shift; Ablation test to assess influence |
# | **Title** | <span style="color:orange">**0.1749**<span style="color:orange"> | At minimum group rare titles into new "Other" category; Consider excluding rare titles completely; Ablation test to assess influence|
# | **Age** | <span style="color:orange">**1.3025** | Re-bin Age_bin to align distributions across data sets.; Reweight sample based on Age bins; Ablation test to assess influence|
# | **Fare** | <span style="color:orange">**3.4819** | Calculate "fare per person" (FPP) using training data set to calculate group size; Bin values to consolidate long-tail values; Reweight sample based on FPP bins; Ablation test to assess influence |

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Pclass_Sex One-Hot Encodings

# %% [markdown]
# ##### Create Features

# %%
def create_Pclass_Sex_one_hot_encodings(train_df, test_df):
    for df in [train_df, test_df]:
        dummies = pd.get_dummies(df['Pclass_Sex'], prefix='Pclass_Sex')
        df[dummies.columns] = dummies
        print(f"{len(dummies)} one-hot encodings created for Pclass x Sex: {dummies.columns}")
    return dummies.columns

pclass_sex_oh_cols = create_Pclass_Sex_one_hot_encodings(train_df, test_df)
# Out:
# 891 one-hot encodings created for Pclass x Sex: Index(['Pclass_Sex_1_female', 'Pclass_Sex_1_male', 'Pclass_Sex_2_female',
#        'Pclass_Sex_2_male', 'Pclass_Sex_3_female', 'Pclass_Sex_3_male'],
#       dtype='object')
# 418 one-hot encodings created for Pclass x Sex: Index(['Pclass_Sex_1_female', 'Pclass_Sex_1_male', 'Pclass_Sex_2_female',
#        'Pclass_Sex_2_male', 'Pclass_Sex_3_female', 'Pclass_Sex_3_male'],
#       dtype='object')

# %% [markdown]
# ##### Assess Distribution Shift

# %% [markdown]
# Negligible distribution shift for all created Pclass x Sex one-hot encodings (all KL < 0.02)

# %%
for col in pclass_sex_oh_cols:
    print_train_test_distributions_for_feature(col, prepared_train_df, prepared_test_df)
# Out:
#    Pclass_Sex_1_female  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0                False          797         368          89.45         88.04
# 1                 True           94          50          10.55         11.96
#
# KL Divergence: 0.0010
#
#    Pclass_Sex_1_male  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0              False          769         361          86.31         86.36
# 1               True          122          57          13.69         13.64
#
# KL Divergence: 0.0000
#
#    Pclass_Sex_2_female  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0                False          815         388          91.47         92.82
# 1                 True           76          30           8.53          7.18
#
# KL Divergence: 0.0013
#
#    Pclass_Sex_2_male  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0              False          783         355          87.88         84.93
# 1               True          108          63          12.12         15.07
#
# KL Divergence: 0.0036
#
#    Pclass_Sex_3_female  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0                False          747         346          83.84         82.78
# 1                 True          144          72          16.16         17.22
#
# KL Divergence: 0.0004
#
#    Pclass_Sex_3_male  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0              False          544         272          61.05         65.07
# 1               True          347         146          38.95         34.93
#
# KL Divergence: 0.0035

# %% [markdown]
# #### Smoothed Features

# %%
# Create reusable function for creating Pclass x Sex smoothed rate features
def create_pclass_sex_smoothed_feature(train_df, test_df, pclass_val, sex_val, grouping_col=None, prior=10):
    """
    Creates a smoothed survival rate feature for a specific Pclass and Sex group.
    
    If `grouping_col` is provided, the smoothed survival rate is computed for each subgroup within 
    the Pclass-Sex group using that column (e.g., Age_Group, Parch).
    
    If `grouping_col` is None, a single smoothed survival rate is computed for the overall 
    Pclass-Sex group (e.g., P1_Male, P2_Female).

    All rates are computed using training data only to prevent data leakage, and applied safely 
    to both train_df and test_df.

    Rules (for grouped smoothing only):
    - Include grouping_col groups with n >= 10
    - Also include groups with 5 <= n < 10 if survival rate == 100%
    - Exclude groups with n < 5

    Args:
        train_df (pd.DataFrame): The training set used to compute survival statistics.
        test_df (pd.DataFrame): The test set to apply the smoothed feature to.
        pclass_val (int): Value of Pclass to filter for (e.g., 1, 2, or 3).
        sex_val (str): Value of Sex to filter for (e.g., 'male' or 'female').
        grouping_col (str or None): Optional. Categorical column to group by for smoothing (e.g., 'Age_Group').
                                    If None, computes a single smoothed rate for the entire Pclass-Sex group.
        prior (int, optional): Smoothing strength that balances global vs. group survival rates. Default is 10.

    Returns:
        str: Name of the created smoothed feature column.
    """
    mask = (train_df['Pclass'] == pclass_val) & (train_df['Sex'] == sex_val)
    subset_df = train_df[mask]
    global_mean = train_df['Survived'].mean()

    if grouping_col is None:
        group_mean = subset_df['Survived'].mean()
        group_count = subset_df.shape[0]

        smoothed_rate = (group_mean * group_count + prior * global_mean) / (group_count + prior)
        col_name = f'P{pclass_val}_{sex_val.capitalize()}_smoothed'

        train_df[col_name] = 0.0
        train_df.loc[mask, col_name] = smoothed_rate

        test_mask = (test_df['Pclass'] == pclass_val) & (test_df['Sex'] == sex_val)
        test_df[col_name] = 0.0
        test_df.loc[test_mask, col_name] = smoothed_rate

    else:
        group_stats = (
            subset_df.groupby(grouping_col, observed=True)['Survived']
            .agg(['mean', 'count'])
            .reset_index()
            .rename(columns={'mean': 'group_mean', 'count': 'group_count'})
        )

        included = group_stats[
            (group_stats['group_count'] >= 10) |
            ((group_stats['group_count'] >= 5) & (group_stats['group_mean'] == 1.0))
        ].copy()

        included['smoothed_rate'] = (
            (included['group_mean'] * included['group_count'] + prior * global_mean) /
            (included['group_count'] + prior)
        )

        col_name = f'P{pclass_val}_{sex_val.capitalize()}_{grouping_col}_smoothed'
        map_dict = included.set_index(grouping_col)['smoothed_rate'].to_dict()

        train_df[col_name] = 0.0
        train_df.loc[mask, col_name] = (
            train_df.loc[mask, grouping_col].map(map_dict)
        )

        test_mask = (test_df['Pclass'] == pclass_val) & (test_df['Sex'] == sex_val)
        test_df[col_name] = 0.0
        test_df.loc[test_mask, col_name] = (
            test_df.loc[test_mask, grouping_col].map(map_dict)
        )

    print(f"Created {col_name} feature in training and test dataframes.")
    print(train_df[col_name].describe())
    print()

    return col_name

# %% [markdown]
# #### Is_Shared_Ticket

# %%
# Construct list of all smoothed feature dicts
smoothed_features_to_create = [
    { 'pclass': 1, 'sex': 'male', 'group_col': None },
    { 'pclass': 2, 'sex': 'male', 'group_col': None },
    { 'pclass': 3, 'sex': 'male', 'group_col': None },
    { 'pclass': 1, 'sex': 'female', 'group_col': 'Parch' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'Parch' },
    { 'pclass': 3, 'sex': 'female', 'group_col': 'Embarked' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'HasCabin' },
    { 'pclass': 1, 'sex': 'female', 'group_col': 'Cabin_count' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'Cabin_count' },
    { 'pclass': 3, 'sex': 'male', 'group_col': 'Cabin_count' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'Cabin_Location_s' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'Deck' },
    { 'pclass': 3, 'sex': 'male', 'group_col': 'Deck' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'Title' },
    { 'pclass': 3, 'sex': 'male', 'group_col': 'Title' },
    { 'pclass': 1, 'sex': 'female', 'group_col': 'Age_Group' },
    { 'pclass': 1, 'sex': 'male', 'group_col': 'Age_Group' },
    { 'pclass': 2, 'sex': 'male', 'group_col': 'Age_Group' },
    { 'pclass': 3, 'sex': 'male', 'group_col': 'Age_Group' },
]
smoothed_feature_cols =  []
for smoothed_feature_config in smoothed_features_to_create:
    smoothed_feature_col = create_pclass_sex_smoothed_feature(prepared_train_df, prepared_test_df, smoothed_feature_config['pclass'], smoothed_feature_config['sex'], smoothed_feature_config['group_col'])
    smoothed_feature_cols.append(smoothed_feature_col)
print(f"Created {len(smoothed_feature_cols)} smoothed features.")
# Out:
# Created P1_Male_smoothed feature in training and test dataframes.
# count    891.000000
# mean       0.050661
# std        0.127261
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.369988
# Name: P1_Male_smoothed, dtype: float64
#
# Created P2_Male_smoothed feature in training and test dataframes.
# count    891.000000
# mean       0.021406
# std        0.057669
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.176596
# Name: P2_Male_smoothed, dtype: float64
#
# Created P3_Male_smoothed feature in training and test dataframes.
# count    891.000000
# mean       0.055459
# std        0.069479
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.142404
# max        0.142404
# Name: P3_Male_smoothed, dtype: float64
#
# Created P1_Female_Parch_smoothed feature in training and test dataframes.
# count    891.000000
# mean       0.089016
# std        0.261131
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.903221
# Name: P1_Female_Parch_smoothed, dtype: float64
#
# Created P2_Male_Parch_smoothed feature in training and test dataframes.
# count    886.000000
# mean       0.019148
# std        0.065553
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.451599
# Name: P2_Male_Parch_smoothed, dtype: float64
#
# Created P3_Female_Embarked_smoothed feature in training and test dataframes.
# count    891.000000
# mean       0.075840
# std        0.179376
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.647404
# Name: P3_Female_Embarked_smoothed, dtype: float64
#
# Created P2_Male_HasCabin_smoothed feature in training and test dataframes.
# count    885.000000
# mean       0.017328
# std        0.048036
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.150343
# Name: P2_Male_HasCabin_smoothed, dtype: float64
#
# Created P1_Female_Cabin_count_smoothed feature in training and test dataframes.
# count    881.000000
# mean       0.084268
# std        0.260489
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.911585
# Name: P1_Female_Cabin_count_smoothed, dtype: float64
#
# Created P2_Male_Cabin_count_smoothed feature in training and test dataframes.
# count    885.000000
# mean       0.017328
# std        0.048036
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.150343
# Name: P2_Male_Cabin_count_smoothed, dtype: float64
#
# Created P3_Male_Cabin_count_smoothed feature in training and test dataframes.
# count    885.000000
# mean       0.053612
# std        0.067754
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.139141
# max        0.139141
# Name: P3_Male_Cabin_count_smoothed, dtype: float64
#
# Created P2_Male_Cabin_Location_s_smoothed feature in training and test dataframes.
# count    885.000000
# mean       0.017328
# std        0.048036
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.150343
# Name: P2_Male_Cabin_Location_s_smoothed, dtype: float64
#
# Created P2_Male_Deck_smoothed feature in training and test dataframes.
# count    885.000000
# mean       0.017328
# std        0.048036
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.150343
# Name: P2_Male_Deck_smoothed, dtype: float64
#
# Created P3_Male_Deck_smoothed feature in training and test dataframes.
# count    885.000000
# mean       0.053612
# std        0.067754
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.139141
# max        0.139141
# Name: P3_Male_Deck_smoothed, dtype: float64
#
# Created P2_Male_Title_smoothed feature in training and test dataframes.
# count    883.000000
# mean       0.018967
# std        0.075606
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.675704
# Name: P2_Male_Title_smoothed, dtype: float64
#
# Created P3_Male_Title_smoothed feature in training and test dataframes.
# count    891.000000
# mean       0.055624
# std        0.083397
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.121089
# max        0.390484
# Name: P3_Male_Title_smoothed, dtype: float64
#
# Created P1_Female_Age_Group_smoothed feature in training and test dataframes.
# count    887.000000
# mean       0.086118
# std        0.257695
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.899132
# Name: P1_Female_Age_Group_smoothed, dtype: float64
#
# Created P1_Male_Age_Group_smoothed feature in training and test dataframes.
# count    887.000000
# mean       0.047692
# std        0.122985
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.414141
# Name: P1_Male_Age_Group_smoothed, dtype: float64
#
# Created P2_Male_Age_Group_smoothed feature in training and test dataframes.
# count    884.000000
# mean       0.019704
# std        0.073302
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.657688
# Name: P2_Male_Age_Group_smoothed, dtype: float64
#
# Created P3_Male_Age_Group_smoothed feature in training and test dataframes.
# count    887.000000
# mean       0.060156
# std        0.084939
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.129903
# max        0.401422
# Name: P3_Male_Age_Group_smoothed, dtype: float64
#
# Created 19 smoothed features.

# %% [markdown]
# * **Important Notes re: Data Leakage:**
#     * To prevent test data set leakage, it's critical to only use the training data set when calculating the frequency in which a ticket is shared amongst passengers.
#     * Knowing that tickets are also shared by passengers in the test data set (and likely beyond), this makes the frequency calculation more of a "weight" to aid training prediction, rather than a true calculation of ticket frequency.
#     * A share count map is implemented here to make the ticket share counts of the training data available in the test data.
# * Analysis of shared ticket count amongst training data applied to match tickets in test data revealed the frequency of matching counts dropped significantly for `Share_Ticket_Count >= 1`, motivating creating a binary `Is_Shared_Ticket` feature instead to indicate whether or not a given ticket was shared by training data passengers.
# * <span style="color:orange">**Distribution Shift of `Is_Shared_Ticket`:**</span>
#     * Sparse distribution of test data passengers with tickets matching training set shared tickets
#     * Will keep in mind during feature experimentation and drop from model if it contributes to overfitting.

# %%
def create_feature_Is_Shared_Ticket(train_df, test_df):
    """
    Creates "Is_Shared_Ticket" feature, which is a binary integer indicating whether a given ticket was shared by any other training set passenger.

    Is_Shared_Ticket of tickets not shared by any other passenger is set to zero / False.
    
    Training data Is_Shared_Ticket value is associated to tickets in the test data that share the same ticket number.
    
    Is_Shared_Ticket of test data ticket numbers that do not appear in the training data is set to zero.
    
    To prevent test data set leakage, it's critical to only use the training data set when calculating the 
    count ticket is shared amongst passengers.

    Args:
        train_df (DataFrame): Training data set  
        test_df (DataFrame): Test data set 
    Returns:
        Nothing
    """

    # Calculate ticket counts, including subtracting by one to prevent giving weight to tickets not being shared by others
    training_ticket_counts = train_df['Ticket'].value_counts() - 1 
    is_shared_ticket_df = training_ticket_counts > 0
    
    train_df['Is_Shared_Ticket'] = train_df['Ticket'].map(is_shared_ticket_df).astype(int)
    test_df['Is_Shared_Ticket'] = test_df['Ticket'].map(is_shared_ticket_df).fillna(0).astype(int)

create_feature_Is_Shared_Ticket(prepared_train_df, prepared_test_df)

# %%
print_train_test_distributions_for_feature("Is_Shared_Ticket", prepared_train_df, prepared_test_df)
# Out:
#    Is_Shared_Ticket  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0                 0          547         346          61.39         82.78
# 1                 1          344          72          38.61         17.22
#
# KL Divergence: 0.1281

# %% [markdown]
# #### Fare_Per_Person_log_bin

# %% [markdown]
# <span style="color:orange">**Distribution Shift for `Fare_Per_Person_log_bin`:**</span>
# * Even with quantile binning, KL divergence between training/test sets is relatively high at 0.0709.
# * Combining with `Pclass` resulted in huge distribution shift (KL > 0.50).
# * Will keep `Fare_Per_Person_log_bin` for now and keep/discard based on feature experimentation results.

# %%
def create_feature_Fare_per_person_log(train_df, test_df):
    """
    Creates "Fare_Per_Person", "Fare_Per_Person_log", and "Fare_Per_Person_log_bin" features.
    Applies quantile-based binning to "Fare_Per_Person_log" using training data to minimize distribution shift.
    Bin edges are expanded to include ±infinity to ensure all test values map to valid bins.

    Args:
        train_df (DataFrame): Training data set
        test_df (DataFrame): Test data set

    Returns:
        Nothing
    """
    # Calculate ticket counts from training data
    training_ticket_counts = train_df['Ticket'].value_counts()

    for df in [train_df, test_df]:
        ticket_counts = df['Ticket'].map(training_ticket_counts).fillna(1)
        df['Fare_Per_Person'] = df['Fare'] / ticket_counts
        df['Fare_Per_Person_log'] = np.log1p(df['Fare_Per_Person'])
        
create_feature_Fare_per_person_log(prepared_train_df, prepared_test_df)

# %%
print_train_test_distributions_for_feature("Fare_Per_Person_log", prepared_train_df, prepared_test_df)
# Out:
#      Fare_Per_Person_log  Train_Count  Test_Count  Train_Percent  Test_Percent
# 121             2.639057           56        18.0           6.29          4.83
# 67              2.202765           55        18.0           6.17          4.83
# 50              2.169054           40        21.0           4.49          5.63
# 63              2.185579           38        11.0           4.26          2.95
# 106             2.442347           26        11.0           2.92          2.95
# ..                   ...          ...         ...            ...           ...
# 188             3.573867            1         0.0           0.11          0.00
# 227             4.133232            1         1.0           0.11          0.27
# 211             3.921973            1         0.0           0.11          0.00
# 2               1.611935            1         0.0           0.11          0.00
# 246             5.406181            1         3.0           0.11          0.80
#
# [247 rows x 5 columns]
#
# KL Divergence: 3.5689

# %%
def create_feature_Fare_per_person_log_bin(train_df, test_df):
    """
    Creates "Fare_Per_Person", "Fare_Per_Person_log", and "Fare_Per_Person_log_bin" features.
    Applies quantile-based binning to "Fare_Per_Person_log" using training data to minimize distribution shift.
    Bin edges are expanded to include ±infinity to ensure all test values map to valid bins.

    Args:
        train_df (DataFrame): Training data set
        test_df (DataFrame): Test data set

    Returns:
        Nothing
    """
    # Calculate ticket counts from training data
    training_ticket_counts = train_df['Ticket'].value_counts()

    for df in [train_df, test_df]:
        ticket_counts = df['Ticket'].map(training_ticket_counts).fillna(1)
        df['Fare_Per_Person'] = df['Fare'] / ticket_counts
        df['Fare_Per_Person_log'] = np.log1p(df['Fare_Per_Person'])

    # Compute quantile-based bins from training set
    qcut_bins = pd.qcut(train_df['Fare_Per_Person_log'], q=6, duplicates='drop', retbins=True)[1]
    qcut_bins[0] = -np.inf  # Extend first bin edge to -inf
    qcut_bins[-1] = np.inf  # Extend last bin edge to +inf

    # Create bin labels
    bin_labels = [f"Bin {i+1}" for i in range(len(qcut_bins) - 1)]
    cat_dtype = pd.api.types.CategoricalDtype(categories=bin_labels, ordered=True)

    for df in [train_df, test_df]:
        df['FPP_log_bin'] = pd.cut(
            df['Fare_Per_Person_log'],
            bins=qcut_bins,
            labels=bin_labels,
            include_lowest=True
        ).astype(cat_dtype)
        
create_feature_Fare_per_person_log_bin(prepared_train_df, prepared_test_df)

# %%
print_train_test_distributions_for_feature("FPP_log_bin", prepared_train_df, prepared_test_df)
# Out:
#   FPP_log_bin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 1       Bin 2          162          88          18.18         21.05
# 3       Bin 4          159          61          17.85         14.59
# 0       Bin 1          156          39          17.51          9.33
# 5       Bin 6          147          92          16.50         22.01
# 4       Bin 5          139         100          15.60         23.92
# 2       Bin 3          128          38          14.37          9.09
#
# KL Divergence: 0.0709

# %% [markdown]
# #### Has_Other_Family_Members

# %% [markdown]
# * A "family member" here means a `Surname`/`Pclass`/`Fare`/`Embarked` combination that likely identifies multiple passengers as being from the same family.
# * Similar to what was decided for `Is_Shared_Ticket`, a new `Has_Other_Family_Members` binary feature was created here given the sparse number of test data passengers who had matching family member characteristics.
# * <span style="color:orange">**Distribution Shift for `Has_Other_Family_Members`:**</span>
#     * Training/test set distribution still differ significantly (KL=0.1305) despite binning into a binary variable.
#     * Keep for now and decide to keep/discard post feature experimentation results.
# * **Important Notes re: Data Leakage:**
#     * To prevent test data set leakage, it's critical to only use the training data set when calculating the frequency in which a passenger shared family member traits with others.
#     * Knowing that family members are in the test data set (and likely beyond), this makes the frequency calculation more of a "weight" to aid training prediction, rather than a true calculation of family size.
#     * A family member frequency map is implemented here to make the family member frequencies of the training data available in the test data.

# %%
def create_feature_Has_Other_Family_Members(train_df, test_df):
    """
    Creates a binary feature 'Has_Other_Family_Members' in both train_df and test_df.

    The feature is 1 if there is at least one *other* passenger in the training set
    with the same combination of Surname, Pclass, Fare, and Embarked. Otherwise, it is 0.

    Uses only training data to calculate group sizes to prevent data leakage.

    Args:
        train_df (DataFrame): Training dataset
        test_df (DataFrame): Test dataset

    Returns:
        None (modifies train_df and test_df in place)
    """
    family_key_cols = ["Surname", "Pclass", "Fare", "Embarked"]

    # Get size of each family group from training data
    family_sizes = (
        train_df
        .groupby(family_key_cols, observed=True)
        .size()
        .sub(1)  # subtract self
        .gt(0)   # convert to boolean
        .astype(int)
        .reset_index(name="Has_Other_Family_Members")
    )

    # Merge into train and test sets
    train_df["Has_Other_Family_Members"] = (
        train_df[family_key_cols]
        .merge(family_sizes, on=family_key_cols, how="left")["Has_Other_Family_Members"]
        .fillna(0)
        .astype(int)
    )

    test_df["Has_Other_Family_Members"] = (
        test_df[family_key_cols]
        .merge(family_sizes, on=family_key_cols, how="left")["Has_Other_Family_Members"]
        .fillna(0)
        .astype(int)
    )

create_feature_Has_Other_Family_Members(prepared_train_df, prepared_test_df)

# %%
print_train_test_distributions_for_feature("Has_Other_Family_Members", prepared_train_df, prepared_test_df)
# Out:
#    Has_Other_Family_Members  Train_Count  Test_Count  Train_Percent  \
# 0                         0          609         367          68.35
# 1                         1          282          51          31.65
#
#    Test_Percent
# 0          87.8
# 1          12.2
#
# KL Divergence: 0.1305

# %% [markdown]
# #### Compilation of Engineered Features and KL Values

# %% [markdown]
# * 23 feature canidates identified
#     * 6 binary one-hot encodings of `Pclass_Sex`
#     * 17 smoothed rate features
#     * 3 additional features with high KL divergence (KL > 0.02)
# * Will exclude the 3 high-KL features for now and proceed to Model Development with the 20 candidates!

# %%
def compute_kl_table(feature_names, train_df, test_df):
    import pandas as pd
    from IPython.display import display

    rows = []
    for feature in feature_names:
        try:
            kl_value = compute_kl_divergence(feature, train_df, test_df)
            rows.append({"Feature": feature, "KL_Divergence": kl_value})
        except Exception as e:
            rows.append({"Feature": feature, "KL_Divergence": f"Error: {str(e)}"})

    df = pd.DataFrame(rows)
    df["KL_Divergence"] = pd.to_numeric(df["KL_Divergence"], errors="coerce")
    df_sorted = df.sort_values(by="KL_Divergence", ascending=False).reset_index(drop=True)

    def highlight_kl(val):
        if pd.notna(val) and val > 0.02:
            return "background-color: yellow"
        return ""

    return df_sorted.style.map(highlight_kl, subset=["KL_Divergence"])

# %%
feature_list = pclass_sex_oh_cols.tolist() + [
    "FPP_log_bin",
    "Has_Other_Family_Members",
    "Is_Shared_Ticket"

    # We don't include the smoothed rate features here as we don't
    # care of distribution shift of features that were intentionally defined using 
    # only training set data.
]
kl_table = compute_kl_table(feature_list, prepared_train_df, prepared_test_df)
display(kl_table)
# Out:
# <style type="text/css">
# #T_b7f61_row0_col1, #T_b7f61_row1_col1, #T_b7f61_row2_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b7f61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7f61_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_b7f61_level0_col1" class="col_heading level0 col1" >KL_Divergence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7f61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7f61_row0_col0" class="data row0 col0" >Has_Other_Family_Members</td>
#       <td id="T_b7f61_row0_col1" class="data row0 col1" >0.130539</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7f61_row1_col0" class="data row1 col0" >Is_Shared_Ticket</td>
#       <td id="T_b7f61_row1_col1" class="data row1 col1" >0.128142</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7f61_row2_col0" class="data row2 col0" >FPP_log_bin</td>
#       <td id="T_b7f61_row2_col1" class="data row2 col1" >0.070930</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7f61_row3_col0" class="data row3 col0" >Pclass_Sex_2_male</td>
#       <td id="T_b7f61_row3_col1" class="data row3 col1" >0.003604</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b7f61_row4_col0" class="data row4 col0" >Pclass_Sex_3_male</td>
#       <td id="T_b7f61_row4_col1" class="data row4 col1" >0.003492</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b7f61_row5_col0" class="data row5 col0" >Pclass_Sex_2_female</td>
#       <td id="T_b7f61_row5_col1" class="data row5 col1" >0.001301</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b7f61_row6_col0" class="data row6 col0" >Pclass_Sex_1_female</td>
#       <td id="T_b7f61_row6_col1" class="data row6 col1" >0.000981</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b7f61_row7_col0" class="data row7 col0" >Pclass_Sex_3_female</td>
#       <td id="T_b7f61_row7_col1" class="data row7 col1" >0.000403</td>
#     </tr>
#     <tr>
#       <th id="T_b7f61_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b7f61_row8_col0" class="data row8 col0" >Pclass_Sex_1_male</td>
#       <td id="T_b7f61_row8_col1" class="data row8 col1" >0.000001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model Development

# %%
# Create functions to identify highly-correlated feature pairs to remove
def get_highly_correlated_feature_pairs(df, threshold=0.85):
    """
    Returns a DataFrame of feature pairs with correlation above the specified threshold.

    Args:
        df (pd.DataFrame): DataFrame of features (should be numeric or dummy-encoded).
        threshold (float): Minimum correlation to include in output.

    Returns:
        pd.DataFrame: Correlated feature pairs and their correlation coefficient.
    """
    corr_matrix = df.corr().abs()
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

    # Filter for correlations above the threshold
    high_corr = upper_triangle.stack().reset_index()
    high_corr.columns = ['Feature A', 'Feature B', 'Correlation']
    return high_corr[high_corr['Correlation'] >= threshold].sort_values(by='Correlation', ascending=False)

def identify_lower_importance_correlated_features_to_drop(corr_df, importance_dict, threshold=0.85):
    """
    For each correlated feature pair, identifies the feature with lower importance and prints the decision.

    Args:
        corr_df (pd.DataFrame): Output from get_highly_correlated_feature_pairs().
        importance_dict (dict or pd.Series): Feature importance scores (higher is better).
        threshold (float): Correlation threshold to consider dropping features.

    Returns:
        set: Set of feature names to drop.
    """
    to_drop = set()

    print(f"Features with correlation ≥ {threshold} and lower importance:\n")

    for _, row in corr_df.iterrows():
        if row['Correlation'] >= threshold:
            feat_a = row['Feature A']
            feat_b = row['Feature B']
            imp_a = importance_dict.get(feat_a, 0)
            imp_b = importance_dict.get(feat_b, 0)

            if imp_a >= imp_b:
                to_drop.add(feat_b)
                print(f"Drop: {feat_b:30} (Importance: {imp_b:.5f})  ⬅️ Keep: {feat_a:30} (Importance: {imp_a:.5f})")
            else:
                to_drop.add(feat_a)
                print(f"Drop: {feat_a:30} (Importance: {imp_a:.5f})  ⬅️ Keep: {feat_b:30} (Importance: {imp_b:.5f})")

    return to_drop

# %%
# Create reusable functions to evaluate learning curve and feature importances (where supported) for each model
def plot_validation_curve(model, param_name, param_range, selected_features=[], drop_cols=[]):

    X_all = pd.concat([prepared_train_df[selected_features], prepared_test_df[selected_features]], axis=0)
    X_all_encoded = pd.get_dummies(X_all, drop_first=False)
    
    X_train_encoded = X_all_encoded.iloc[:len(train_df)].copy()
    X_test_encoded = X_all_encoded.iloc[len(train_df):].copy()

    def clean_encodings_for_xgb(train_encoded_df, test_encoded_df):
        for df in [train_encoded_df, test_encoded_df]:
            df.columns = df.columns.str.replace(r'[<>\[\]\(\)]', '', regex=True)
            df.columns = df.columns.str.replace(', ', '_', regex=False)
            df.columns = df.columns.str.replace(r'[^0-9a-zA-Z_]', '_', regex=True)
    clean_encodings_for_xgb(X_train_encoded, X_test_encoded)

    if drop_cols:
        X_train_encoded.drop(columns=drop_cols, inplace=True)
        X_test_encoded.drop(columns=drop_cols, inplace=True)
             
    y = prepared_train_df['Survived']
  
    print("Evaluating baseline model with the following variables:")
    for col in X_train_encoded.columns:
        print(f"* {col}")

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    train_scores, val_scores = validation_curve(
        estimator=model,  # e.g., DecisionTreeClassifier
        X=X_train_encoded,
        y=y,
        param_name=param_name,
        param_range=param_range,
        cv=cv,
        scoring='accuracy'
    )
    
    # Compute means
    train_mean = train_scores.mean(axis=1)
    val_mean = val_scores.mean(axis=1)
    
    # Plot
    plt.plot(param_range, train_mean, label="Training Score")
    plt.plot(param_range, val_mean, label="Validation Score")
    plt.xlabel(param_name)
    plt.ylabel("Accuracy")
    plt.title("Validation Curve: max_depth")
    title = f"Validation Curve for {param_name}"
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_learning_curve(model, X, y, label=None):
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    train_sizes, train_scores, val_scores = learning_curve(
        estimator=model,
        X=X,
        y=y,
        cv=cv,
        scoring='accuracy',
        n_jobs=2,
        train_sizes=np.linspace(0.1, 1.0, 10)
    )
    
    # Compute mean and std
    train_mean = train_scores.mean(axis=1)
    train_std = train_scores.std(axis=1)
    val_mean = val_scores.mean(axis=1)
    val_std = val_scores.std(axis=1)

    # Plot curves
    plt.plot(train_sizes, train_mean, label='Training Score', color='blue')
    plt.plot(train_sizes, val_mean, label='Validation Score', color='orange')
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.2, color='blue')
    plt.fill_between(train_sizes, val_mean - val_std, val_mean + val_std, alpha=0.2, color='orange')

    # Get final values
    final_train_acc = train_mean[-1]
    final_val_acc = val_mean[-1]
    delta = final_train_acc - final_val_acc

    # Annotate final scores and delta with 4 decimal places
    plt.text(train_sizes[-1], final_train_acc + 0.005, f"Train: {final_train_acc:.4f}", color='blue')
    plt.text(train_sizes[-1], final_val_acc - 0.035, f"Val: {final_val_acc:.4f}", color='orange')
    plt.text(train_sizes[-1] * 0.5, min(val_mean) - 0.06,
             f"Δ (Train - Val): {delta:.4f}", fontsize=10, style='italic', color='gray')

    # Labels and formatting
    plt.xlabel("Training Set Size")
    plt.ylabel("Accuracy")
    title = f"Learning Curve for {label}" if label else "Learning Curve"
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_feature_importances(model, X):
    importances = pd.Series(model.feature_importances_, index=X.columns)
    importances = importances.sort_values(ascending=False)

    # Print feature importances in a grid format
    importance_df = pd.DataFrame({
        'Feature': importances.index,
        'Importance': importances.values
    })
    print("\nEstimator Feature Importances:\n")
    print(importance_df.to_string(index=False))

    # Plot
    plt.figure(figsize=(8, 5))
    ax = importances.plot(kind='bar')
    plt.title(f"Feature Importances from {model.__class__.__name__}")
    plt.ylabel("Relative Importance")
    
    # Add value labels above each bar
    for i, value in enumerate(importances):
        plt.text(i, value + 0.001, f"{value:.3f}", ha='center', va='bottom', fontsize=9)
    
    plt.tight_layout()
    plt.show()

def analyze_mistake_overrepresentation(worst_fold_mistakes, full_df):
    bool_cols = worst_fold_mistakes.select_dtypes(bool).columns
    mistake_counts = worst_fold_mistakes[bool_cols].sum()
    full_counts = full_df[bool_cols].sum()
    full_counts = full_counts.replace(0, pd.NA)
    ratio = (mistake_counts / full_counts).sort_values(ascending=False)
    comparison_df = pd.DataFrame({
        'Mistake_Count': mistake_counts,
        'Train_Count': full_counts,
        'Overrepresentation_Rate': ratio
    }).dropna().sort_values(by='Overrepresentation_Rate', ascending=False)
    return comparison_df

def plot_feature_cooccurrence_heatmap(worst_fold_mistakes, focus_col, exclude_cols=None):
    """
    Creates a heatmap showing the number of mistakes where focus_col and each other feature are both 1.
    
    Parameters:
    - worst_fold_mistakes: DataFrame containing only the mistaken predictions
    - focus_col: The binary feature to cross with all others (e.g. 'Pclass_3')
    - exclude_cols: Optional list of columns to ignore (e.g. ['Actual', 'Predicted'])
    """
    if exclude_cols is None:
        exclude_cols = ['Actual', 'Predicted']
    feature_cols = [col for col in worst_fold_mistakes.columns if col not in exclude_cols + [focus_col]]

    # Filter to rows where focus_col == 1
    relevant_mistakes = worst_fold_mistakes[worst_fold_mistakes[focus_col] == 1]

    # Count co-occurrences
    counts = {}
    for col in feature_cols:
        counts[col] = (relevant_mistakes[col] == 1).sum()
    
    # Convert to DataFrame for heatmap
    df_counts = pd.DataFrame.from_dict(counts, orient='index', columns=['Mistake_Count']).sort_values('Mistake_Count', ascending=False)

    # Plot
    plt.figure(figsize=(8, len(df_counts) * 0.4 + 1))
    sns.heatmap(df_counts.T, annot=True, cmap='Reds', cbar=False, fmt='d')
    plt.title(f"Mistake Counts When {focus_col} == 1")
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %%
# Create reusable methods to accelerate feature experimentation

# PT 5/13: Deciding not to reweight sample for now as engineering/encoding reduced KL divergences to < 0.02
def compute_sample_weights(X_train, X_test, stratify_cols):
    
    # Compute combined stratify key
    if stratify_cols:
        train_keys = X_train[stratify_cols].astype(str).agg('_'.join, axis=1)
        test_keys = X_test[stratify_cols].astype(str).agg('_'.join, axis=1)
    
        # Compute frequencies
        train_dist = train_keys.value_counts(normalize=True)
        test_dist = test_keys.value_counts(normalize=True)
    
        # Compute sample weights
        weights = train_keys.map(lambda key: test_dist.get(key, 0) / train_dist.get(key, 1)).fillna(0)
        sample_weights = weights.values
    else:
        sample_weights = np.ones(len(X_train))
    
    return sample_weights

def iterate_model(selected_features=[], drop_cols=[], feature_importances=False, permutation_importances=False, learning_curve=False, analyze_mistakes=True, **model_params):

    X_train_selected = prepared_train_df[selected_features].copy() 
    X_test_selected = prepared_test_df[selected_features].copy()
    y_train_full = prepared_train_df['Survived']
  
    clf = XGBClassifier(**model_params)

    if drop_cols:
        X_train_selected.drop(columns=drop_cols, inplace=True)
        X_test_selected.drop(columns=drop_cols, inplace=True)
        print(f"\nDropping these variables from model input:")
        for col in drop_cols:
            print(f"* {col}")

    print(f"\nEvaluating {clf.__class__.__name__} model with the following variables:")
    for col in X_train_selected.columns:
        print(f"* {col}")
        
    # feature_to_boost = 'FemaleTitle_YAdult_P3_False'
    # boost = 12
    # print(f"\nBoosting weights for {feature_to_boost} with factor {boost}:")
    # mask = X_train_encoded[feature_to_boost] == True
    sample_weights = np.ones(len(X_train_selected))  
    # sample_weights[mask] *= boost
    # sample_weights /= np.mean(sample_weights)
    # print(np.unique(sample_weights, return_counts=True))
    
    cv_scores = []
    fold_indices = []
    all_preds = []
    oof_preds = np.zeros_like(y_train_full)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for train_idx, test_idx in skf.split(X_train_selected, y_train_full):
        X_train, X_val = X_train_selected.iloc[train_idx], X_train_selected.iloc[test_idx]
        y_train, y_val = y_train_full.iloc[train_idx], y_train_full.iloc[test_idx]

        clf.fit(X_train, y_train, sample_weight=sample_weights[train_idx])
        preds = clf.predict(X_val)

        cv_scores.append(accuracy_score(y_val, preds))
        fold_indices.append((train_idx, test_idx))
        all_preds.append(preds)
        oof_preds[test_idx] = preds
                         
    worst_fold_idx = np.argmin(cv_scores)
    worst_test_idx = fold_indices[worst_fold_idx][1]

    X_worst = X_train_selected.iloc[worst_test_idx].copy()
    y_worst = y_train_full.iloc[worst_test_idx].copy()
    preds_worst = all_preds[worst_fold_idx]
    
    mistakes = X_worst[y_worst != preds_worst].copy()
    mistakes['Actual'] = y_worst[y_worst != preds_worst]
    mistakes['Predicted'] = preds_worst[y_worst != preds_worst]

    print(f"\nCV Scores: {cv_scores}")
    print(f"Worst Fold Index: {worst_fold_idx}")
    print(f"Mean Accuracy: {np.mean(cv_scores):.4f}")
    print(f"Standard Deviation: {np.std(cv_scores):.4f}")

    ## Retrain classifier will full training dataset + sample weights
    clf.fit(X_train_selected, y_train_full, sample_weight=sample_weights)

    if learning_curve:
        plot_learning_curve(clf, X_train_selected, y_train_full, label=f"{len(X_train_selected.columns)} columns") 
    
    if feature_importances:   
        plot_feature_importances(clf, X_train_selected)

    if permutation_importances:
        result = permutation_importance(clf, X_train_selected, y_train_full, n_repeats=10, random_state=42, scoring='accuracy')
        importances = pd.DataFrame({
            'feature': X_train_selected.columns,
            'importance_mean': result.importances_mean,
            'importance_std': result.importances_std
        }).sort_values(by='importance_mean', ascending=False)
        print("\nPermutation Importances:")
        print(importances)
        print()

    corr_df = get_highly_correlated_feature_pairs(X_train_selected, threshold=0.85)
    importance_dict = dict(zip(clf.feature_names_in_, clf.feature_importances_))
    features_to_drop = identify_lower_importance_correlated_features_to_drop(corr_df, importance_dict)
    print(f"Found {len(features_to_drop)} feature(s) to drop.\n\n")

    # Return (fitted model, filtered test_df, mistakes, filtered train_df) tuple for submission pipeline
    return clf, X_test_selected, oof_preds, X_train_selected

# %% [markdown]
# #### Baseline Establishment

# %% [markdown]
# Baseline accuracy scores are established to gauge the progress and efficacy of developing models using our engineered features.

# %% [markdown]
# ##### Predict Majority Class

# %% [markdown]
# First baseline taken simply calculates the accuracy of a simulated prediction output that assigns every passenger to the majority target class.
# * **Baseline Accuracy of Predicting Majority Class:** 62%

# %%
# Create a majority-class series and score it against the target values in the training data
target = prepared_train_df['Survived']
majority_class = target.mode()[0]
baseline_majority = pd.Series([majority_class] * len(target))
baseline_accuracy = accuracy_score(target, baseline_majority)
print(f"Baseline majority-class accuracy: {baseline_accuracy:.2f}")
# Out:
# Baseline majority-class accuracy: 0.62

# %% [markdown]
# ##### Predict Simple Model

# %% [markdown]
# * This baseline trains an `XGBoostClassifier` using only one-hot encoded Pclass_Sex features to evaluate their standalone predictive power.
# * A 5-fold stratified cross-validation setup is used to train and evaluate the model. Accuracy is calculated as the mean across folds, with the Kth fold used as "unseen" validation data each iteration.
# * In addition to model accuracy, we capture diagnostics to guide future iterations:
#     * **Learning Curve:** Plots the model's accuracy in predicting the training set and the validation (unseen) set as it increases training set size.  Helps quickly assess the extent to which the model is overfitting or underfitting the data.
#     * **Feature Importances:** Reports which features the model relied on the most when making decisions.
#     * **Permutation Importances:** Tests how much each feature affects model accuracy by randomly shuffling its values.

# %% [markdown]
# **Summary Observations:**
#
# * **Average Accuracy of XGBClassifier with Pclass_Sex OHE Features Only:** 77.4%
#  * **Learning Curve:**  Suggests model slight underfitting, as can be seen by training and validation accuracy decreasing in close proximity as training set size increases
# * **Feature Importances:**
#     * Feature contributions are relatively balanced in that no feature is dominating the model's decision making at the expensive of others.
#     * Most used feature is `Pclass_Sex_3_female`, used in 35.4% of model splits
#     * Least used feature is `Pclass_Sex_1_female`, used in 5.7% of model splits
# * **Permutation Importances:**
#     * Surprisingly, the `Pclass_Sex_3_female` feature -- the most used feature -- has the _lowest_ Permutation Importance with a mean of 0.07%
#     * This suggests the model may be overusing this feature despite its limited true value, possibly due to group imbalances or confounded patterns

# %%
baseline_input_features = pclass_sex_oh_cols
baseline_drop_cols = []
baseline_model, baseline_X_test_encoded, worst_fold_mistakes, X_train_encoded = iterate_model(
    baseline_input_features, 
    baseline_drop_cols, 
    feature_importances=True,
    permutation_importances=True,
    learning_curve=True
)
# Out:
# Evaluating XGBClassifier model with the following variables:
# * Pclass_Sex_1_female
# * Pclass_Sex_1_male
# * Pclass_Sex_2_female
# * Pclass_Sex_2_male
# * Pclass_Sex_3_female
# * Pclass_Sex_3_male
#
# CV Scores: [0.7821229050279329, 0.7640449438202247, 0.7696629213483146, 0.7640449438202247, 0.7921348314606742]
# Worst Fold Index: 1
# Mean Accuracy: 0.7744
# Standard Deviation: 0.0111
# Estimator Feature Importances:
#
#             Feature  Importance
# Pclass_Sex_3_female    0.353995
#   Pclass_Sex_3_male    0.291663
#   Pclass_Sex_2_male    0.143335
# Pclass_Sex_1_female    0.081116
# Pclass_Sex_2_female    0.072465
#   Pclass_Sex_1_male    0.057427
# Permutation Importances:
#                feature  importance_mean  importance_std
# 5    Pclass_Sex_3_male         0.168911        0.010942
# 3    Pclass_Sex_2_male         0.073850        0.004071
# 0  Pclass_Sex_1_female         0.046352        0.009629
# 2  Pclass_Sex_2_female         0.034007        0.010014
# 1    Pclass_Sex_1_male         0.031987        0.003339
# 4  Pclass_Sex_3_female         0.000673        0.007137
#
# Features with correlation ≥ 0.85 and lower importance:
#
# Found 0 feature(s) to drop.

# %% [markdown]
# #### Engineered Features Test

# %%
selected_feature_list = pclass_sex_oh_cols.tolist() + smoothed_feature_cols
selected_drop_cols = [
    "P1_Male_smoothed",
    "P2_Male_smoothed",
    "P3_Male_smoothed",
    "P2_Male_HasCabin_smoothed",
    "P2_Male_Cabin_Location_s_smoothed",
    "Pclass_Sex_1_female",
    "Pclass_Sex_3_male",
    "Pclass_Sex_1_male",
    "Pclass_Sex_2_male",
    "P1_Female_Parch_smoothed",
    "P3_Male_Age_Group_smoothed",
    "P1_Female_Cabin_count_smoothed",
    "P2_Male_Age_Group_smoothed",

    # Not dropping despite correlation warning given postive accuracy effect
    #"P3_Female_Embarked_smoothed",
]
submission_model, submission_X_test_selected, oof_preds, X_train_selected = iterate_model(selected_feature_list, selected_drop_cols, feature_importances=True, permutation_importances=True,
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    subsample=1,
    colsample_bytree=1,
    min_child_weight=1,
    gamma=0,
    reg_alpha=0,
    reg_lambda=1,
    eval_metric='error'  # or 'auc', 'error', etc. depending on your task  
                                                                                                  
    # n_estimators=500,         
    # learning_rate=0.01,        
    # max_depth=4,             
    # min_child_weight=3,        
    # gamma=0,                                                                                        
    # subsample=0.8,            
    # colsample_bytree=0.8,    
    # reg_alpha=0.1,      
    # reg_lambda=5,                                                                                         
    # objective='binary:logistic',  
    # eval_metric='error',    
    # random_state=42               
)
# Out:
# Dropping these variables from model input:
# * P1_Male_smoothed
# * P2_Male_smoothed
# * P3_Male_smoothed
# * P2_Male_HasCabin_smoothed
# * P2_Male_Cabin_Location_s_smoothed
# * Pclass_Sex_1_female
# * Pclass_Sex_3_male
# * Pclass_Sex_1_male
# * Pclass_Sex_2_male
# * P1_Female_Parch_smoothed
# * P3_Male_Age_Group_smoothed
# * P1_Female_Cabin_count_smoothed
# * P2_Male_Age_Group_smoothed
#
# Evaluating XGBClassifier model with the following variables:
# * Pclass_Sex_2_female
# * Pclass_Sex_3_female
# * P2_Male_Parch_smoothed
# * P3_Female_Embarked_smoothed
# * P2_Male_Cabin_count_smoothed
# * P3_Male_Cabin_count_smoothed
# * P2_Male_Deck_smoothed
# * P3_Male_Deck_smoothed
# * P2_Male_Title_smoothed
# * P3_Male_Title_smoothed
# * P1_Female_Age_Group_smoothed
# * P1_Male_Age_Group_smoothed
#
# CV Scores: [0.8268156424581006, 0.8258426966292135, 0.7921348314606742, 0.8426966292134831, 0.8314606741573034]
# Worst Fold Index: 2
# Mean Accuracy: 0.8238
# Standard Deviation: 0.0169
#
# Estimator Feature Importances:
#
#                      Feature  Importance
# P2_Male_Cabin_count_smoothed    0.331970
# P3_Male_Cabin_count_smoothed    0.255678
#          Pclass_Sex_3_female    0.126801
#          Pclass_Sex_2_female    0.093064
# P1_Female_Age_Group_smoothed    0.061614
#       P2_Male_Title_smoothed    0.048831
#   P1_Male_Age_Group_smoothed    0.032257
#  P3_Female_Embarked_smoothed    0.024293
#       P3_Male_Title_smoothed    0.017711
#       P2_Male_Parch_smoothed    0.007781
#        P2_Male_Deck_smoothed    0.000000
#        P3_Male_Deck_smoothed    0.000000
# Permutation Importances:
#                          feature  importance_mean  importance_std
# 5   P3_Male_Cabin_count_smoothed         0.184848        0.010014
# 10  P1_Female_Age_Group_smoothed         0.047587        0.008372
# 0            Pclass_Sex_2_female         0.038047        0.007848
# 11    P1_Male_Age_Group_smoothed         0.037598        0.003558
# 3    P3_Female_Embarked_smoothed         0.024355        0.004816
# 1            Pclass_Sex_3_female         0.021886        0.004924
# 8         P2_Male_Title_smoothed         0.012570        0.001931
# 4   P2_Male_Cabin_count_smoothed         0.011897        0.002311
# 9         P3_Male_Title_smoothed         0.001235        0.000337
# 2         P2_Male_Parch_smoothed         0.000898        0.001489
# 6          P2_Male_Deck_smoothed         0.000000        0.000000
# 7          P3_Male_Deck_smoothed         0.000000        0.000000
#
# Features with correlation ≥ 0.85 and lower importance:
#
# Drop: P2_Male_Deck_smoothed          (Importance: 0.00000)  ⬅️ Keep: P2_Male_Cabin_count_smoothed   (Importance: 0.33197)
# Drop: P3_Male_Deck_smoothed          (Importance: 0.00000)  ⬅️ Keep: P3_Male_Cabin_count_smoothed   (Importance: 0.25568)
# Drop: P3_Female_Embarked_smoothed    (Importance: 0.02429)  ⬅️ Keep: Pclass_Sex_3_female            (Importance: 0.12680)
# Drop: P2_Male_Parch_smoothed         (Importance: 0.00778)  ⬅️ Keep: P2_Male_Title_smoothed         (Importance: 0.04883)
# Found 4 feature(s) to drop.

# %% [markdown]
# #### Out-of-Fold Prediction Mistake Analysis

# %%
def compute_oof_subgroup_mistakes(oof_preds, y_true, group_col, train_df):
    """
    Computes number of mistakes per group based on out-of-fold predictions.

    Args:
        oof_preds (np.ndarray or pd.Series): Out-of-fold predicted labels (0/1).
        y_true (np.ndarray or pd.Series): Ground truth labels.
        group_col (str): Column name in train_df to group by (e.g., 'Pclass_Sex').
        train_df (pd.DataFrame): DataFrame that includes the group_col.

    Returns:
        pd.DataFrame: Mistake counts and mistake rates by group.
    """
    df = train_df.copy()
    df['y_true'] = y_true
    df['y_pred'] = oof_preds
    df['mistake'] = df['y_true'] != df['y_pred']

    result = (
        df.groupby(group_col)
          .agg(
              Mistake_Count=('mistake', 'sum'),
              Train_Count=(group_col, 'count')
          )
          .assign(Mistake_Rate=lambda d: d['Mistake_Count'] / d['Train_Count'])
          .sort_values('Mistake_Count', ascending=False)
    )

    return result

# %% [markdown]
# * The following data counts the number of mistakes generated for each `Pclass_Sex` group found in the training set.
# * We see the most mistakes were made within the `3_female` group, which is the 2nd largest group represented in the training set.

# %%
prepared_train_df['Pclass_Sex'] = (
    prepared_train_df['Pclass'].astype(str) + '_' + prepared_train_df['Sex'].astype(str)
)
oof_mistakes_df = compute_oof_subgroup_mistakes(
    oof_preds=oof_preds, 
    y_true=prepared_train_df['Survived'], 
    group_col="Pclass_Sex", 
    train_df=prepared_train_df
)
display(oof_mistakes_df)
# Out:
#             Mistake_Count  Train_Count  Mistake_Rate
# Pclass_Sex
# 3_female               50          144      0.347222
# 3_male                 47          347      0.135447
# 1_male                 41          122      0.336066
# 2_male                 10          108      0.092593
# 2_female                6           76      0.078947
# 1_female                3           94      0.031915

# %% [markdown]
# #### SHAP Analysis of Mistakes

# %% [markdown]
# * We use SHAP analysis to understand the magnitude and direction each feature contributes to the model's _mistaken_ prediction of `3_female` survival.
# * The analysis revealed that **9 of the 11 features** used were not intended to affect `3_female` survival.
# * The model used the following features to predict the survival of a `3_female`, all irrelevant to the class:
#     * `P3_Male_Cabin_count_smoothed`
#     * `P1_Female_Age_Group_smoothed`
#     * `P2_Male_Cabin_count_smoothed`
#     * `Pclass_Sex_2_female`
#     * `P1_Male_Age_Group_smoothed`
#     * `P2_Male_Title_smoothed`
#     * `P3_Male_Title_smoothed`
# * The only two features relevant to `3_female` were `P3_Female_Embarked_smoothed` and `Pclass_Sex_3_female`.
#
# **Assessment:**
# * The model is using features irrelevant to a `Pclass_Sex` subgroup when developing prediction rules for that subgroup.
# * In order to isolate the features to only influence their own `Pclass_Sex` subgroup, a separate model will be trained for each subgroup, with each subgroup model being trained only on the features relevant to its subgroup.

# %%
# Zoom in on 3_female mistakes
mask_3_female = (prepared_train_df['Pclass'] == 3) & (prepared_train_df['Sex'] == 'female')
X_3_female = X_train_selected[mask_3_female]
mistake_mask = (oof_preds != prepared_train_df['Survived']) & mask_3_female
X_3_female_mistakes = X_train_selected[mistake_mask]
explainer = shap.Explainer(submission_model)
X_shap_safe = X_3_female_mistakes.copy()
X_shap_safe.fillna(0.0, inplace=True)  # or 0.0, if neutral
shap_values = explainer(X_shap_safe)

# %%
shap.plots.beeswarm(shap_values, show=False)
plt.title("3_female SHAP Values")
plt.show()

# %%
def plot_survival_probability_vs_actual_survival(one_hot_feature):
    y_train_full = prepared_train_df['Survived']
    group_mask = X_train_encoded[one_hot_feature] == 1
    X_group = X_train_encoded[group_mask]
    y_group = y_train_full[group_mask]
    y_group_proba = submission_model.predict_proba(X_group)[:, 1]  # Probability of survival (class 1)
    df_probs = pd.DataFrame({
        'Actual': y_group.values,
        'Predicted_Prob': y_group_proba
    })
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='Actual', y='Predicted_Prob', data=df_probs)
    plt.title(f"Predicted Survival Probability vs Actual Class\n({one_hot_feature} == 1)")
    plt.xlabel("Actual Survival (0 = died, 1 = survived)")
    plt.ylabel("Predicted Survival Probability")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_false_prediction_SHAP_beeswarm(one_hot_feature, pos_or_neg=True):
    y_train_full = prepared_train_df['Survived']
    group_mask = X_train_encoded[one_hot_feature] == 1
    X_group = X_train_encoded[group_mask]
    y_group = y_train_full[group_mask]
    y_group_preds = submission_model.predict(X_group)
    if pos_or_neg:
        false_outcome = (y_group_preds == 1) & (y_group == 0)
    else:
        false_outcome = (y_group_preds == 0) & (y_group == 1)
    X_fo = X_group[false_outcome]
    X_fo = X_fo.astype(float)
    explainer = shap.Explainer(submission_model, X_fo)
    shap_values_fo = explainer(X_fo)
    shap.plots.beeswarm(shap_values_fo, max_display=15, show=False)
    plt.title(f"SHAP for False {"Positives" if pos_or_neg else "Negatives"} in ({one_hot_feature} == 1) group")
    plt.show()
    return X_fo

# %% [markdown]
# #### Pclass x Sex Subgroup Sample Size Analysis

# %% [markdown]
# * Sample size analysis of the individual `Pclass_Sex` subgroups revealed two classes significantly imbalanced to one target class:
#     * `1_female`: 91 survived, 3 did not survive
#     * `2_female`: 70 survived, 6 did not survive
# * **Given this data, I will  try simply hardcoding survival for all females in 1st and 2nd class in the submission test set.**
# * This narrows my modeling focus to 3rd class females, and 1st, 2nd, and 3rd class males.
# * Given modeling each subgroup separately reduces the sample sizes each model will train on, exploratory data analysis will be performed for each feature to investigate where binning and grouping can be performed to increase predictive power.

# %%
def check_group_class_balance(train_df, test_df, group_col, target_col, min_class_samples=10):
    """
    Checks whether each group in group_col has enough samples for each class in the target,
    using counts from the training set only. Test set is used for row count only.

    Args:
        train_df (pd.DataFrame): Your training DataFrame.
        test_df (pd.DataFrame): Your test DataFrame.
        group_col (str): Column containing the subgroup label (e.g., 'Pclass_Sex').
        target_col (str): Column name of the binary target variable (e.g., 'Survived').
        min_class_samples (int): Minimum number of samples required per class.

    Returns:
        pd.DataFrame: Table showing class counts per group and which are under threshold.
    """
    def get_class_counts(df, prefix):
        result = (
            df.groupby([group_col, target_col])
              .size()
              .unstack(fill_value=0)
        )
        if 0 not in result.columns:
            result[0] = 0
        if 1 not in result.columns:
            result[1] = 0
        return result.rename(columns={0: f"{prefix}_Count_0", 1: f"{prefix}_Count_1"})

    def get_group_counts(df, prefix):
        return df[group_col].value_counts().rename(f"{prefix}_Total").to_frame()

    train_summary = get_class_counts(train_df, "Train")
    test_counts = get_group_counts(test_df, "Test")

    combined = pd.concat([train_summary, test_counts], axis=1).fillna(0)
    combined["Min_Class_Count"] = combined[["Train_Count_0", "Train_Count_1"]].min(axis=1)
    combined["Too_Imbalanced"] = combined["Min_Class_Count"] < min_class_samples

    # Move Test_Total to the end
    test_total = combined.pop("Test_Total")
    combined["Test_Total"] = test_total

    return combined.reset_index()

# %%
check_group_class_balance(prepared_train_df, prepared_test_df, 'Pclass_Sex', 'Survived')
# Out:
#   Pclass_Sex  Train_Count_0  Train_Count_1  Min_Class_Count  Too_Imbalanced  \
# 0   1_female              3             91                3            True
# 1     1_male             77             45               45           False
# 2   2_female              6             70                6            True
# 3     2_male             91             17               17           False
# 4   3_female             72             72               72           False
# 5     3_male            300             47               47           False
#
#    Test_Total
# 0          50
# 1          57
# 2          30
# 3          63
# 4          72
# 5         146

# %% [markdown]
# #### Model-per-Subgroup Baseline Performance

# %% [markdown]
# * CV accuracy of initial subgroup models were mixed:
#     * `1_male`: 0.6397
#     * `2_male`: 0.9082
#     * `3_male`: 0.8559
#     * `1_female`: 0.9684**
#     * `2_female`: 0.9217**
#     * `3_female`: 0.6522
# * `1_female` and `2_female` accuracies will be ignored/unreliable due to majority target class imbalance cited above
# * Underfitting was expected for the `1_male` and `3_female` models given their relatively low number of features:
#     * `1_male`
#         * `P1_Male_smoothed`
#         * `P1_Male_Age_Group_smoothed`
#     * `2_male`
#         * `P2_Male_smoothed`
#         * `P2_Male_Parch_smoothed`
#         * `P2_Male_HasCabin_smoothed`
#         * `P2_Male_Cabin_Location_s_smoothed`
#         * `P2_Male_Deck_smoothed`
#         * `P2_Male_Title_smoothed`
#         * `P2_Male_Age_Group_smoothed`
#     * `3_male`
#         * `P3_Male_smoothed`
#         * `P3_Male_Deck_smoothed`
#         * `P3_Male_Title_smoothed`
#         * `P3_Male_Age_Group_smoothed`
#     * `3_female`
#         * `P3_Female_Embarked_smoothed`

# %%
def train_group_models(train_df, target_col, group_col, model_config, model_params=None,
                       show_feature_importances=False,
                       show_permutation_importance=False):
    """
    Trains models only for the specified groups in model_config using group-specific features and evaluation.

    Args:
        train_df (pd.DataFrame): The default/global training dataset.
        target_col (str): The name of the target column.
        group_col (str): Column to split the training into subgroups (e.g., 'Pclass_Sex').
        model_config (dict): Dict mapping group -> {
            'features': [...],
            'drop_cols': [...],
            'train_df': pd.DataFrame (optional, overrides global train_df)
        }.
        model_params (dict): Parameters for XGBClassifier.
        show_feature_importances (bool): Whether to show feature importance plots.
        show_permutation_importance (bool): Whether to show permutation importance plots.

    Returns:
        models (dict): group -> trained model
        oof_dfs (dict): group -> out-of-fold predictions DataFrame
    """
    model_params = model_params or {}
    models = {}
    oof_dfs = {}

    for group_value, config in model_config.items():
        print(f"\n\n===== Training model for group: {group_value} =====")

        group_train_df = config.get('train_df', train_df)
        group_mask = group_train_df[group_col] == group_value
        group_data = group_train_df[group_mask].copy()
        
        X = group_data[config['features']].copy()
        if 'drop_cols' in config:
            X.drop(columns=config['drop_cols'], inplace=True, errors='ignore')
        y = group_data[target_col]

        # Check multicollinearity
        corr_matrix = X.corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        highly_corr_pairs = [(col1, col2, corr_matrix.loc[col1, col2])
                             for col1 in upper.columns for col2 in upper.columns
                             if upper.loc[col1, col2] > 0.85]

        if highly_corr_pairs:
            print("\n⚠️  Highly correlated feature pairs (corr > 0.85):")
            for f1, f2, val in highly_corr_pairs:
                print(f"- {f1} vs {f2}: corr={val:.2f}")

        clf = XGBClassifier(**model_params)
        cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        cv_scores = []

        oof_data = []

        for i, (train_idx, val_idx) in enumerate(cv.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

            clf.fit(X_train, y_train)
            preds = clf.predict(X_val)
            acc = accuracy_score(y_val, preds)
            cv_scores.append(acc)
            print(f"Fold {i + 1} accuracy: {acc:.4f}")

            fold_df = X_val.copy()
            fold_df['y_true'] = y_val
            fold_df['y_pred'] = preds
            oof_data.append(fold_df)

        print(f"Average CV accuracy: {np.mean(cv_scores):.4f}")
        models[group_value] = clf
        oof_dfs[group_value] = pd.concat(oof_data).reset_index(drop=True)

        if show_feature_importances:
            importances = clf.feature_importances_
            fi_df = pd.DataFrame({"feature": X.columns, "importance": importances})
            fi_df = fi_df.sort_values(by="importance", ascending=False)
            plt.figure()
            sns.barplot(data=fi_df, x="importance", y="feature")
            plt.title(f"Feature Importances: {group_value}")
            plt.show()

        if show_permutation_importance:
            result = permutation_importance(clf, X, y, n_repeats=10, random_state=42, scoring='accuracy')
            pi_df = pd.DataFrame({
                'feature': X.columns,
                'importance_mean': result.importances_mean,
                'importance_std': result.importances_std
            }).sort_values(by='importance_mean', ascending=False)
            print("\nPermutation Importances:")
            print(pi_df.to_string(index=False))

    return models, oof_dfs

# %%
model_config = {
    '1_male': {
        'features': [
            'P1_Male_smoothed',
            'P1_Male_Age_Group_smoothed',
        ],
        'drop_cols': []
    },
    '2_male': {
        'features': [
            'P2_Male_smoothed',
            'P2_Male_Parch_smoothed',
            'P2_Male_HasCabin_smoothed',
            'P2_Male_Cabin_count_smoothed',
            'P2_Male_Cabin_Location_s_smoothed',
            'P2_Male_Deck_smoothed',
            'P2_Male_Title_smoothed',
            'P2_Male_Age_Group_smoothed',
        ],
        'drop_cols': [
            'P2_Male_Title_smoothed'
        ]
    },
    '3_male': {
        'features': [
            'P3_Male_smoothed',
            'P3_Male_Cabin_count_smoothed',
            'P3_Male_Deck_smoothed',
            'P3_Male_Title_smoothed',
            'P3_Male_Age_Group_smoothed',
        ],
        'drop_cols': []
    },
    '1_female': {
        'features': [
            'P1_Female_Parch_smoothed',
            'P1_Female_Cabin_count_smoothed',
            'P1_Female_Age_Group_smoothed'
        ],
        'drop_cols': []
    },
    '2_female': {
        'features': [
            # No stats sig associations with new, will add redundant OHE col to not prevent array OOB error
            'Pclass_Sex_2_female'
        ],
        'drop_cols': []
    },
    '3_female': {
        'features': [
            'P3_Female_Embarked_smoothed'
        ],
        'drop_cols': []
    },
}

# %%
models = train_group_models(
    train_df=prepared_train_df,
    target_col='Survived',
    group_col='Pclass_Sex',
    model_config=model_config,
    model_params={'n_estimators': 100, 'max_depth': 3, 'random_state': 42},
    show_feature_importances=True,
    show_permutation_importance=True
)
# Out:
# ===== Training model for group: 1_male =====
# Fold 1 accuracy: 0.6000
# Fold 2 accuracy: 0.6400
# Fold 3 accuracy: 0.6667
# Fold 4 accuracy: 0.6250
# Fold 5 accuracy: 0.6667
# Average CV accuracy: 0.6397
# Permutation Importances:
#                    feature  importance_mean  importance_std
# P1_Male_Age_Group_smoothed         0.034426        0.020011
#           P1_Male_smoothed         0.000000        0.000000
#
#
# ===== Training model for group: 2_male =====
# Fold 1 accuracy: 0.9091
# Fold 2 accuracy: 0.9091
# Fold 3 accuracy: 0.8182
# Fold 4 accuracy: 1.0000
# Fold 5 accuracy: 0.9048
# Average CV accuracy: 0.9082
# Permutation Importances:
#                           feature  importance_mean  importance_std
#        P2_Male_Age_Group_smoothed         0.122222        0.016973
#                  P2_Male_smoothed         0.000000        0.000000
#            P2_Male_Parch_smoothed         0.000000        0.000000
#         P2_Male_HasCabin_smoothed         0.000000        0.000000
#      P2_Male_Cabin_count_smoothed         0.000000        0.000000
# P2_Male_Cabin_Location_s_smoothed         0.000000        0.000000
#             P2_Male_Deck_smoothed         0.000000        0.000000
#
#
# ===== Training model for group: 3_male =====
# Fold 1 accuracy: 0.8571
# Fold 2 accuracy: 0.8571
# Fold 3 accuracy: 0.8696
# Fold 4 accuracy: 0.8261
# Fold 5 accuracy: 0.8696
# Average CV accuracy: 0.8559
# Permutation Importances:
#                      feature  importance_mean  importance_std
#             P3_Male_smoothed              0.0             0.0
# P3_Male_Cabin_count_smoothed              0.0             0.0
#        P3_Male_Deck_smoothed              0.0             0.0
#       P3_Male_Title_smoothed              0.0             0.0
#   P3_Male_Age_Group_smoothed              0.0             0.0
#
#
# ===== Training model for group: 1_female =====
# Fold 1 accuracy: 1.0000
# Fold 2 accuracy: 0.9474
# Fold 3 accuracy: 0.9474
# Fold 4 accuracy: 0.9474
# Fold 5 accuracy: 1.0000
# Average CV accuracy: 0.9684
# C:\Users\pault\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# Permutation Importances:
#                        feature  importance_mean  importance_std
#       P1_Female_Parch_smoothed              0.0             0.0
# P1_Female_Cabin_count_smoothed              0.0             0.0
#   P1_Female_Age_Group_smoothed              0.0             0.0
#
#
# ===== Training model for group: 2_female =====
# Fold 1 accuracy: 0.8750
# Fold 2 accuracy: 0.9333
# Fold 3 accuracy: 0.9333
# Fold 4 accuracy: 0.9333
# Fold 5 accuracy: 0.9333
# Average CV accuracy: 0.9217
# Permutation Importances:
#             feature  importance_mean  importance_std
# Pclass_Sex_2_female              0.0             0.0
#
#
# ===== Training model for group: 3_female =====
# Fold 1 accuracy: 0.6207
# Fold 2 accuracy: 0.6897
# Fold 3 accuracy: 0.5172
# Fold 4 accuracy: 0.8621
# Fold 5 accuracy: 0.5714
# Average CV accuracy: 0.6522
# Permutation Importances:
#                     feature  importance_mean  importance_std
# P3_Female_Embarked_smoothed         0.155556        0.027639

# %% [markdown]
# ### Pclass x Sex Subgroup Development

# %% [markdown]
# Given baseline subgroup model accuracy of the `2_male` and `3_male` models exceeds 85%, I will scope my subgroup development to `1_male` and `3_female` subgroups for now.

# %% [markdown]
# #### P1 Male

# %% [markdown]
# ##### P1 Male Desciptive Statistics

# %%
base_features = ['Pclass', 'Sex', 'Parch', 'SibSp', 'Embarked', 'HasCabin', 'Cabin_count', 'Cabin_Location_s', 'Deck', 'Title', 'Age', 'Age_Group', 'Fare', 'Fare_log']
p1_males_train_df = prepared_train_df[prepared_train_df['Pclass_Sex'] == '1_male'].copy()
p1_males_test_df = prepared_test_df[prepared_test_df['Pclass_Sex'] == '1_male'].copy()

# %%
p1_males_train_df[base_features].describe(include="all")
# Out:
#         Pclass   Sex       Parch       SibSp Embarked    HasCabin  \
# count    122.0   122  122.000000  122.000000      122  122.000000
# unique     NaN     1         NaN         NaN        3         NaN
# top        NaN  male         NaN         NaN        S         NaN
# freq       NaN   122         NaN         NaN       79         NaN
# mean       1.0   NaN    0.278689    0.311475      NaN    0.778689
# std        0.0   NaN    0.658853    0.546695      NaN    0.416842
# min        1.0   NaN    0.000000    0.000000      NaN    0.000000
# 25%        1.0   NaN    0.000000    0.000000      NaN    1.000000
# 50%        1.0   NaN    0.000000    0.000000      NaN    1.000000
# 75%        1.0   NaN    0.000000    1.000000      NaN    1.000000
# max        1.0   NaN    4.000000    3.000000      NaN    1.000000
#
#         Cabin_count Cabin_Location_s Deck Title         Age Age_Group  \
# count         122.0              122  122   122  122.000000       122
# unique          4.0                4    7     9         NaN         5
# top             1.0             port    C   Mr.         NaN     Adult
# freq           85.0               59   32   107         NaN        83
# mean            NaN              NaN  NaN   NaN   41.114098       NaN
# std             NaN              NaN  NaN   NaN   13.780246       NaN
# min             NaN              NaN  NaN   NaN    0.920000       NaN
# 25%             NaN              NaN  NaN   NaN   33.250000       NaN
# 50%             NaN              NaN  NaN   NaN   40.000000       NaN
# 75%             NaN              NaN  NaN   NaN   49.000000       NaN
# max             NaN              NaN  NaN   NaN   80.000000       NaN
#
#               Fare    Fare_log
# count   122.000000  122.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# mean     67.226127    3.797279
# std      77.548021    1.049017
# min       0.000000    0.000000
# 25%      27.728100    3.357876
# 50%      41.262500    3.743538
# 75%      78.459375    4.375209
# max     512.329200    6.240917

# %%
p1_males_test_df[base_features].describe(include="all")
# Out:
#         Pclass   Sex      Parch      SibSp Embarked   HasCabin  Cabin_count  \
# count     57.0    57  57.000000  57.000000       57  57.000000         57.0
# unique     NaN     1        NaN        NaN        2        NaN          5.0
# top        NaN  male        NaN        NaN        S        NaN          1.0
# freq       NaN    57        NaN        NaN       29        NaN         34.0
# mean       1.0   NaN   0.280702   0.403509      NaN   0.701754          NaN
# std        0.0   NaN   0.647919   0.529813      NaN   0.461555          NaN
# min        1.0   NaN   0.000000   0.000000      NaN   0.000000          NaN
# 25%        1.0   NaN   0.000000   0.000000      NaN   0.000000          NaN
# 50%        1.0   NaN   0.000000   0.000000      NaN   1.000000          NaN
# 75%        1.0   NaN   0.000000   1.000000      NaN   1.000000          NaN
# max        1.0   NaN   3.000000   2.000000      NaN   1.000000          NaN
#
#        Cabin_Location_s Deck Title        Age Age_Group        Fare   Fare_log
# count                57   57    57  57.000000        57   57.000000  57.000000
# unique                4    6     4        NaN         4         NaN        NaN
# top                port    M   Mr.        NaN     Adult         NaN        NaN
# freq                 23   17    52        NaN        44         NaN        NaN
# mean                NaN  NaN   NaN  40.701754       NaN   75.586551   3.951934
# std                 NaN  NaN   NaN  12.644472       NaN   66.339086   1.041058
# min                 NaN  NaN   NaN   6.000000       NaN    0.000000   0.000000
# 25%                 NaN  NaN   NaN  31.000000       NaN   27.720800   3.357622
# 50%                 NaN  NaN   NaN  42.000000       NaN   51.862500   3.967694
# 75%                 NaN  NaN   NaN  49.000000       NaN   83.158300   4.432700
# max                 NaN  NaN   NaN  67.000000       NaN  262.375000   5.573579

# %% [markdown]
# ##### P1 Male Distribution Shift Assessment

# %% [markdown]
# * <span style="color:orange">**Significant KL divergences found between `1_male` training and test data sets**</span>
# * Features where `KL > 0.02`:
#     * `Parch` 0.1416
#     * `SibSp` 0.1511
#     * `Embarked` 0.1643
#     * `Cabin_count` 0.0594
#     * `Cabin_Location_s` 0.0522
#     * `Deck` 0.1521
#     * `Title` 0.7590
#     * `Age` 9.4825
#     * `Age_Group` inf
#     * `Fare` 9.7836
# * Only feature where `KL < 0.02`: `HasCabin` 0.0150
# * Features must be engineered to reduce KL divergences to < 0.02 to mitigate overfitting risks

# %%
for base_feature in base_features:
    print_train_test_distributions_for_feature(base_feature, p1_males_train_df, p1_males_test_df)
# Out:
#    Pclass  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0       1          122          57          100.0         100.0
#
# KL Divergence: 0.0000
#
#     Sex  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0  male          122          57          100.0         100.0
#
# KL Divergence: 0.0000
#
#    Parch  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0      0           99        46.0          81.15         82.14
# 1      1           14         7.0          11.48         12.50
# 2      2            8         3.0           6.56          5.36
# 3      4            1         0.0           0.82          0.00
#
# KL Divergence: 0.1416
#
#    SibSp  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0      0           88        35.0          72.13         61.40
# 1      1           31        21.0          25.41         36.84
# 2      2            2         1.0           1.64          1.75
# 3      3            1         0.0           0.82          0.00
#
# KL Divergence: 0.1511
#
#   Embarked  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2        S           79        29.0          64.75         50.88
# 0        C           42        28.0          34.43         49.12
# 1        Q            1         0.0           0.82          0.00
#
# KL Divergence: 0.1643
#
#    HasCabin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 1         1           95          40          77.87         70.18
# 0         0           27          17          22.13         29.82
#
# KL Divergence: 0.0150
#
#   Cabin_count  Train_Count  Test_Count  Train_Percent  Test_Percent
# 1           1           85          34          69.67         61.82
# 0           0           27          17          22.13         30.91
# 2           2            6           3           4.92          5.45
# 3           3            4           1           3.28          1.82
#
# KL Divergence: 0.0594
#
#   Cabin_Location_s  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2             port           59        23.0          48.36         41.82
# 3        starboard           35        15.0          28.69         27.27
# 0    no_cabin_info           27        17.0          22.13         30.91
# 1  no_cabin_number            1         0.0           0.82          0.00
#
# KL Divergence: inf
#
#   Deck  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2    C           32        16.0          26.23         28.07
# 5    M           27        17.0          22.13         29.82
# 1    B           20         9.0          16.39         15.79
# 4    E           15         5.0          12.30          8.77
# 0    A           14         4.0          11.48          7.02
# 3    D           13         6.0          10.66         10.53
# 6    T            1         0.0           0.82          0.00
#
# KL Divergence: 0.1521
#
#        Title  Train_Count  Test_Count  Train_Percent  Test_Percent
# 7        Mr.          107        52.0          87.70         91.23
# 3        Dr.            4         1.0           3.28          1.75
# 6    Master.            3         2.0           2.46          3.51
# 1       Col.            2         2.0           1.64          3.51
# 5     Major.            2         0.0           1.64          0.00
# 0      Capt.            1         0.0           0.82          0.00
# 2       Don.            1         0.0           0.82          0.00
# 4  Jonkheer.            1         0.0           0.82          0.00
# 8       Sir.            1         0.0           0.82          0.00
#
# KL Divergence: 0.7590
#
#       Age  Train_Count  Test_Count  Train_Percent  Test_Percent
# 25  40.00           23         0.0          18.85          0.00
# 21  36.00            6         1.0           4.92          2.22
# 13  28.00            4         0.0           3.28          0.00
# 28  45.00            4         2.0           3.28          4.44
# 32  47.00            4         2.0           3.28          4.44
# 12  27.00            4         1.0           3.28          2.22
# 22  37.00            3         1.0           2.46          2.22
# 33  48.00            3         1.0           2.46          2.22
# 16  31.00            3         1.0           2.46          2.22
# 40  56.00            3         0.0           2.46          0.00
# 20  35.00            3         0.0           2.46          0.00
# 23  38.00            3         0.0           2.46          0.00
# 26  42.00            3        10.0           2.46         22.22
# 35  50.00            3         2.0           2.46          4.44
# 34  49.00            3         2.0           2.46          4.44
# 14  29.00            2         0.0           1.64          0.00
# 45  64.00            2         1.0           1.64          2.22
# 42  60.00            2         0.0           1.64          0.00
# 10  25.00            2         1.0           1.64          2.22
# 38  54.00            2         1.0           1.64          2.22
# 43  61.00            2         1.0           1.64          2.22
# 44  62.00            2         0.0           1.64          0.00
# 9   24.00            2         2.0           1.64          4.44
# 37  52.00            2         0.0           1.64          0.00
# 5   19.00            2         0.0           1.64          0.00
# 46  65.00            2         0.0           1.64          0.00
# 48  71.00            2         0.0           1.64          0.00
# 30  46.00            2         3.0           1.64          6.67
# 41  58.00            2         0.0           1.64          0.00
# 36  51.00            2         0.0           1.64          0.00
# 8   23.00            1         1.0           0.82          2.22
# 27  44.00            1         0.0           0.82          0.00
# 1    4.00            1         0.0           0.82          0.00
# 24  39.00            1         2.0           0.82          4.44
# 19  34.00            1         0.0           0.82          0.00
# 18  33.00            1         1.0           0.82          2.22
# 17  32.00            1         0.0           0.82          0.00
# 29  45.50            1         0.0           0.82          0.00
# 15  30.00            1         4.0           0.82          8.89
# 3   17.00            1         1.0           0.82          2.22
# 7   22.00            1         0.0           0.82          0.00
# 6   21.00            1         1.0           0.82          2.22
# 4   18.00            1         0.0           0.82          0.00
# 2   11.00            1         0.0           0.82          0.00
# 11  26.00            1         0.0           0.82          0.00
# 31  46.50            1         0.0           0.82          0.00
# 0    0.92            1         0.0           0.82          0.00
# 47  70.00            1         0.0           0.82          0.00
# 39  55.00            1         3.0           0.82          6.67
# 49  80.00            1         0.0           0.82          0.00
#
# KL Divergence: 9.4825
#
#      Age_Group  Train_Count  Test_Count  Train_Percent  Test_Percent
# 3        Adult           83        44.0          68.03         77.19
# 2  Young_Adult           21         7.0          17.21         12.28
# 4       Senior           14         3.0          11.48          5.26
# 0  Young_Child            2         0.0           1.64          0.00
# 1        Child            2         3.0           1.64          5.26
#
# KL Divergence: inf
#
#         Fare  Train_Count  Test_Count  Train_Percent  Test_Percent
# 7    26.5500           14         5.0          11.48         14.29
# 13   30.5000            5         1.0           4.10          2.86
# 31   52.0000            5         0.0           4.10          0.00
# 0     0.0000            5         2.0           4.10          5.71
# 21   35.5000            4         0.0           3.28          0.00
# ..       ...          ...         ...            ...           ...
# 62  151.5500            1         1.0           0.82          2.86
# 63  153.4625            1         0.0           0.82          0.00
# 64  211.5000            1         2.0           0.82          5.71
# 65  221.7792            1         1.0           0.82          2.86
# 35   55.9000            1         0.0           0.82          0.00
#
# [70 rows x 5 columns]
#
# KL Divergence: 9.7836
#
#     Fare_log  Train_Count  Test_Count  Train_Percent  Test_Percent
# 7   3.316003           14         5.0          11.48         14.29
# 13  3.449988            5         1.0           4.10          2.86
# 31  3.970292            5         0.0           4.10          0.00
# 0   0.000000            5         2.0           4.10          5.71
# 21  3.597312            4         0.0           3.28          0.00
# ..       ...          ...         ...            ...           ...
# 62  5.027492            1         1.0           0.82          2.86
# 63  5.039951            1         0.0           0.82          0.00
# 64  5.358942            1         2.0           0.82          5.71
# 65  5.406181            1         1.0           0.82          2.86
# 35  4.041295            1         0.0           0.82          0.00
#
# [70 rows x 5 columns]
#
# KL Divergence: 9.7836

# %% [markdown]
# ##### P1 Male Feature Engineering

# %% [markdown]
# ###### P1_Male_Parch_SibSp_bin

# %%
def create_feature_P1_Male_Parch_SibSp_bin(train_df, test_df):
    """
    Creates a binned version of the sum of Parch and SibSp for P1_Male.
    The new feature 'P1_Male_Parch_SibSp_bin' is categorical with values:
    - "0" for total=0
    - "1" for total=1
    - "2+" for total >=2

    Args:
        train_df (pd.DataFrame): Training subset for P1_Male.
        test_df (pd.DataFrame): Test subset for P1_Male.
    """
    for df in [train_df, test_df]:
        total = df['Parch'] + df['SibSp']
        df['P1_Male_Parch_SibSp_bin'] = pd.cut(
            total,
            bins=[-1, 0, 1, float('inf')],
            labels=['0', '1', '2+']
        ).astype('category').astype(str)

create_feature_P1_Male_Parch_SibSp_bin(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Parch_SibSp_bin', p1_males_train_df, p1_males_test_df)
# Out:
#   P1_Male_Parch_SibSp_bin  Train_Count  Test_Count  Train_Percent  \
# 0                       0           75          33          61.48
# 1                       1           31          14          25.41
# 2                      2+           16          10          13.11
#
#    Test_Percent
# 0         57.89
# 1         24.56
# 2         17.54
#
# KL Divergence: 0.0074

# %% [markdown]
# ###### P1_Male_Embarked_Is_S

# %%
def create_feature_P1_Male_Embarked_Is_S(train_df, test_df):
    for df in [train_df, test_df]:
        df['P1_Male_Embarked_Is_S'] = (df['Embarked'] == 'S').astype(int)

create_feature_P1_Male_Embarked_Is_S(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Embarked_Is_S', p1_males_train_df, p1_males_test_df)
# Out:
#    P1_Male_Embarked_Is_S  Train_Count  Test_Count  Train_Percent  Test_Percent
# 1                      1           79          29          64.75         50.88
# 0                      0           43          28          35.25         49.12
#
# KL Divergence: 0.0392

# %% [markdown]
# <span style="color:orange">**Distribution Shift for `P1_Male_Embarked_is_S`:**</span> KL > 0.02.  Use with caution.  Encoding to smoothed rate feature may help feature generalize to test data set.

# %% [markdown]
# ###### P1_Male_Cabin_count_bin

# %%
def create_feature_P1_Male_Cabin_count_bin(train_df, test_df):
    for df in [train_df, test_df]:
        cabin_count_int = df['Cabin_count'].astype(int)
        df['P1_Male_Cabin_count_bin'] = pd.cut(
            cabin_count_int,
            bins=[-1, 0, 1, float('inf')],
            labels=['0', '1', '2+']
        ).astype('category').astype(str)

create_feature_P1_Male_Cabin_count_bin(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Cabin_count_bin', p1_males_train_df, p1_males_test_df)
# Out:
#   P1_Male_Cabin_count_bin  Train_Count  Test_Count  Train_Percent  \
# 1                       1           85          34          69.67
# 0                       0           27          17          22.13
# 2                      2+           10           6           8.20
#
#    Test_Percent
# 1         59.65
# 0         29.82
# 2         10.53
#
# KL Divergence: 0.0217

# %% [markdown]
# ###### P1_Male Cabin_Location_s

# %% [markdown]
# **Usage of `Cabin_Location_s` for P1 Males will be avoided for now** given the <span style="color:orange">**large KL Divergence found**</span> both with existing values (KL = inf) as well as when merging the 'no_cabin_number` outlier with `no_cabin_info` (not shown, `KL > 0.02`).

# %% [markdown]
# ###### P1_Male_Deck_bin

# %% [markdown]
# * We use deck proximity to the lifeboats on the titanic to guide binning of decks .
#     * Lifeboats were located on the ship's top deck and therefore were more accessible to higher decks than lower decks (see References (1)).
# * The following bins are defined:
#     * `High_Access`: Decks `A` and `B`
#     * `Medium_Access`: Decks `C` and `D`
#     * `Low_Access` : Decks `E`, `M`, `T`
# * Implementing `P1_Male_Deck_bin` reduced distribution shift of decks to usable levels (KL = 0.0071)

# %%
def create_feature_P1_Male_Deck_bin(train_df, test_df):
    """
    Creates a categorical deck access feature for P1_Male group:
    - High_Access: Decks A, B
    - Medium_Access: Decks C, D
    - Low_Access: Decks E, M, T
    """
    access_map = {
        'A': 'High_Access',
        'B': 'High_Access',
        'C': 'Medium_Access',
        'D': 'Medium_Access',
        'E': 'Low_Access',
        'M': 'Low_Access',
        'T': 'Low_Access'
    }

    for df in [train_df, test_df]:
        df['P1_Male_Deck_bin'] = df['Deck'].map(access_map).astype('category')   

create_feature_P1_Male_Deck_bin(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Deck_bin', p1_males_train_df, p1_males_test_df)
# Out:
#   P1_Male_Deck_bin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2    Medium_Access           45          22          36.89         38.60
# 1       Low_Access           43          22          35.25         38.60
# 0      High_Access           34          13          27.87         22.81
#
# KL Divergence: 0.0071

# %%
plt.figure(figsize=(5,3))
sns.countplot(data=p1_males_train_df, x="P1_Male_Deck_bin", hue="Survived")
plt.title("All P1 Male Deck Bin Values")
plt.show()

survival_df = (
    p1_males_train_df
    .groupby("P1_Male_Deck_bin", observed=True)
    .agg(
        Survival_Rate=('Survived', 'mean'),
        Count=('Survived', 'size')
    )
    .reset_index()
    .sort_values(by="P1_Male_Deck_bin", ascending=True)
)
survival_df
# Out:
#   P1_Male_Deck_bin  Survival_Rate  Count
# 0      High_Access       0.411765     34
# 1       Low_Access       0.325581     43
# 2    Medium_Access       0.377778     45

# %% [markdown]
# ###### P1_Male_Title_bin

# %% [markdown]
# * We bin P1 Male titles into three groups: `Mr`, `Master`, and `Other`.
# * Doing so reduced P1 Male Title distribution shift to negligble levels (KL = 0.0182)

# %%
def create_feature_P1_Male_Title_bin(train_df, test_df):
    """
    Bins Title into three categories:
    - 'Mr'
    - 'Master'
    - 'Other' (includes all other rare titles)
    """
    def bin_title(title):
        if title == 'Mr.':
            return 'Mr'
        elif title == 'Master.':
            return 'Master'
        else:
            return 'Other'

    for df in [train_df, test_df]:
        df['P1_Male_Title_bin'] = df['Title'].apply(bin_title).astype('category')

create_feature_P1_Male_Title_bin(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Title_bin', p1_males_train_df, p1_males_test_df)
# Out:
#   P1_Male_Title_bin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 1                Mr          107          52          87.70         91.23
# 2             Other           12           3           9.84          5.26
# 0            Master            3           2           2.46          3.51
#
# KL Divergence: 0.0182

# %% [markdown]
# ###### P1_Male_Age_bin

# %% [markdown]
# * We revisit P1 Male Ages to identify age groups affording optimal sample sizes across groups.
# * We bin P1 Male Age into 5 new groups: `Young`, `Prime`, `Late-30s`, `Mid-40s`, and `Older`
# * Doing so reduced P1 Male Age distribution shift to borderline acceptable levels (KL = 0.0109)

# %%
def create_feature_P1_Male_Age_bin(train_df, test_df):
    """
    Bins Age into 5 categories to reduce distribution shift for 1_male.
    """
    def bin_age(val):
        if val < 25:
            return 'Young'
        elif val <= 36:
            return 'Prime'
        elif val <= 43:
            return 'Late-30s'
        elif val <= 50:
            return 'Mid-40s'
        else:
            return 'Older'

    for df in [train_df, test_df]:
        df['P1_Male_Age_bin'] = df['Age'].apply(bin_age).astype('category').astype(str)


create_feature_P1_Male_Age_bin(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Age_bin', p1_males_train_df, p1_males_test_df)
# Out:
#   P1_Male_Age_bin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0        Late-30s           33          16          27.05         28.07
# 3           Prime           29          11          23.77         19.30
# 2           Older           26          11          21.31         19.30
# 1         Mid-40s           22          12          18.03         21.05
# 4           Young           12           7           9.84         12.28
#
# KL Divergence: 0.0109

# %% [markdown]
# ###### P1_Male_Fare_log_bin

# %% [markdown]
# * We bin P1 Male Fares into four groups: `Low`, `Lower-Mid`, `Upper-Mid`, and `High`
# * Doing so reduced P1 Male Fare distribution shift to negligble levels (KL = 0.0116)

# %%
def create_feature_P1_Male_Fare_log_bin(train_df, test_df):
    """
    Bins the Fare_log feature into 4 bins to reduce KL divergence:
    - 'Low': < 3.15
    - 'Lower-Mid': 3.15 to < 3.55
    - 'Upper-Mid': 3.55 to < 4.5
    - 'High': >= 4.5
    """
    def bin_fare_log(val):
        if val < 3.15:
            return 'Low'
        elif val < 3.55:
            return 'Lower-Mid'
        elif val < 4.5:
            return 'Upper-Mid'
        else:
            return 'High'

    for df in [train_df, test_df]:
        df['P1_Male_Fare_log_bin'] = df['Fare_log'].apply(bin_fare_log).astype('category').astype(str)

create_feature_P1_Male_Fare_log_bin(p1_males_train_df, p1_males_test_df)

# %%
print_train_test_distributions_for_feature('P1_Male_Fare_log_bin', p1_males_train_df, p1_males_test_df)
# Out:
#   P1_Male_Fare_log_bin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 3            Upper-Mid           48          22          39.34         38.60
# 2            Lower-Mid           45          19          36.89         33.33
# 0                 High           23          14          18.85         24.56
# 1                  Low            6           2           4.92          3.51
#
# KL Divergence: 0.0116

# %% [markdown]
# ##### P1 Male Feature Chi-Square Testing

# %% [markdown]
# * Chi-squared testing showed `P1_Male_Age_bin` had a statistically-significant assocation with P1 Male Survival rates (p < 0.05).
# * We'll create a smoothed rate feature `P1_Male_Age_bin_smoothed` to capture the association and test with our model.

# %%
def analyze_subgroup_feature_x_survival(subgroup_name, feature, df, target_col='Survived', styled=True):
    """
    Run chi-squared test for a single feature within a Pclass_Sex subgroup.

    Args:
        subgroup_name (str): Subgroup identifier.
        feature (str): Feature to analyze.
        df (DataFrame): Dataset.
        target_col (str): Target column.
        styled (bool): Whether to return a styled DataFrame.

    Returns:
        DataFrame or Styler: Chi-squared results for the feature.
    """
    results = []
    subset = df[df['Pclass_Sex'] == subgroup_name].copy()
    contingency = pd.crosstab(index=subset[feature], columns=subset[target_col])

    if contingency.shape[0] < 2 or contingency.shape[1] < 2:
        return pd.DataFrame()

    chi2, p, dof, _ = chi2_contingency(contingency)
    results.append({
        'Pclass_Sex': subgroup_name,
        'Feature': feature,
        'Chi2': chi2,
        'p-value': p,
        'Degrees of Freedom': dof,
        'Significant': p < 0.05
    })

    df_result = pd.DataFrame(results)

    if styled:
        def highlight_significant(row):
            return ['background-color: lightgreen' if row['Significant'] else '' for _ in row]
        return df_result.style.apply(highlight_significant, axis=1)
    else:
        return df_result
        
def analyze_standalone_feature_batch(df, feature_list, target_col='Survived', subgroup_name=None):
    """
    Analyze a list of standalone features for statistical significance using chi-squared tests within a subgroup.

    Args:
        df (DataFrame): Dataset.
        feature_list (list): List of single-column feature names.
        target_col (str): Target column name (e.g., 'Survived').
        subgroup_name (str): Optional subgroup identifier (e.g., '1_male').

    Returns:
        Styler: Styled DataFrame with chi-squared test results.
    """
    results = []
    for feature in feature_list:
        result_df = analyze_subgroup_feature_x_survival(subgroup_name, feature, df, styled=False)
        if not result_df.empty:
            results.append(result_df)

    if not results:
        return pd.DataFrame()

    full_results = pd.concat(results).reset_index(drop=True)
    full_results = full_results.sort_values(by=['Pclass_Sex', 'Significant'], ascending=[True, False])

    def highlight_significant(row):
        return ['background-color: lightgreen' if row['Significant'] else '' for _ in row]

    return full_results.style.apply(highlight_significant, axis=1)

def analyze_composite_feature_subgroups(df, feature_1, feature_2, target_col='Survived', subgroup_name=None):
    """
    Perform chi-squared test on a composite of two features within a specific Pclass_Sex subgroup.
    
    Args:
                feature_1 (str): First feature for composite.
        feature_2 (str): Second feature for composite.
        target_col (str): Target column name.
        subgroup_name (str): Subgroup identifier, e.g. '2_male'.

    Returns:
        DataFrame: Chi-squared test results for the composite feature.
    """
    results = []
    if subgroup_name is None:
        raise ValueError("subgroup_name must be specified.")

    subset = df[df['Pclass_Sex'] == subgroup_name].copy()
    subset['composite_feature'] = subset[feature_1].astype(str) + "_x_" + subset[feature_2].astype(str)
    contingency = pd.crosstab(index=subset['composite_feature'], columns=subset[target_col])

    if contingency.shape[0] < 2 or contingency.shape[1] < 2:
        return pd.DataFrame()

    chi2, p, dof, _ = chi2_contingency(contingency)
    results.append({
        'Pclass_Sex': subgroup_name,
        'Feature': f'{feature_1} x {feature_2}',
        'Chi2': chi2,
        'p-value': p,
        'Degrees of Freedom': dof,
        'Significant': p < 0.05
    })

    df_result = pd.DataFrame(results).sort_values(by=['Pclass_Sex', 'Significant'], ascending=[True, False])
    return df_result

def analyze_composite_feature_batch(df, composite_pairs, target_col='Survived', subgroup_name=None):
    """
    Analyze a list of composite feature pairs for statistical significance within a subgroup.

    Args:
        df (DataFrame): Dataset.
        composite_pairs (list): List of tuples representing feature pairs.
        target_col (str): Target column name.
        subgroup_name (str): Subgroup identifier.

    Returns:
        Styler: Styled DataFrame with chi-squared test results.
    """
    results = []
    for feature_1, feature_2 in composite_pairs:
        result_df = analyze_composite_feature_subgroups(df, feature_1, feature_2, target_col, subgroup_name)
        if not result_df.empty:
            results.append(result_df)

    if not results:
        return pd.DataFrame()

    full_results = pd.concat(results).reset_index(drop=True)
    full_results = full_results.sort_values(by=['Pclass_Sex', 'Significant'], ascending=[True, False])

    def highlight_significant(row):
        return ['background-color: lightgreen' if row['Significant'] else '' for _ in row]

    return full_results.style.apply(highlight_significant, axis=1)

def create_smoothed_pclass_sex_composite_feature(train_df, test_df, pclass_val, sex_val, feature1, feature2, prior=10):
    """
    Creates a smoothed survival rate feature for a specific Pclass and Sex group,
    using the combination of two categorical features.

    Rules:
    - Include composite groups with n >= 10
    - Also include groups with 5 <= n < 10 if survival rate == 100%
    - Exclude groups with n < 5

    Args:
        train_df (pd.DataFrame): Training data used to compute survival statistics.
        test_df (pd.DataFrame): Test data where smoothed features will be applied.
        pclass_val (int): Pclass value to filter on (1, 2, or 3).
        sex_val (str): Sex value to filter on ('male' or 'female').
        feature1 (str): First feature in the composite key.
        feature2 (str): Second feature in the composite key.
        prior (int, optional): Smoothing strength. Default is 10.

    Returns:
        str: Name of the created smoothed feature.
    """
    mask = (train_df['Pclass'] == pclass_val) & (train_df['Sex'] == sex_val)
    subset_df = train_df[mask].copy()
    global_mean = train_df['Survived'].mean()

    composite_col = f'{feature1}__{feature2}'
    subset_df[composite_col] = subset_df[feature1].astype(str) + "__" + subset_df[feature2].astype(str)

    group_stats = (
        subset_df.groupby(composite_col, observed=True)['Survived']
        .agg(['mean', 'count'])
        .reset_index()
        .rename(columns={'mean': 'group_mean', 'count': 'group_count'})
    )

    included = group_stats[
        (group_stats['group_count'] >= 10) |
        ((group_stats['group_count'] >= 5) & (group_stats['group_mean'] == 1.0))
    ].copy()

    included['smoothed_rate'] = (
        (included['group_mean'] * included['group_count'] + prior * global_mean) /
        (included['group_count'] + prior)
    )

    col_name = f'P{pclass_val}_{sex_val.capitalize()}_{feature1}_{feature2}_smoothed'
    map_dict = included.set_index(composite_col)['smoothed_rate'].to_dict()

    # Create in train
    train_df[col_name] = 0.0
    train_df.loc[mask, col_name] = (
        subset_df[composite_col].map(map_dict)
    )

    # Create in test
    test_mask = (test_df['Pclass'] == pclass_val) & (test_df['Sex'] == sex_val)
    test_composite = (
        test_df.loc[test_mask, feature1].astype(str) + "__" +
        test_df.loc[test_mask, feature2].astype(str)
    )
    test_df[col_name] = 0.0
    test_df.loc[test_mask, col_name] = test_composite.map(map_dict)

    print(f"✅ Created {col_name}")
    print(train_df[col_name].describe())
    print()

    return col_name

# %%
standalone_candidates = [
    'P1_Male_Parch_SibSp_bin', 'P1_Male_Embarked_Is_S', 'P1_Male_Cabin_count_bin',
    'P1_Male_Deck_bin', 'P1_Male_Title_bin', 'P1_Male_Age_bin', 'P1_Male_Fare_log_bin'
    # Cabin_Location_s not included due to large KL shift
]
analyze_standalone_feature_batch(p1_males_train_df, standalone_candidates, subgroup_name='1_male')
# Out:
# <style type="text/css">
# #T_5e494_row0_col0, #T_5e494_row0_col1, #T_5e494_row0_col2, #T_5e494_row0_col3, #T_5e494_row0_col4, #T_5e494_row0_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e494">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e494_level0_col0" class="col_heading level0 col0" >Pclass_Sex</th>
#       <th id="T_5e494_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_5e494_level0_col2" class="col_heading level0 col2" >Chi2</th>
#       <th id="T_5e494_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_5e494_level0_col4" class="col_heading level0 col4" >Degrees of Freedom</th>
#       <th id="T_5e494_level0_col5" class="col_heading level0 col5" >Significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e494_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_5e494_row0_col0" class="data row0 col0" >1_male</td>
#       <td id="T_5e494_row0_col1" class="data row0 col1" >P1_Male_Age_bin</td>
#       <td id="T_5e494_row0_col2" class="data row0 col2" >12.356086</td>
#       <td id="T_5e494_row0_col3" class="data row0 col3" >0.014891</td>
#       <td id="T_5e494_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_5e494_row0_col5" class="data row0 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5e494_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_5e494_row1_col0" class="data row1 col0" >1_male</td>
#       <td id="T_5e494_row1_col1" class="data row1 col1" >P1_Male_Parch_SibSp_bin</td>
#       <td id="T_5e494_row1_col2" class="data row1 col2" >1.632876</td>
#       <td id="T_5e494_row1_col3" class="data row1 col3" >0.442003</td>
#       <td id="T_5e494_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_5e494_row1_col5" class="data row1 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e494_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_5e494_row2_col0" class="data row2 col0" >1_male</td>
#       <td id="T_5e494_row2_col1" class="data row2 col1" >P1_Male_Embarked_Is_S</td>
#       <td id="T_5e494_row2_col2" class="data row2 col2" >0.063059</td>
#       <td id="T_5e494_row2_col3" class="data row2 col3" >0.801724</td>
#       <td id="T_5e494_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_5e494_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e494_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_5e494_row3_col0" class="data row3 col0" >1_male</td>
#       <td id="T_5e494_row3_col1" class="data row3 col1" >P1_Male_Cabin_count_bin</td>
#       <td id="T_5e494_row3_col2" class="data row3 col2" >3.586647</td>
#       <td id="T_5e494_row3_col3" class="data row3 col3" >0.166406</td>
#       <td id="T_5e494_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_5e494_row3_col5" class="data row3 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e494_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_5e494_row4_col0" class="data row4 col0" >1_male</td>
#       <td id="T_5e494_row4_col1" class="data row4 col1" >P1_Male_Deck_bin</td>
#       <td id="T_5e494_row4_col2" class="data row4 col2" >0.630184</td>
#       <td id="T_5e494_row4_col3" class="data row4 col3" >0.729722</td>
#       <td id="T_5e494_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_5e494_row4_col5" class="data row4 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e494_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_5e494_row5_col0" class="data row5 col0" >1_male</td>
#       <td id="T_5e494_row5_col1" class="data row5 col1" >P1_Male_Title_bin</td>
#       <td id="T_5e494_row5_col2" class="data row5 col2" >5.495547</td>
#       <td id="T_5e494_row5_col3" class="data row5 col3" >0.064070</td>
#       <td id="T_5e494_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_5e494_row5_col5" class="data row5 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e494_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e494_row6_col0" class="data row6 col0" >1_male</td>
#       <td id="T_5e494_row6_col1" class="data row6 col1" >P1_Male_Fare_log_bin</td>
#       <td id="T_5e494_row6_col2" class="data row6 col2" >5.695243</td>
#       <td id="T_5e494_row6_col3" class="data row6 col3" >0.127416</td>
#       <td id="T_5e494_row6_col4" class="data row6 col4" >3</td>
#       <td id="T_5e494_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### P1 Male Smoothed Feature Engineering

# %%
create_pclass_sex_smoothed_feature(p1_males_train_df, p1_males_test_df, 1, 'male', 'P1_Male_Age_bin')
# Out:
# Created P1_Male_P1_Male_Age_bin_smoothed feature in training and test dataframes.
# count    122.000000
# mean       0.368812
# std        0.113499
# min        0.241348
# 25%        0.318338
# 50%        0.334016
# 75%        0.394933
# max        0.556116
# Name: P1_Male_P1_Male_Age_bin_smoothed, dtype: float64
# 'P1_Male_P1_Male_Age_bin_smoothed'

# %% [markdown]
# As model was later shown to still underfit with `P1_Male_P1_Male_Age_bin_smoothed`, I opted to test additional features despite their lack of statistical-significance:
# * `P1_Male_Title_bin` (p = 0.06)
# * `P1_Male_Fare_log_bin` (p = 0.13)
# * `P1_Male_Cabin_count_bin` (p = 16.6)

# %%
create_pclass_sex_smoothed_feature(p1_males_train_df, p1_males_test_df, 1, 'male', 'P1_Male_Title_bin')
# Out:
# Created P1_Male_P1_Male_Title_bin_smoothed feature in training and test dataframes.
# count    119.000000
# mean       0.352522
# std        0.014263
# min        0.347765
# 25%        0.347765
# 50%        0.347765
# 75%        0.347765
# max        0.394933
# Name: P1_Male_P1_Male_Title_bin_smoothed, dtype: float64
# 'P1_Male_P1_Male_Title_bin_smoothed'

# %%
create_pclass_sex_smoothed_feature(p1_males_train_df, p1_males_test_df, 1, 'male', 'P1_Male_Fare_log_bin')
# Out:
# Created P1_Male_P1_Male_Fare_log_bin_smoothed feature in training and test dataframes.
# count    116.000000
# mean       0.382658
# std        0.051329
# min        0.322216
# 25%        0.322216
# 50%        0.414804
# 75%        0.430700
# max        0.430700
# Name: P1_Male_P1_Male_Fare_log_bin_smoothed, dtype: float64
# 'P1_Male_P1_Male_Fare_log_bin_smoothed'

# %%
create_pclass_sex_smoothed_feature(p1_males_train_df, p1_males_test_df, 1, 'male', 'P1_Male_Cabin_count_bin')
# Out:
# Created P1_Male_P1_Male_Cabin_count_bin_smoothed feature in training and test dataframes.
# count    122.000000
# mean       0.369964
# std        0.058775
# min        0.261852
# 25%        0.396721
# 50%        0.396721
# 75%        0.396721
# max        0.434426
# Name: P1_Male_P1_Male_Cabin_count_bin_smoothed, dtype: float64
# 'P1_Male_P1_Male_Cabin_count_bin_smoothed'

# %%
p1_male_features = [
    'P1_Male_Parch_SibSp_bin',
    'P1_Male_Embarked_Is_S',
    'P1_Male_Cabin_count_bin',
    'P1_Male_Deck_bin',
    'P1_Male_Title_bin',
    'P1_Male_Age_bin',
    'P1_Male_Fare_log_bin'
]
composite_pairs = list(combinations(p1_male_features, 2))
composite_results = analyze_composite_feature_batch(
    p1_males_train_df,  # <- subgroup-specific DataFrame for 1_male
    composite_pairs,
    target_col='Survived',
    subgroup_name='1_male'
)
display(composite_results)
# Out:
# <style type="text/css">
# #T_24a50_row0_col0, #T_24a50_row0_col1, #T_24a50_row0_col2, #T_24a50_row0_col3, #T_24a50_row0_col4, #T_24a50_row0_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_24a50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24a50_level0_col0" class="col_heading level0 col0" >Pclass_Sex</th>
#       <th id="T_24a50_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_24a50_level0_col2" class="col_heading level0 col2" >Chi2</th>
#       <th id="T_24a50_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_24a50_level0_col4" class="col_heading level0 col4" >Degrees of Freedom</th>
#       <th id="T_24a50_level0_col5" class="col_heading level0 col5" >Significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24a50_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_24a50_row0_col0" class="data row0 col0" >1_male</td>
#       <td id="T_24a50_row0_col1" class="data row0 col1" >P1_Male_Title_bin x P1_Male_Age_bin</td>
#       <td id="T_24a50_row0_col2" class="data row0 col2" >21.791198</td>
#       <td id="T_24a50_row0_col3" class="data row0 col3" >0.009565</td>
#       <td id="T_24a50_row0_col4" class="data row0 col4" >9</td>
#       <td id="T_24a50_row0_col5" class="data row0 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_24a50_row1_col0" class="data row1 col0" >1_male</td>
#       <td id="T_24a50_row1_col1" class="data row1 col1" >P1_Male_Parch_SibSp_bin x P1_Male_Embarked_Is_S</td>
#       <td id="T_24a50_row1_col2" class="data row1 col2" >4.206159</td>
#       <td id="T_24a50_row1_col3" class="data row1 col3" >0.520132</td>
#       <td id="T_24a50_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_24a50_row1_col5" class="data row1 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_24a50_row2_col0" class="data row2 col0" >1_male</td>
#       <td id="T_24a50_row2_col1" class="data row2 col1" >P1_Male_Parch_SibSp_bin x P1_Male_Cabin_count_bin</td>
#       <td id="T_24a50_row2_col2" class="data row2 col2" >9.544356</td>
#       <td id="T_24a50_row2_col3" class="data row2 col3" >0.298472</td>
#       <td id="T_24a50_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_24a50_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_24a50_row3_col0" class="data row3 col0" >1_male</td>
#       <td id="T_24a50_row3_col1" class="data row3 col1" >P1_Male_Parch_SibSp_bin x P1_Male_Deck_bin</td>
#       <td id="T_24a50_row3_col2" class="data row3 col2" >7.044825</td>
#       <td id="T_24a50_row3_col3" class="data row3 col3" >0.531804</td>
#       <td id="T_24a50_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_24a50_row3_col5" class="data row3 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_24a50_row4_col0" class="data row4 col0" >1_male</td>
#       <td id="T_24a50_row4_col1" class="data row4 col1" >P1_Male_Parch_SibSp_bin x P1_Male_Title_bin</td>
#       <td id="T_24a50_row4_col2" class="data row4 col2" >7.376221</td>
#       <td id="T_24a50_row4_col3" class="data row4 col3" >0.287451</td>
#       <td id="T_24a50_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_24a50_row4_col5" class="data row4 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_24a50_row5_col0" class="data row5 col0" >1_male</td>
#       <td id="T_24a50_row5_col1" class="data row5 col1" >P1_Male_Parch_SibSp_bin x P1_Male_Age_bin</td>
#       <td id="T_24a50_row5_col2" class="data row5 col2" >23.266968</td>
#       <td id="T_24a50_row5_col3" class="data row5 col3" >0.056062</td>
#       <td id="T_24a50_row5_col4" class="data row5 col4" >14</td>
#       <td id="T_24a50_row5_col5" class="data row5 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_24a50_row6_col0" class="data row6 col0" >1_male</td>
#       <td id="T_24a50_row6_col1" class="data row6 col1" >P1_Male_Parch_SibSp_bin x P1_Male_Fare_log_bin</td>
#       <td id="T_24a50_row6_col2" class="data row6 col2" >10.679845</td>
#       <td id="T_24a50_row6_col3" class="data row6 col3" >0.220508</td>
#       <td id="T_24a50_row6_col4" class="data row6 col4" >8</td>
#       <td id="T_24a50_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_24a50_row7_col0" class="data row7 col0" >1_male</td>
#       <td id="T_24a50_row7_col1" class="data row7 col1" >P1_Male_Embarked_Is_S x P1_Male_Cabin_count_bin</td>
#       <td id="T_24a50_row7_col2" class="data row7 col2" >6.755112</td>
#       <td id="T_24a50_row7_col3" class="data row7 col3" >0.239499</td>
#       <td id="T_24a50_row7_col4" class="data row7 col4" >5</td>
#       <td id="T_24a50_row7_col5" class="data row7 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_24a50_row8_col0" class="data row8 col0" >1_male</td>
#       <td id="T_24a50_row8_col1" class="data row8 col1" >P1_Male_Embarked_Is_S x P1_Male_Deck_bin</td>
#       <td id="T_24a50_row8_col2" class="data row8 col2" >4.210192</td>
#       <td id="T_24a50_row8_col3" class="data row8 col3" >0.519567</td>
#       <td id="T_24a50_row8_col4" class="data row8 col4" >5</td>
#       <td id="T_24a50_row8_col5" class="data row8 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_24a50_row9_col0" class="data row9 col0" >1_male</td>
#       <td id="T_24a50_row9_col1" class="data row9 col1" >P1_Male_Embarked_Is_S x P1_Male_Title_bin</td>
#       <td id="T_24a50_row9_col2" class="data row9 col2" >6.111444</td>
#       <td id="T_24a50_row9_col3" class="data row9 col3" >0.190979</td>
#       <td id="T_24a50_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_24a50_row9_col5" class="data row9 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_24a50_row10_col0" class="data row10 col0" >1_male</td>
#       <td id="T_24a50_row10_col1" class="data row10 col1" >P1_Male_Embarked_Is_S x P1_Male_Age_bin</td>
#       <td id="T_24a50_row10_col2" class="data row10 col2" >13.254731</td>
#       <td id="T_24a50_row10_col3" class="data row10 col3" >0.151415</td>
#       <td id="T_24a50_row10_col4" class="data row10 col4" >9</td>
#       <td id="T_24a50_row10_col5" class="data row10 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row11" class="row_heading level0 row11" >10</th>
#       <td id="T_24a50_row11_col0" class="data row11 col0" >1_male</td>
#       <td id="T_24a50_row11_col1" class="data row11 col1" >P1_Male_Embarked_Is_S x P1_Male_Fare_log_bin</td>
#       <td id="T_24a50_row11_col2" class="data row11 col2" >8.513555</td>
#       <td id="T_24a50_row11_col3" class="data row11 col3" >0.202840</td>
#       <td id="T_24a50_row11_col4" class="data row11 col4" >6</td>
#       <td id="T_24a50_row11_col5" class="data row11 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row12" class="row_heading level0 row12" >11</th>
#       <td id="T_24a50_row12_col0" class="data row12 col0" >1_male</td>
#       <td id="T_24a50_row12_col1" class="data row12 col1" >P1_Male_Cabin_count_bin x P1_Male_Deck_bin</td>
#       <td id="T_24a50_row12_col2" class="data row12 col2" >4.485415</td>
#       <td id="T_24a50_row12_col3" class="data row12 col3" >0.481837</td>
#       <td id="T_24a50_row12_col4" class="data row12 col4" >5</td>
#       <td id="T_24a50_row12_col5" class="data row12 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_24a50_level0_row13" class="row_heading level0 row13" >12</th>

# %%
create_smoothed_pclass_sex_composite_feature(p1_males_train_df, p1_males_test_df, 1, 'male', 'P1_Male_Title_bin', 'P1_Male_Age_bin')
# Out:
# ✅ Created P1_Male_P1_Male_Title_bin_P1_Male_Age_bin_smoothed
# count    98.000000
# mean      0.363908
# std       0.124290
# min       0.209016
# 25%       0.321797
# 50%       0.333866
# 75%       0.544435
# max       0.544435
# Name: P1_Male_P1_Male_Title_bin_P1_Male_Age_bin_smoothed, dtype: float64
# 'P1_Male_P1_Male_Title_bin_P1_Male_Age_bin_smoothed'

# %% [markdown]
# ##### P1 Male Model Development

# %% [markdown]
# * <span style="color:green">**Model development accuracy increased to `0.7057`**</span> when replacing `P1_Male_Age_Group_smoothed` with `P1_Male_P1_Male_Age_bin_smoothed` and `P1_Male_P1_Male_Title_bin_smoothed`.
# * Model accuracy was not able to be increased further when attempting to apply stats-sig composite feature `P1_Male_P1_Male_Title_bin_P1_Male_Age_bin_smoothed` nor near-stats-sig composites.
# * Will accept this model accuracy for P1 Male subgroup for now and move on to P3 Female model optimization.

# %%
p1_male_model_config = {
    '1_male': {
        'features': [
            #'P1_Male_P1_Male_Title_bin_P1_Male_Age_bin_smoothed',
            'P1_Male_P1_Male_Age_bin_smoothed',
            'P1_Male_P1_Male_Title_bin_smoothed',
            #'P1_Male_P1_Male_Fare_log_bin_smoothed',
            #'P1_Male_P1_Male_Cabin_count_bin_smoothed' 
            #'P1_Male_P1_Male_Parch_SibSp_bin_P1_Male_Age_bin_smoothed',
            #'P1_Male_P1_Male_Deck_bin_P1_Male_Age_bin_smoothed',
            #'P1_Male_P1_Male_Cabin_count_bin_P1_Male_Age_bin_smoothed'
        ],
        'drop_cols': [],
        'train_df': p1_males_train_df   # Specify P1 Male specific training DF to override full train DF
    }
}

# %%
models_with_p1_only = train_group_models(
    train_df=prepared_train_df,
    target_col='Survived',
    group_col='Pclass_Sex',
    model_config=p1_male_model_config,
    model_params={'n_estimators': 100, 'max_depth': 3, 'random_state': 42},
    show_feature_importances=True,
    show_permutation_importance=True
)
# Out:
# ===== Training model for group: 1_male =====
# Fold 1 accuracy: 0.6400
# Fold 2 accuracy: 0.6800
# Fold 3 accuracy: 0.6667
# Fold 4 accuracy: 0.8333
# Fold 5 accuracy: 0.7083
# Average CV accuracy: 0.7057
# Permutation Importances:
#                            feature  importance_mean  importance_std
#   P1_Male_P1_Male_Age_bin_smoothed         0.158197        0.047094
# P1_Male_P1_Male_Title_bin_smoothed         0.024590        0.007331

# %% [markdown]
# #### P3 Female

# %% [markdown]
# ##### P3 Female Desciptive Statistics

# %%
base_features = ['Pclass', 'Sex', 'Parch', 'SibSp', 'Embarked', 'HasCabin', 'Cabin_count', 'Cabin_Location_s', 'Deck', 'Title', 'Age', 'Age_Group', 'Fare', 'Fare_log']
p3_females_train_df = prepared_train_df[prepared_train_df['Pclass_Sex'] == '3_female'].copy()
p3_females_test_df = prepared_test_df[prepared_test_df['Pclass_Sex'] == '3_female'].copy()

# %%
p3_females_train_df[base_features].describe(include="all")
# Out:
#         Pclass     Sex       Parch       SibSp Embarked    HasCabin  \
# count    144.0     144  144.000000  144.000000      144  144.000000
# unique     NaN       1         NaN         NaN        3         NaN
# top        NaN  female         NaN         NaN        S         NaN
# freq       NaN     144         NaN         NaN       88         NaN
# mean       3.0     NaN    0.798611    0.895833      NaN    0.041667
# std        0.0     NaN    1.237976    1.531573      NaN    0.200524
# min        3.0     NaN    0.000000    0.000000      NaN    0.000000
# 25%        3.0     NaN    0.000000    0.000000      NaN    0.000000
# 50%        3.0     NaN    0.000000    0.000000      NaN    0.000000
# 75%        3.0     NaN    1.000000    1.000000      NaN    0.000000
# max        3.0     NaN    6.000000    8.000000      NaN    1.000000
#
#         Cabin_count Cabin_Location_s Deck  Title         Age    Age_Group  \
# count         144.0              144  144    144  144.000000          144
# unique          3.0                3    4      2         NaN            5
# top             0.0    no_cabin_info    M  Miss.         NaN  Young_Adult
# freq          138.0              138  138    102         NaN           74
# mean            NaN              NaN  NaN    NaN   21.468750          NaN
# std             NaN              NaN  NaN    NaN   11.090847          NaN
# min             NaN              NaN  NaN    NaN    0.750000          NaN
# 25%             NaN              NaN  NaN    NaN   18.000000          NaN
# 50%             NaN              NaN  NaN    NaN   18.000000          NaN
# 75%             NaN              NaN  NaN    NaN   29.000000          NaN
# max             NaN              NaN  NaN    NaN   63.000000          NaN
#
#               Fare    Fare_log
# count   144.000000  144.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# mean     16.118810    2.679111
# std      11.690314    0.533309
# min       6.750000    2.047693
# 25%       7.854200    2.180892
# 50%      12.475000    2.600836
# 75%      20.221875    3.055032
# max      69.550000    4.256322

# %%
p3_females_test_df[base_features].describe(include="all")
# Out:
#         Pclass     Sex      Parch      SibSp Embarked   HasCabin  Cabin_count  \
# count     72.0      72  72.000000  72.000000       72  72.000000         72.0
# unique     NaN       1        NaN        NaN        3        NaN          2.0
# top        NaN  female        NaN        NaN        S        NaN          0.0
# freq       NaN      72        NaN        NaN       41        NaN         71.0
# mean       3.0     NaN   0.597222   0.583333      NaN   0.013889          NaN
# std        0.0     NaN   1.307182   1.241875      NaN   0.117851          NaN
# min        3.0     NaN   0.000000   0.000000      NaN   0.000000          NaN
# 25%        3.0     NaN   0.000000   0.000000      NaN   0.000000          NaN
# 50%        3.0     NaN   0.000000   0.000000      NaN   0.000000          NaN
# 75%        3.0     NaN   1.000000   1.000000      NaN   0.000000          NaN
# max        3.0     NaN   9.000000   8.000000      NaN   1.000000          NaN
#
#        Cabin_Location_s Deck  Title        Age    Age_Group       Fare  \
# count                72   72     72  72.000000           72  72.000000
# unique                2    2      3        NaN            4        NaN
# top       no_cabin_info    M  Miss.        NaN  Young_Adult        NaN
# freq                 71   71     48        NaN           48        NaN
# mean                NaN  NaN    NaN  23.398194          NaN  13.735129
# std                 NaN  NaN    NaN   9.391368          NaN  11.898984
# min                 NaN  NaN    NaN   0.170000          NaN   6.950000
# 25%                 NaN  NaN    NaN  19.750000          NaN   7.750000
# 50%                 NaN  NaN    NaN  22.000000          NaN   8.081250
# 75%                 NaN  NaN    NaN  28.000000          NaN  15.500000
# max                 NaN  NaN    NaN  47.000000          NaN  69.550000
#
#          Fare_log
# count   72.000000
# unique        NaN
# top           NaN
# freq          NaN
# mean     2.524172
# std      0.505813
# min      2.073172
# 25%      2.169054
# 50%      2.206206
# 75%      2.803360
# max      4.256322

# %% [markdown]
# ##### P3 Female Distribution Shift Assessment

# %% [markdown]
# * <span style="color:orange">**Significant KL divergences found between `3_female` training and test data sets**</span>
# * Features where `KL > 0.02`:
#     * `Parch` 0.7955
#     * `SibSp` 0.9693
#     * `Embarked` 0.0250
#     * `Cabin_count` inf
#     * `Cabin_Location_s` inf
#     * `Deck` inf
#     * `Title` 0.7590
#     * `Age` 5.3369
#     * `Age_Group` inf
#     * `Fare` 7.6277
# * Two features where `KL < 0.02`:
#     * `HasCabin` 0.0184
#     * `Title`: 0.0164
# * Features must be engineered to reduce KL divergences to < 0.02 to mitigate overfitting risks

# %%
for base_feature in base_features:
    print_train_test_distributions_for_feature(base_feature, p3_females_train_df, p3_females_test_df)
# Out:
#    Pclass  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0       3          144          72          100.0         100.0
#
# KL Divergence: 0.0000
#
#       Sex  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0  female          144          72          100.0         100.0
#
# KL Divergence: 0.0000
#
#    Parch  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0      0           85        50.0          59.03         70.42
# 1      1           25        10.0          17.36         14.08
# 2      2           25        10.0          17.36         14.08
# 5      5            4         0.0           2.78          0.00
# 3      3            2         0.0           1.39          0.00
# 4      4            2         1.0           1.39          1.41
# 6      6            1         0.0           0.69          0.00
#
# KL Divergence: 0.7955
#
#    SibSp  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0      0           81        46.0          56.25         63.89
# 1      1           38        21.0          26.39         29.17
# 3      3            8         0.0           5.56          0.00
# 2      2            7         2.0           4.86          2.78
# 4      4            6         1.0           4.17          1.39
# 6      8            3         1.0           2.08          1.39
# 5      5            1         1.0           0.69          1.39
#
# KL Divergence: 0.9693
#
#   Embarked  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2        S           88          41          61.11         56.94
# 1        Q           33          23          22.92         31.94
# 0        C           23           8          15.97         11.11
#
# KL Divergence: 0.0250
#
#    HasCabin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0         0          138          71          95.83         98.61
# 1         1            6           1           4.17          1.39
#
# KL Divergence: 0.0184
#
#   Cabin_count  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0           0          138        71.0          95.83         98.61
# 1           1            5         1.0           3.47          1.39
# 2           2            1         0.0           0.69          0.00
#
# KL Divergence: inf
#
#   Cabin_Location_s  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0    no_cabin_info          138        71.0          95.83         98.61
# 1             port            4         1.0           2.78          1.39
# 2        starboard            2         0.0           1.39          0.00
#
# KL Divergence: inf
#
#   Deck  Train_Count  Test_Count  Train_Percent  Test_Percent
# 3    M          138        71.0          95.83         98.61
# 2    G            4         1.0           2.78          1.39
# 0    E            1         0.0           0.69          0.00
# 1    F            1         0.0           0.69          0.00
#
# KL Divergence: inf
#
#    Title  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0  Miss.          102          48          70.83         67.61
# 1   Mrs.           42          23          29.17         32.39
#
# KL Divergence: 0.0164
#
#       Age  Train_Count  Test_Count  Train_Percent  Test_Percent
# 17  18.00           41         4.0          28.47          5.71
# 31  31.00           13         0.0           9.03          0.00
# 21  22.00            6        20.0           4.17         28.57
# 8    9.00            4         1.0           2.78          1.43
# 20  21.00            4         1.0           2.78          1.43
# 23  24.00            4         2.0           2.78          2.86
# 2    2.00            4         1.0           2.78          1.43
# 15  16.00            3         2.0           2.08          2.86
# 28  29.00            3         1.0           2.08          1.43
# 42  45.00            3         2.0           2.08          2.86
# 25  26.00            3         2.0           2.08          2.86
# 26  27.00            3         3.0           2.08          4.29
# 14  15.00            3         0.0           2.08          0.00
# 29  30.00            3         3.0           2.08          4.29
# 4    4.00            3         0.0           2.08          0.00
# 5    5.00            3         0.0           2.08          0.00
# 1    1.00            2         2.0           1.39          2.86
# 18  19.00            2         2.0           1.39          2.86
# 12  14.00            2         0.0           1.39          0.00
# 16  17.00            2         2.0           1.39          2.86
# 0    0.75            2         0.0           1.39          0.00
# 19  20.00            2         1.0           1.39          1.43
# 24  25.00            2         0.0           1.39          0.00
# 22  23.00            2         3.0           1.39          4.29
# 38  39.00            2         0.0           1.39          0.00
# 40  41.00            2         0.0           1.39          0.00
# 27  28.00            2         8.0           1.39         11.43
# 34  35.00            1         1.0           0.69          1.43
# 13  14.50            1         0.0           0.69          0.00
# 11  13.00            1         0.0           0.69          0.00
# 10  11.00            1         0.0           0.69          0.00
# 30  30.50            1         0.0           0.69          0.00
# 9   10.00            1         1.0           0.69          1.43
# 32  32.00            1         0.0           0.69          0.00
# 33  33.00            1         1.0           0.69          1.43
# 35  36.00            1         2.0           0.69          2.86
# 7    8.00            1         0.0           0.69          0.00
# 37  38.00            1         2.0           0.69          2.86
# 39  40.00            1         0.0           0.69          0.00
# 6    6.00            1         0.0           0.69          0.00
# 41  43.00            1         0.0           0.69          0.00
# 3    3.00            1         1.0           0.69          1.43
# 43  47.00            1         1.0           0.69          1.43
# 44  48.00            1         0.0           0.69          0.00
# 36  37.00            1         1.0           0.69          1.43
# 45  63.00            1         0.0           0.69          0.00
#
# KL Divergence: 5.3369
#
#      Age_Group  Train_Count  Test_Count  Train_Percent  Test_Percent
# 2  Young_Adult           74        48.0          51.39         66.67
# 3        Adult           34        13.0          23.61         18.06
# 1        Child           20         6.0          13.89          8.33
# 0  Young_Child           15         5.0          10.42          6.94
# 4       Senior            1         0.0           0.69          0.00
#
# KL Divergence: inf
#
#        Fare  Train_Count  Test_Count  Train_Percent  Test_Percent
# 10   7.7500           15         9.0          10.42         16.98
# 38  14.4542            5         1.0           3.47          1.89
# 63  31.2750            5         0.0           3.47          0.00
# 17   7.9250            5         2.0           3.47          3.77
# 14   7.8542            4         2.0           2.78          3.77
# ..      ...          ...         ...            ...           ...
# 0    6.7500            1         0.0           0.69          0.00
# 43  15.7417            1         1.0           0.69          1.89
# 20   8.1375            1         0.0           0.69          0.00
# 4    7.4958            1         0.0           0.69          0.00
# 34  12.2875            1         1.0           0.69          1.89
#
# [69 rows x 5 columns]
#
# KL Divergence: 7.6277
#
#     Fare_log  Train_Count  Test_Count  Train_Percent  Test_Percent
# 10  2.169054           15         9.0          10.42         16.98
# 38  2.737881            5         1.0           3.47          1.89
# 63  3.474293            5         0.0           3.47          0.00
# 17  2.188856            5         2.0           3.47          3.77
# 14  2.180892            4         2.0           2.78          3.77
# ..       ...          ...         ...            ...           ...
# 0   2.047693            1         0.0           0.69          0.00
# 43  2.817903            1         1.0           0.69          1.89
# 20  2.212387            1         0.0           0.69          0.00
# 4   2.139572            1         0.0           0.69          0.00
# 34  2.586824            1         1.0           0.69          1.89
#
# [69 rows x 5 columns]
#
# KL Divergence: 7.6277

# %% [markdown]
# ##### P3 Female Feature Engineering

# %% [markdown]
# ###### P3_Female_Parch_SibSp_bin

# %% [markdown]
# <span style="color:orange">**Distribution Shift for `P3_Female_Parch_SibSp_bin`:**</span> KL = 0.0388
# * Even after binning into only two groups given the P3 Female-specific data, KL is still greater than 0.02.
# * It is not "extreme" (e.g. KL > 0.05) but still represents significant distribution shift that risks reducing generalizability of feature alone.
# * Will test feature alone in P3 Female model development as well as explore combining into composite feature.

# %%
def create_feature_P3_Female_Parch_SibSp_bin(train_df, test_df):
    """
    Creates a binned version of the sum of Parch and SibSp for P3_Female.
    The new feature 'P3_Female_Parch_SibSp_bin' is categorical with values:
    - "0" for total=0
    - "1+" for total >= 1

    Args:
        train_df (pd.DataFrame): Training subset for P3_Female.
        test_df (pd.DataFrame): Test subset for P3_Female.
    """
    for df in [train_df, test_df]:
        total = df['Parch'] + df['SibSp']
        df['P3_Female_Parch_SibSp_bin'] = pd.cut(
            total,
            bins=[-1, 0, float('inf')],
            labels=['0', '1+']
        ).astype('category').astype(str)

create_feature_P3_Female_Parch_SibSp_bin(p3_females_train_df, p3_females_test_df)

# %%
print_train_test_distributions_for_feature('P3_Female_Parch_SibSp_bin', p3_females_train_df, p3_females_test_df)
# Out:
#   P3_Female_Parch_SibSp_bin  Train_Count  Test_Count  Train_Percent  \
# 1                        1+           84          32          58.33
# 0                         0           60          40          41.67
#
#    Test_Percent
# 1         44.44
# 0         55.56
#
# KL Divergence: 0.0388

# %% [markdown]
# ###### P3_Female_Embarked_Is_S

# %% [markdown]
# * P3 Female Embarked binned similar to P1 Male for consistency.
# * Binning into `P3_Female_Embarked_Is_S` reduced distribution shift to negligible levels (KL = 0.0036).

# %%
def create_feature_P3_Female_Embarked_Is_S(train_df, test_df):
    for df in [train_df, test_df]:
        df['P3_Female_Embarked_Is_S'] = (df['Embarked'] == 'S').astype(int)

create_feature_P3_Female_Embarked_Is_S(p3_females_train_df, p3_females_test_df)

# %%
print_train_test_distributions_for_feature('P3_Female_Embarked_Is_S', p3_females_train_df, p3_females_test_df)
# Out:
#    P3_Female_Embarked_Is_S  Train_Count  Test_Count  Train_Percent  \
# 1                        1           88          41          61.11
# 0                        0           56          31          38.89
#
#    Test_Percent
# 1         56.94
# 0         43.06
#
# KL Divergence: 0.0036

# %% [markdown]
# ###### P3_Female_Cabin_count_bin

# %% [markdown]
# * Binning P3 Female Cabin_count into two bins reduced distribution shift to negligible levels (KL = 0.0184).
# * Translating into smoothed rate feature will account for small sample sizes.

# %%
def create_feature_P3_Female_Cabin_count_bin(train_df, test_df):
    for df in [train_df, test_df]:
        cabin_count_int = df['Cabin_count'].astype(int)
        df['P3_Female_Cabin_count_bin'] = pd.cut(
            cabin_count_int,
            bins=[-1, 0, float('inf')],
            labels=['0', '1+']
        ).astype('category').astype(str)

create_feature_P3_Female_Cabin_count_bin(p3_females_train_df, p3_females_test_df)

# %%
print_train_test_distributions_for_feature('P3_Female_Cabin_count_bin', p3_females_train_df, p3_females_test_df)
# Out:
#   P3_Female_Cabin_count_bin  Train_Count  Test_Count  Train_Percent  \
# 0                         0          138          71          95.83
# 1                        1+            6           1           4.17
#
#    Test_Percent
# 0         98.61
# 1          1.39
#
# KL Divergence: 0.0184

# %% [markdown]
# ###### P3_Female_Cabin_Location_s_bin

# %% [markdown]
# **Usage of `Cabin_Location_s` for P3 Females will also be avoided for now** given the <span style="color:orange">**large KL Divergence found**</span> with existing values (KL = inf).

# %% [markdown]
# ###### P3_Female_Deck_bin

# %% [markdown]
# * As was done for `P1_M"ale_Deck_bin`, we use deck proximity to the lifeboats on the titanic to guide binning of decks for P3 Females.
#     * Lifeboats were located on the ship's top deck and therefore were more accessible to higher decks than lower decks (see References (1)).
# * The following bins are defined:
#     * `High_Access`: Decks `A` and `B`
#     * `Medium_Access`: Decks `C` and `D`
#     * `Low_Access` : Decks `E`, `M`, `T`
# * Implementing `P3_Female_Deck_bin` resulted in <span style="color:orange">**all P3 Females having one value**</span> => zero variance => likely to poorly generalize
# * Refrain from incorporating `P3_Female_Deck_bin` into P3 Female model

# %%
def create_feature_P3_Female_Deck_bin(train_df, test_df):
    """
    Creates a categorical deck access feature for P3_Female group:
    - High_Access: Decks A, B
    - Medium_Access: Decks C, D
    - Low_Access: Decks E, M, T
    """
    access_map = {
        'A': 'High_Access',
        'B': 'High_Access',
        'C': 'Medium_Access',
        'D': 'Medium_Access',
        'E': 'Low_Access',
        'F': 'Low_Access',
        'G': 'Low_Access',
        'M': 'Low_Access',
        'T': 'Low_Access'
    }

    for df in [train_df, test_df]:
        df['P3_Female_Deck_bin'] = df['Deck'].map(access_map).astype('category').astype(str)   

create_feature_P3_Female_Deck_bin(p3_females_train_df, p3_females_test_df)

# %%
print_train_test_distributions_for_feature('P3_Female_Deck_bin', p3_females_train_df, p3_females_test_df)
# Out:
#   P3_Female_Deck_bin  Train_Count  Test_Count  Train_Percent  Test_Percent
# 0         Low_Access          144          72          100.0         100.0
#
# KL Divergence: 0.0000

# %% [markdown]
# ### Subgroup Feature Search

# %%
from scipy.stats import chi2_contingency
import pandas as pd
from IPython.display import display
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt

def analyze_composite_feature_subgroups(df, feature_1, feature_2, target_col='Survived', subgroup_name=None):
    """
    Perform chi-squared test on a composite of two features within a specific Pclass_Sex subgroup.
    
    Args:
                feature_1 (str): First feature for composite.
        feature_2 (str): Second feature for composite.
        target_col (str): Target column name.
        subgroup_name (str): Subgroup identifier, e.g. '2_male'.

    Returns:
        DataFrame: Chi-squared test results for the composite feature.
    """
    results = []
    if subgroup_name is None:
        raise ValueError("subgroup_name must be specified.")

    subset = df[df['Pclass_Sex'] == subgroup_name].copy()
    subset['composite_feature'] = subset[feature_1].astype(str) + "_x_" + subset[feature_2].astype(str)
    contingency = pd.crosstab(index=subset['composite_feature'], columns=subset[target_col])

    if contingency.shape[0] < 2 or contingency.shape[1] < 2:
        return pd.DataFrame()

    chi2, p, dof, _ = chi2_contingency(contingency)
    results.append({
        'Pclass_Sex': subgroup_name,
        'Feature': f'{feature_1} x {feature_2}',
        'Chi2': chi2,
        'p-value': p,
        'Degrees of Freedom': dof,
        'Significant': p < 0.05
    })

    df_result = pd.DataFrame(results).sort_values(by=['Pclass_Sex', 'Significant'], ascending=[True, False])
    return df_result

def analyze_composite_feature_batch(df, composite_pairs, target_col='Survived', subgroup_name=None):
    """
    Analyze a list of composite feature pairs for statistical significance within a subgroup.

    Args:
        df (DataFrame): Dataset.
        composite_pairs (list): List of tuples representing feature pairs.
        target_col (str): Target column name.
        subgroup_name (str): Subgroup identifier.

    Returns:
        Styler: Styled DataFrame with chi-squared test results.
    """
    results = []
    for feature_1, feature_2 in composite_pairs:
        result_df = analyze_composite_feature_subgroups(df, feature_1, feature_2, target_col, subgroup_name)
        if not result_df.empty:
            results.append(result_df)

    if not results:
        return pd.DataFrame()

    full_results = pd.concat(results).reset_index(drop=True)
    full_results = full_results.sort_values(by=['Pclass_Sex', 'Significant'], ascending=[True, False])

    def highlight_significant(row):
        return ['background-color: lightgreen' if row['Significant'] else '' for _ in row]

    return full_results.style.apply(highlight_significant, axis=1)

def analyze_subgroup_feature_x_survival(subgroup_name, feature, df, target_col='Survived', styled=True):
    """
    Run chi-squared test for a single feature within a Pclass_Sex subgroup.

    Args:
        subgroup_name (str): Subgroup identifier.
        feature (str): Feature to analyze.
        df (DataFrame): Dataset.
        target_col (str): Target column.
        styled (bool): Whether to return a styled DataFrame.

    Returns:
        DataFrame or Styler: Chi-squared results for the feature.
    """
    results = []
    subset = df[df['Pclass_Sex'] == subgroup_name].copy()
    contingency = pd.crosstab(index=subset[feature], columns=subset[target_col])

    if contingency.shape[0] < 2 or contingency.shape[1] < 2:
        return pd.DataFrame()

    chi2, p, dof, _ = chi2_contingency(contingency)
    results.append({
        'Pclass_Sex': subgroup_name,
        'Feature': feature,
        'Chi2': chi2,
        'p-value': p,
        'Degrees of Freedom': dof,
        'Significant': p < 0.05
    })

    df_result = pd.DataFrame(results)

    if styled:
        def highlight_significant(row):
            return ['background-color: lightgreen' if row['Significant'] else '' for _ in row]
        return df_result.style.apply(highlight_significant, axis=1)
    else:
        return df_result

def compute_mutual_info_for_composites(df, composite_pairs, target_col='Survived', subgroup_name='2_male'):
    """
    Compute mutual information for composite features within a specified subgroup.

    Args:
        df (DataFrame): Dataset.
        composite_pairs (list): List of tuples of feature pairs.
        target_col (str): Target column name.
        subgroup_name (str): Subgroup identifier.

    Returns:
        DataFrame: Ranked mutual information scores for composite features.
    """
    subset = df[df['Pclass_Sex'] == subgroup_name].copy()
    y = subset[target_col]

    for feature_1, feature_2 in composite_pairs:
        composite_name = f'{feature_1}_x_{feature_2}'
        subset[composite_name] = subset[feature_1].astype(str) + '_' + subset[feature_2].astype(str)

    composite_cols = [f'{f1}_x_{f2}' for f1, f2 in composite_pairs]
    X = subset[composite_cols].apply(lambda col: pd.factorize(col)[0])

    mi_scores = mutual_info_classif(X, y, discrete_features=True)
    return pd.DataFrame({
        'Composite_Feature': composite_cols,
        'Mutual_Info': mi_scores
    }).sort_values(by='Mutual_Info', ascending=False).reset_index(drop=True)

def compute_significant_composite_mi(df, composite_pairs, target_col='Survived', subgroup_name='2_male'):
    """
    Identify and score statistically significant composite features by mutual information.

    Args:
        df (DataFrame): Dataset.
        composite_pairs (list): List of tuples of composite features.
        target_col (str): Target column.
        subgroup_name (str): Subgroup identifier.

    Returns:
        DataFrame: Mutual information scores for significant composite features.
    """
    sig_df = analyze_composite_feature_batch(df, composite_pairs, target_col=target_col, subgroup_name=subgroup_name).data
    if sig_df.empty:
        print("No statistically significant composite features found.")
        return pd.DataFrame()

    sig_pairs = sig_df[sig_df['Significant'] == True]['Feature'].str.split(' x ').apply(tuple).tolist()
    mi_df = compute_mutual_info_for_composites(df, sig_pairs, target_col=target_col, subgroup_name=subgroup_name)

    return mi_df

def create_top_composite_smoothed_features(train_df, test_df, mi_df, subgroup_name='2_male', top_n=10, prior=10):
    """
    Create smoothed rate features for top N composite features by mutual information.

    Args:
        df (DataFrame): Full dataset.
        train_df (DataFrame): Training subset.
        test_df (DataFrame): Testing subset.
        mi_df (DataFrame): Mutual information ranking of composite features.
        subgroup_name (str): Subgroup to create features for.
        top_n (int): Number of top features to use.
        prior (int): Smoothing prior.

    Returns:
        None: Adds columns to train_df and test_df in-place.
    """

    # Ensure Pclass_Sex column exists
    if 'Pclass_Sex' not in train_df.columns:
        train_df['Pclass_Sex'] = train_df['Pclass'].astype(str) + '_' + train_df['Sex'].astype(str)
    if 'Pclass_Sex' not in test_df.columns:
        test_df['Pclass_Sex'] = test_df['Pclass'].astype(str) + '_' + test_df['Sex'].astype(str)
      
    top_features = mi_df.head(top_n)['Composite_Feature'].tolist()

    for composite in top_features:
        f1, f2 = composite.split('_x_')
        col_name = f'{subgroup_name}_{f1}_{f2}_smoothed'

        train_df[col_name] = np.nan
        test_df[col_name] = np.nan

        subset = train_df[train_df['Pclass_Sex'] == subgroup_name].copy()
        composite_col = subset[f1].astype(str) + '_' + subset[f2].astype(str)
        global_mean = train_df['Survived'].mean()

        rate_df = subset.copy()
        rate_df['composite'] = composite_col
        stats = rate_df.groupby('composite')['Survived'].agg(['mean', 'count'])
        included = stats[(stats['count'] >= 10) | ((stats['count'] >= 5) & (stats['mean'] == 1.0))].copy()
        included['smoothed'] = (included['mean'] * included['count'] + prior * global_mean) / (included['count'] + prior)

        smoothed_map = included['smoothed'].to_dict()

        mask_train = train_df['Pclass_Sex'] == subgroup_name
        mask_test = test_df['Pclass_Sex'] == subgroup_name

        train_df.loc[mask_train, col_name] = (
            train_df.loc[mask_train, f1].astype(str) + '_' + train_df.loc[mask_train, f2].astype(str)
        ).map(smoothed_map)

        test_df.loc[mask_test, col_name] = (
            test_df.loc[mask_test, f1].astype(str) + '_' + test_df.loc[mask_test, f2].astype(str)
        ).map(smoothed_map)

        print(f"Created {col_name}")

# %%
# Prepare composite and standalone feature lists for inspection for each subgroup
all_features = [
    'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'HasCabin',
    'Cabin_count', 'Cabin_Location_s', 'Deck', 'Title', 'Age_Group' 
    # Ignoring Fare for now given distribution shift
]
composite_candidates = list(combinations(all_features, 2))

standalone_candidates = [
    'SibSp', 'Parch', 'Embarked', 'HasCabin',
    'Cabin_count', 'Cabin_Location_s', 'Deck',
    'Title', 'Age_Group'
]

# %% [markdown]
# #### P1 Male

# %% [markdown]
# * Chi-squared testing of standalone and composite feature candidates did not identify new candidates beyond pre-existing features or features collinear to the existing.
# * Will skip further optimization of this model for now and revisit after reviewing score post-submission.

# %%
compute_significant_composite_mi(prepared_train_df, composite_candidates, subgroup_name='1_male')
# Out:
#     Composite_Feature  Mutual_Info
# 0  Pclass_x_Age_Group     0.048628
# 1     Sex_x_Age_Group     0.048628

# %%
analyze_standalone_feature_batch(prepared_train_df, standalone_candidates, subgroup_name='1_male')
# Out:
# <style type="text/css">
# #T_1238d_row0_col0, #T_1238d_row0_col1, #T_1238d_row0_col2, #T_1238d_row0_col3, #T_1238d_row0_col4, #T_1238d_row0_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1238d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1238d_level0_col0" class="col_heading level0 col0" >Pclass_Sex</th>
#       <th id="T_1238d_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_1238d_level0_col2" class="col_heading level0 col2" >Chi2</th>
#       <th id="T_1238d_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_1238d_level0_col4" class="col_heading level0 col4" >Degrees of Freedom</th>
#       <th id="T_1238d_level0_col5" class="col_heading level0 col5" >Significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1238d_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_1238d_row0_col0" class="data row0 col0" >1_male</td>
#       <td id="T_1238d_row0_col1" class="data row0 col1" >Age_Group</td>
#       <td id="T_1238d_row0_col2" class="data row0 col2" >10.257159</td>
#       <td id="T_1238d_row0_col3" class="data row0 col3" >0.036312</td>
#       <td id="T_1238d_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_1238d_row0_col5" class="data row0 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_1238d_row1_col0" class="data row1 col0" >1_male</td>
#       <td id="T_1238d_row1_col1" class="data row1 col1" >SibSp</td>
#       <td id="T_1238d_row1_col2" class="data row1 col2" >3.077840</td>
#       <td id="T_1238d_row1_col3" class="data row1 col3" >0.379779</td>
#       <td id="T_1238d_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_1238d_row1_col5" class="data row1 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_1238d_row2_col0" class="data row2 col0" >1_male</td>
#       <td id="T_1238d_row2_col1" class="data row2 col1" >Parch</td>
#       <td id="T_1238d_row2_col2" class="data row2 col2" >3.266342</td>
#       <td id="T_1238d_row2_col3" class="data row2 col3" >0.352355</td>
#       <td id="T_1238d_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_1238d_row2_col5" class="data row2 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_1238d_row3_col0" class="data row3 col0" >1_male</td>
#       <td id="T_1238d_row3_col1" class="data row3 col1" >Embarked</td>
#       <td id="T_1238d_row3_col2" class="data row3 col2" >0.887638</td>
#       <td id="T_1238d_row3_col3" class="data row3 col3" >0.641582</td>
#       <td id="T_1238d_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_1238d_row3_col5" class="data row3 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_1238d_row4_col0" class="data row4 col0" >1_male</td>
#       <td id="T_1238d_row4_col1" class="data row4 col1" >HasCabin</td>
#       <td id="T_1238d_row4_col2" class="data row4 col2" >2.444523</td>
#       <td id="T_1238d_row4_col3" class="data row4 col3" >0.117936</td>
#       <td id="T_1238d_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_1238d_row4_col5" class="data row4 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_1238d_row5_col0" class="data row5 col0" >1_male</td>
#       <td id="T_1238d_row5_col1" class="data row5 col1" >Cabin_count</td>
#       <td id="T_1238d_row5_col2" class="data row5 col2" >2.594585</td>
#       <td id="T_1238d_row5_col3" class="data row5 col3" >0.273271</td>
#       <td id="T_1238d_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_1238d_row5_col5" class="data row5 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_1238d_row6_col0" class="data row6 col0" >1_male</td>
#       <td id="T_1238d_row6_col1" class="data row6 col1" >Cabin_Location_s</td>
#       <td id="T_1238d_row6_col2" class="data row6 col2" >4.156957</td>
#       <td id="T_1238d_row6_col3" class="data row6 col3" >0.125120</td>
#       <td id="T_1238d_row6_col4" class="data row6 col4" >2</td>
#       <td id="T_1238d_row6_col5" class="data row6 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_1238d_row7_col0" class="data row7 col0" >1_male</td>
#       <td id="T_1238d_row7_col1" class="data row7 col1" >Deck</td>
#       <td id="T_1238d_row7_col2" class="data row7 col2" >5.685339</td>
#       <td id="T_1238d_row7_col3" class="data row7 col3" >0.459345</td>
#       <td id="T_1238d_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_1238d_row7_col5" class="data row7 col5" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1238d_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_1238d_row8_col0" class="data row8 col0" >1_male</td>
#       <td id="T_1238d_row8_col1" class="data row8 col1" >Title</td>
#       <td id="T_1238d_row8_col2" class="data row8 col2" >9.433114</td>
#       <td id="T_1238d_row8_col3" class="data row8 col3" >0.307086</td>
#       <td id="T_1238d_row8_col4" class="data row8 col4" >8</td>
#       <td id="T_1238d_row8_col5" class="data row8 col5" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### P2 Male

# %%
p2_male_mi_df = compute_significant_composite_mi(prepared_train_df, composite_candidates, subgroup_name='2_male')
create_top_composite_smoothed_features(prepared_train_df, prepared_test_df, p2_male_mi_df, subgroup_name='2_male', top_n=50)
# Out:
# Created 2_male_Parch_Age_Group_smoothed
# Created 2_male_SibSp_Age_Group_smoothed
# Created 2_male_Title_Age_Group_smoothed
# Created 2_male_Deck_Title_smoothed
# Created 2_male_Cabin_Location_s_Title_smoothed
# Created 2_male_Parch_Title_smoothed
# Created 2_male_HasCabin_Title_smoothed
# Created 2_male_SibSp_Title_smoothed
# Created 2_male_Deck_Age_Group_smoothed
# Created 2_male_Cabin_Location_s_Age_Group_smoothed
# Created 2_male_Embarked_Title_smoothed
# Created 2_male_Cabin_count_Title_smoothed
# Created 2_male_Pclass_Title_smoothed
# Created 2_male_Sex_Title_smoothed
# Created 2_male_HasCabin_Age_Group_smoothed
# Created 2_male_Embarked_Age_Group_smoothed
# Created 2_male_Pclass_Age_Group_smoothed
# Created 2_male_Cabin_count_Age_Group_smoothed
# Created 2_male_Sex_Age_Group_smoothed
# Created 2_male_Parch_Cabin_Location_s_smoothed
# Created 2_male_Parch_Deck_smoothed
# Created 2_male_Parch_HasCabin_smoothed
# Created 2_male_SibSp_Parch_smoothed
# Created 2_male_Parch_Embarked_smoothed
# Created 2_male_SibSp_Deck_smoothed
# Created 2_male_SibSp_Cabin_Location_s_smoothed
# Created 2_male_SibSp_HasCabin_smoothed
# Created 2_male_Sex_Parch_smoothed
# Created 2_male_Parch_Cabin_count_smoothed
# Created 2_male_Pclass_Parch_smoothed
# Created 2_male_Embarked_Deck_smoothed
# Created 2_male_Embarked_HasCabin_smoothed
# Created 2_male_Cabin_Location_s_Deck_smoothed
# Created 2_male_Embarked_Cabin_Location_s_smoothed
# Created 2_male_HasCabin_Cabin_Location_s_smoothed
# Created 2_male_Cabin_count_Cabin_Location_s_smoothed
# Created 2_male_Sex_Cabin_Location_s_smoothed
# Created 2_male_Pclass_Cabin_Location_s_smoothed
# Created 2_male_HasCabin_Deck_smoothed
# Created 2_male_Cabin_count_Deck_smoothed
# Created 2_male_Sex_Deck_smoothed
# Created 2_male_Pclass_Deck_smoothed
# Created 2_male_HasCabin_Cabin_count_smoothed
# Created 2_male_Pclass_HasCabin_smoothed
# Created 2_male_Sex_HasCabin_smoothed

# %% [markdown]
# #### P3 Male

# %%
p3_male_mi_df = compute_significant_composite_mi(prepared_train_df, composite_candidates, subgroup_name='3_male')
create_top_composite_smoothed_features(prepared_train_df, prepared_test_df, p3_male_mi_df, subgroup_name='3_male', top_n=50)
# Out:
# Created 3_male_SibSp_Title_smoothed
# Created 3_male_SibSp_Age_Group_smoothed
# Created 3_male_Embarked_Title_smoothed
# Created 3_male_Embarked_Age_Group_smoothed
# Created 3_male_Deck_Title_smoothed
# Created 3_male_Cabin_Location_s_Age_Group_smoothed
# Created 3_male_Deck_Age_Group_smoothed
# Created 3_male_Parch_Title_smoothed
# Created 3_male_Cabin_Location_s_Title_smoothed
# Created 3_male_HasCabin_Age_Group_smoothed
# Created 3_male_SibSp_Deck_smoothed
# Created 3_male_HasCabin_Title_smoothed
# Created 3_male_Title_Age_Group_smoothed
# Created 3_male_Embarked_Deck_smoothed
# Created 3_male_Parch_Embarked_smoothed
# Created 3_male_Cabin_count_Title_smoothed
# Created 3_male_Parch_Deck_smoothed
# Created 3_male_Pclass_Title_smoothed
# Created 3_male_Sex_Title_smoothed
# Created 3_male_Cabin_count_Age_Group_smoothed
# Created 3_male_Pclass_Age_Group_smoothed
# Created 3_male_Sex_Age_Group_smoothed
# Created 3_male_Sex_Deck_smoothed
# Created 3_male_Pclass_Deck_smoothed
# Created 3_male_HasCabin_Deck_smoothed
# Created 3_male_Cabin_Location_s_Deck_smoothed
# Created 3_male_Cabin_count_Deck_smoothed
# Created 3_male_Embarked_Cabin_Location_s_smoothed
# Created 3_male_Cabin_count_Cabin_Location_s_smoothed
# Created 3_male_HasCabin_Cabin_count_smoothed

# %% [markdown]
# #### P3 Female

# %%
p3_female_mi_df = compute_significant_composite_mi(prepared_train_df, composite_candidates, subgroup_name='3_female')
create_top_composite_smoothed_features(prepared_train_df, prepared_test_df, p3_female_mi_df, subgroup_name='3_female', top_n=20)
# Out:
# Created 3_female_SibSp_Age_Group_smoothed
# Created 3_female_Embarked_Age_Group_smoothed
# Created 3_female_SibSp_Embarked_smoothed
# Created 3_female_Parch_Embarked_smoothed
# Created 3_female_Embarked_Title_smoothed
# Created 3_female_Embarked_Cabin_Location_s_smoothed
# Created 3_female_Embarked_Deck_smoothed
# Created 3_female_Embarked_HasCabin_smoothed
# Created 3_female_Embarked_Cabin_count_smoothed
# Created 3_female_Pclass_Embarked_smoothed
# Created 3_female_Sex_Embarked_smoothed

# %% [markdown]
# ### Hyperparameter Tuning

# %%
plot_validation_curve(submission_model, 'reg_lambda', [1,5,10], selected_feature_list, selected_drop_cols)
# Out:
# Evaluating baseline model with the following variables:
# * Cabin_count
# * Pclass_1
# * Pclass_2
# * Pclass_3
# * ParchSibSp_bin_LargeFamily
# * ParchSibSp_bin_SmallFamily
# * Embarked_C
# * Embarked_Q
# * Embarked_S
# * Cabin_Location_s_port
# * Cabin_Location_s_port_and_starboard_rare
# * Cabin_Location_s_starboard
# * Deck_A
# * Deck_B
# * Deck_C
# * Deck_D
# * Deck_E
# * Deck_F
# * Deck_G
# * Deck_T
# * Title_bin_FemaleTitle
# * Title_bin_Master_
# * Title_bin_Other
# * Age_Group_Child
# * Age_Group_Young_Adult
# * Age_Group_Adult
# * Age_Group_Senior
# * FPP_log_bin_Bin_2
# * FPP_log_bin_Bin_3
# * FPP_log_bin_Bin_4
# * FPP_log_bin_Bin_6
# * CabinMissing_Pclass_has_info_P2
# * CabinMissing_Pclass_has_info_P3
# * CabinMissing_Pclass_missing_P1

# %% [markdown]
# ## Submission

# %%
# Confirm submission input features
selected_feature_list
# Out:
# ['Pclass',
#  'Sex',
#  'ParchSibSp_bin',
#  'Embarked',
#  'HasCabin',
#  'Cabin_count',
#  'Cabin_Location_s',
#  'Deck',
#  'Has_Multiple_Cabins',
#  'Title_bin',
#  'Age_Group',
#  'FPP_log_bin',
#  'Is_Shared_Ticket',
#  'Has_Other_Family_Members',
#  'CabinMissing_Pclass']

# %%
selected_drop_cols
# Out:
# ['Is_Shared_Ticket',
#  'Has_Other_Family_Members',
#  'FPP_log_bin_Bin_1',
#  'FPP_log_bin_Bin_5',
#  'Deck_M',
#  'HasCabin',
#  'Has_Multiple_Cabins',
#  'ParchSibSp_bin_Solo',
#  'Sex_female',
#  'Sex_male',
#  'Title_bin_Mr_',
#  'Cabin_Location_s_no_cabin_info',
#  'CabinMissing_Pclass_missing_P3',
#  'CabinMissing_Pclass_missing_P2',
#  'CabinMissing_Pclass_has_info_P1']

# %%
submission_X_test_encoded.isnull().sum().loc[lambda x: x > 0]
# Out:
# Series([], dtype: int64)

# %%
# Confirm no unexpected columns
submission_X_test_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 0 to 417
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Cabin_count                               418 non-null    int64
#  1   Pclass_1                                  418 non-null    bool
#  2   Pclass_2                                  418 non-null    bool
#  3   Pclass_3                                  418 non-null    bool
#  4   ParchSibSp_bin_LargeFamily                418 non-null    bool
#  5   ParchSibSp_bin_SmallFamily                418 non-null    bool
#  6   Embarked_C                                418 non-null    bool
#  7   Embarked_Q                                418 non-null    bool
#  8   Embarked_S                                418 non-null    bool
#  9   Cabin_Location_s_port                     418 non-null    bool
#  10  Cabin_Location_s_port_and_starboard_rare  418 non-null    bool
#  11  Cabin_Location_s_starboard                418 non-null    bool
#  12  Deck_A                                    418 non-null    bool
#  13  Deck_B                                    418 non-null    bool
#  14  Deck_C                                    418 non-null    bool
#  15  Deck_D                                    418 non-null    bool
#  16  Deck_E                                    418 non-null    bool
#  17  Deck_F                                    418 non-null    bool
#  18  Deck_G                                    418 non-null    bool
#  19  Deck_T                                    418 non-null    bool
#  20  Title_bin_FemaleTitle                     418 non-null    bool
#  21  Title_bin_Master_                         418 non-null    bool
#  22  Title_bin_Other                           418 non-null    bool
#  23  Age_Group_Child                           418 non-null    bool
#  24  Age_Group_Young_Adult                     418 non-null    bool
#  25  Age_Group_Adult                           418 non-null    bool
#  26  Age_Group_Senior                          418 non-null    bool
#  27  FPP_log_bin_Bin_2                         418 non-null    bool
#  28  FPP_log_bin_Bin_3                         418 non-null    bool
#  29  FPP_log_bin_Bin_4                         418 non-null    bool
#  30  FPP_log_bin_Bin_6                         418 non-null    bool
#  31  CabinMissing_Pclass_has_info_P2           418 non-null    bool
#  32  CabinMissing_Pclass_has_info_P3           418 non-null    bool
#  33  CabinMissing_Pclass_missing_P1            418 non-null    bool
#  34  Female_Alone                              418 non-null    int32
# dtypes: bool(33), int32(1), int64(1)
# memory usage: 21.6 KB

# %%
def plot_feature_distributions_grid(features, train_df, test_df):
    """
    Plots train/test distribution comparisons for multiple features in a grid with 3 columns.

    Args:
        features (list of str): List of feature names to compare.
        train_df (DataFrame): Training dataset.
        test_df (DataFrame): Test dataset.
    """
    num_features = len(features)
    num_cols = 3
    num_rows = int(np.ceil(num_features / num_cols))

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(num_cols * 5, num_rows * 4))
    axes = axes.flatten()

    for i, feature in enumerate(features):
        ax = axes[i]
        train_col = train_df[feature].copy()
        test_col = test_df[feature].copy()

        # Handle categorical types
        if isinstance(train_col.dtype, pd.CategoricalDtype):
            category_order = [str(c) for c in train_col.cat.categories]
            train_col = train_col.astype(str).astype(pd.CategoricalDtype(categories=category_order, ordered=True))
            test_col = test_col.astype(str).astype(pd.CategoricalDtype(categories=category_order, ordered=True))
        elif isinstance(train_col.dtype, pd.IntervalDtype):
            category_order = sorted(train_col.astype(str).unique(), key=lambda x: eval(x.strip("[]")).split(",")[0])
            train_col = pd.Categorical(train_col.astype(str), categories=category_order, ordered=True)
            test_col = pd.Categorical(test_col.astype(str), categories=category_order, ordered=True)

        combined = pd.concat([
            train_col.to_frame(name=feature).assign(Dataset='Train'),
            test_col.to_frame(name=feature).assign(Dataset='Test')
        ]).reset_index(drop=True)

        if combined[feature].dtype in ['object', 'category']:
            sns.histplot(data=combined, x=feature, hue='Dataset', stat='percent', multiple='dodge', common_norm=False, ax=ax)
        else:
            sns.kdeplot(data=combined, x=feature, hue='Dataset', fill=True, ax=ax)

        ax.set_title(f"{feature} (Train vs Test)", fontsize=10)
        ax.tick_params(axis='x', rotation=45)

    # Hide any extra subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

# %%
baseline_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
# Confirm submission model configuration
submission_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='error', feature_types=None,
#               feature_weights=None, gamma=0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],
    #'Survived': submission_model.predict(submission_X_test_encoded)
    'Survived': submission_model.predict(submission_X_test_encoded)
})
timestamp = datetime.now().strftime('%Y%m%d-%H%M%S')
filename = f'./submission-{timestamp}.csv'
submission.to_csv(filename, index=False)

# %% [markdown]
# ## References

# %% [markdown]
# * (1) "Titanic Deckplans." _Encyclopedia Titanica_,  https://www.encyclopedia-titanica.org/titanic-deckplans/

# %% [markdown]
# --------------------------

# %% [markdown]
# #### Table of Contents Generator

# %%
import json
import re

def slugify(text):
    text = text.strip()
    text = re.sub(r'[^\w\s\-]', '', text)  # allow (), - and alphanumerics
    return re.sub(r'[\s]+', '-', text)

def extract_headings(ipynb_path):
    with open(ipynb_path, 'r', encoding='utf-8') as f:
        nb = json.load(f)

    toc_lines = ["## Table of Contents\n"]
    for cell in nb['cells']:
        if cell['cell_type'] == 'markdown':
            for line in cell['source']:
                match = re.match(r'^(#{2,6})\s+(.*)', line)
                if match:
                    level = len(match.group(1)) - 1  # offset for nesting
                    title = match.group(2).strip()
                    anchor = slugify(title)
                    indent = '    ' * (level - 1)
                    toc_lines.append(f"{indent}1. [{title}](#{anchor})")

    return '\n'.join(toc_lines)

# Example usage:
toc = extract_headings("titanic_ml_from_disaster__paultongyoo.ipynb")
print(toc)
# Out:
# ## Table of Contents
#
# 1. [Table of Contents](#Table-of-Contents)
# 1. [Project Summary](#Project-Summary)
#     1. [What I Did](#What-I-Did)
#     1. [What I Learned](#What-I-Learned)
#     1. [What's Next](#Whats-Next)
# 1. [Introduction](#Introduction)
# 1. [Methodology](#Methodology)
#     1. [Data Understanding](#Data-Understanding)
#         1. [Data Dictionary](#Data-Dictionary)
#         1. [Variable Notes](#Variable-Notes)
#         1. [Descriptive Statistics](#Descriptive-Statistics)
#         1. [Row Samples](#Row-Samples)
#         1. [Data Types](#Data-Types)
#         1. [Missing Values Summary](#Missing-Values-Summary)
#     1. [Data Preparation](#Data-Preparation)
#         1. [Missing Value Imputation](#Missing-Value-Imputation)
#             1. [Embarked](#Embarked)
#             1. [Cabin](#Cabin)
#             1. [Age](#Age)
#             1. [Fare](#Fare)
#     1. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
#         1. [Individual Features x Target](#Individual-Features-x-Target)
#             1. [Pclass](#Pclass)
#             1. [Sex](#Sex)
#             1. [SibSp](#SibSp)
#             1. [Parch](#Parch)
#             1. [Embarked_](#Embarked_)
#             1. [HasCabin](#HasCabin)
#             1. [Cabin_count](#Cabin_count)
#             1. [Cabin_Location_s](#Cabin_Location_s)
#             1. [Deck](#Deck)
#             1. [Title](#Title)
#             1. [Age_](#Age_)
#             1. [Age_Group](#Age_Group)
#             1. [Fare_](#Fare_)
#             1. [Summary of Single Feature Relationship with Target](#Summary-of-Single-Feature-Relationship-with-Target)
#         1. [Composite Features x Target](#Composite-Features-x-Target)
#             1. [Pclass x Sex](#Pclass-x-Sex)
#             1. [Pclass x Sex x SibSp](#Pclass-x-Sex-x-SibSp)
#             1. [Pclass x Sex x Parch](#Pclass-x-Sex-x-Parch)
#             1. [Pclass x Sex x Embarked](#Pclass-x-Sex-x-Embarked)
#             1. [Pclass x Sex x HasCabin](#Pclass-x-Sex-x-HasCabin)
#             1. [Pclass x Sex x Cabin_count](#Pclass-x-Sex-x-Cabin_count)
#             1. [Pclass x Sex x Cabin_Location_s](#Pclass-x-Sex-x-Cabin_Location_s)
#             1. [Pclass x Sex x Deck](#Pclass-x-Sex-x-Deck)
#             1. [Pclass x Sex x Title](#Pclass-x-Sex-x-Title)
#             1. [Pclass x Sex x Age_Group](#Pclass-x-Sex-x-Age_Group)
#             1. [Pclass x Sex x Fare](#Pclass-x-Sex-x-Fare)
#             1. [Analysis Summary of Composite Feature Relationships with Target](#Analysis-Summary-of-Composite-Feature-Relationships-with-Target)
#         1. [Latent Features](#Latent-Features)
#             1. [Name](#Name)
#             1. [Ticket](#Ticket)
#         1. [Compilation of Feature Engineering Plans](#Compilation-of-Feature-Engineering-Plans)
#     1. [Training/Test Set Distribution Comparison](#TrainingTest-Set-Distribution-Comparison)
#         1. [Pclass_Sex](#Pclass_Sex)
#         1. [Pclass_](#Pclass_)
#         1. [Sex_](#Sex_)
#         1. [SibSp_](#SibSp_)
#         1. [Parch_](#Parch_)
#         1. [Embarked__](#Embarked__)
#         1. [HasCabin_](#HasCabin_)
#         1. [Cabin_count_](#Cabin_count_)
#         1. [Cabin_Location_s_](#Cabin_Location_s_)
#         1. [Deck_](#Deck_)
#         1. [Title_](#Title_)
#         1. [Age__](#Age__)
#         1. [Fare__](#Fare__)
#         1. [Compilation of Distribution Shift Mitigation Plans](#Compilation-of-Distribution-Shift-Mitigation-Plans)
#     1. [Feature Engineering](#Feature-Engineering)
#         1. [Pclass_Sex One-Hot Encodings](#Pclass_Sex-One-Hot-Encodings)
#             1. [Create Features](#Create-Features)
#             1. [Assess Distribution Shift](#Assess-Distribution-Shift)
#         1. [Smoothed Features](#Smoothed-Features)
#         1. [Is_Shared_Ticket](#Is_Shared_Ticket)
#         1. [Fare_Per_Person_log_bin](#Fare_Per_Person_log_bin)
#         1. [Has_Other_Family_Members](#Has_Other_Family_Members)
#         1. [Compilation of Engineered Features and KL Values](#Compilation-of-Engineered-Features-and-KL-Values)
#     1. [Model Development](#Model-Development)
#         1. [Baseline Establishment](#Baseline-Establishment)
#             1. [Predict Majority Class](#Predict-Majority-Class)
#             1. [Predict Simple Model](#Predict-Simple-Model)
#         1. [Engineered Features Test](#Engineered-Features-Test)
#         1. [Out-of-Fold Prediction Mistake Analysis](#Out-of-Fold-Prediction-Mistake-Analysis)
#         1. [SHAP Analysis of Mistakes](#SHAP-Analysis-of-Mistakes)
#         1. [Pclass x Sex Subgroup Sample Size Analysis](#Pclass-x-Sex-Subgroup-Sample-Size-Analysis)
#         1. [Model-per-Subgroup Baseline Performance](#Model-per-Subgroup-Baseline-Performance)
#     1. [Pclass x Sex Subgroup Development](#Pclass-x-Sex-Subgroup-Development)
#         1. [P1 Male](#P1-Male)
#             1. [P1 Male Desciptive Statistics](#P1-Male-Desciptive-Statistics)
#             1. [P1 Male Distribution Shift Assessment](#P1-Male-Distribution-Shift-Assessment)
#             1. [P1 Male Feature Engineering](#P1-Male-Feature-Engineering)
#                 1. [P1_Male_Parch_SibSp_bin](#P1_Male_Parch_SibSp_bin)
#                 1. [P1_Male_Embarked_Is_S](#P1_Male_Embarked_Is_S)
#                 1. [P1_Male_Cabin_count_bin](#P1_Male_Cabin_count_bin)
#                 1. [P1_Male Cabin_Location_s](#P1_Male-Cabin_Location_s)
#                 1. [P1_Male_Deck_bin](#P1_Male_Deck_bin)
#                 1. [P1_Male_Title_bin](#P1_Male_Title_bin)
#                 1. [P1_Male_Age_bin](#P1_Male_Age_bin)
#                 1. [P1_Male_Fare_log_bin](#P1_Male_Fare_log_bin)
#             1. [P1 Male Feature Chi-Square Testing](#P1-Male-Feature-Chi-Square-Testing)
#             1. [P1 Male Smoothed Feature Engineering](#P1-Male-Smoothed-Feature-Engineering)
#             1. [P1 Male Model Development](#P1-Male-Model-Development)
#         1. [P3 Female](#P3-Female)
#             1. [P3 Female Desciptive Statistics](#P3-Female-Desciptive-Statistics)
#             1. [P3 Female Distribution Shift Assessment](#P3-Female-Distribution-Shift-Assessment)
#             1. [P3 Female Feature Engineering](#P3-Female-Feature-Engineering)
#                 1. [P3_Female_Parch_SibSp_bin](#P3_Female_Parch_SibSp_bin)
#                 1. [P3_Female_Embarked_Is_S](#P3_Female_Embarked_Is_S)
#                 1. [P3_Female_Cabin_count_bin](#P3_Female_Cabin_count_bin)
#                 1. [P3_Female_Cabin_Location_s_bin](#P3_Female_Cabin_Location_s_bin)
#                 1. [P3_Female_Deck_bin](#P3_Female_Deck_bin)
#     1. [Subgroup Feature Search](#Subgroup-Feature-Search)
#         1. [P1 Male](#P1-Male)
#         1. [P2 Male](#P2-Male)
#         1. [P3 Male](#P3-Male)
#         1. [P3 Female](#P3-Female)
#     1. [Hyperparameter Tuning](#Hyperparameter-Tuning)
# 1. [Submission](#Submission)
# 1. [References](#References)
#         1. [Table of Contents Generator](#Table-of-Contents-Generator)
